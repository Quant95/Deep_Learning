# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F 
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.autograd import Variable
from torch.utils.data import sampler

import help_func
import new_ALL_Conv
# Out:
# finish
# right

# %%
train_batch_size = 4
test_batch_size = 4

NUM_TRAIN = 49000

transform = transforms.Compose(
          [transforms.ToTensor(),
           transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))])

cifar10_train = torchvision.datasets.CIFAR10('./cs231n/datasets', train=True, download=True,
                             transform=transform)
loader_train = torch.utils.data.DataLoader(cifar10_train, batch_size=train_batch_size, 
                          sampler=sampler.SubsetRandomSampler(range(NUM_TRAIN)))

cifar10_val = torchvision.datasets.CIFAR10('./cs231n/datasets', train=True, download=True,
                           transform=transform)
loader_val = torch.utils.data.DataLoader(cifar10_val, batch_size=train_batch_size, 
                        sampler=sampler.SubsetRandomSampler(range(NUM_TRAIN, 50000)))

cifar10_test = torchvision.datasets.CIFAR10('./cs231n/datasets', train=False, download=True, 
                            transform=transform)
loader_test = torch.utils.data.DataLoader(cifar10_test, batch_size=test_batch_size)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %%
ALL_CNN_A = new_ALL_Conv.ALL_CNN_A()

# %%
lr = [0.025, 0.01, 0.005, 0.001] 
epoch = [200, 250, 300]
run_num = 50
net_name = 'ALL_CNN_A'

#torch.cuda.set_device(2)

ALL_CNN_A = help_func.running_model(run_num, ALL_CNN_A, net_name, lr, epoch, 
                        loader_train, loader_val, loader_test)
# Out:
# using device: cuda
# begin training
# Checking accuracy on validation set
# Got 224 / 1000 correct (22.40)
# 1 epoch,  1000 iteration, loss:2.254
# Checking accuracy on validation set
# Got 307 / 1000 correct (30.70)
# 1 epoch,  2000 iteration, loss:2.134
# Checking accuracy on validation set
# Got 327 / 1000 correct (32.70)
# 1 epoch,  3000 iteration, loss:2.016
# Checking accuracy on validation set
# Got 332 / 1000 correct (33.20)
# 1 epoch,  4000 iteration, loss:1.921
# Checking accuracy on validation set
# Got 342 / 1000 correct (34.20)
# 1 epoch,  5000 iteration, loss:1.812
# Checking accuracy on validation set
# Got 409 / 1000 correct (40.90)
# 1 epoch,  6000 iteration, loss:1.731
# Checking accuracy on validation set
# Got 403 / 1000 correct (40.30)
# 1 epoch,  7000 iteration, loss:1.701
# Checking accuracy on validation set
# Got 432 / 1000 correct (43.20)
# 1 epoch,  8000 iteration, loss:1.668
# Checking accuracy on validation set
# Got 431 / 1000 correct (43.10)
# 1 epoch,  9000 iteration, loss:1.629
# Checking accuracy on validation set
# Got 464 / 1000 correct (46.40)
# 1 epoch, 10000 iteration, loss:1.603
# Checking accuracy on validation set
# Got 483 / 1000 correct (48.30)
# 1 epoch, 11000 iteration, loss:1.567
# Checking accuracy on validation set
# Got 478 / 1000 correct (47.80)
# 1 epoch, 12000 iteration, loss:1.518
#  num 0 epoch
# ####### Training Loss #######
# [1.75563199]
# Checking accuracy on validation set
# Got 447 / 1000 correct (44.70)
# 2 epoch,  1000 iteration, loss:1.500
# Checking accuracy on validation set
# Got 471 / 1000 correct (47.10)
# 2 epoch,  2000 iteration, loss:1.493
# Checking accuracy on validation set
# Got 499 / 1000 correct (49.90)
# 2 epoch,  3000 iteration, loss:1.496
# Checking accuracy on validation set
# Got 492 / 1000 correct (49.20)
# 2 epoch,  4000 iteration, loss:1.437
# Checking accuracy on validation set
# Got 533 / 1000 correct (53.30)
# 2 epoch,  5000 iteration, loss:1.420
# Checking accuracy on validation set
# Got 521 / 1000 correct (52.10)
# 2 epoch,  6000 iteration, loss:1.430
# Checking accuracy on validation set
# Got 522 / 1000 correct (52.20)
# 2 epoch,  7000 iteration, loss:1.406
# Checking accuracy on validation set
# Got 535 / 1000 correct (53.50)
# 2 epoch,  8000 iteration, loss:1.366
# Checking accuracy on validation set
# Got 527 / 1000 correct (52.70)
# 2 epoch,  9000 iteration, loss:1.400
# Checking accuracy on validation set
# Got 530 / 1000 correct (53.00)
# 2 epoch, 10000 iteration, loss:1.360
# Checking accuracy on validation set
# Got 545 / 1000 correct (54.50)
# 2 epoch, 11000 iteration, loss:1.359
# Checking accuracy on validation set
# Got 563 / 1000 correct (56.30)
# 2 epoch, 12000 iteration, loss:1.318
#  num 1 epoch
# ####### Training Loss #######
# [1.3857962]
# Checking accuracy on validation set
# Got 587 / 1000 correct (58.70)
# 3 epoch,  1000 iteration, loss:1.298
# Checking accuracy on validation set
# Got 555 / 1000 correct (55.50)
# 3 epoch,  2000 iteration, loss:1.295
# Checking accuracy on validation set
# Got 587 / 1000 correct (58.70)
# 3 epoch,  3000 iteration, loss:1.276
# Checking accuracy on validation set
# Got 580 / 1000 correct (58.00)
# 3 epoch,  4000 iteration, loss:1.251
# Checking accuracy on validation set
# Got 596 / 1000 correct (59.60)
# 3 epoch,  5000 iteration, loss:1.239
# Checking accuracy on validation set
# Got 584 / 1000 correct (58.40)
# 3 epoch,  6000 iteration, loss:1.254
# Checking accuracy on validation set
# Got 572 / 1000 correct (57.20)
# 3 epoch,  7000 iteration, loss:1.215
# Checking accuracy on validation set
# Got 618 / 1000 correct (61.80)
# 3 epoch,  8000 iteration, loss:1.224
# Checking accuracy on validation set
# Got 625 / 1000 correct (62.50)
# 3 epoch,  9000 iteration, loss:1.229
# Checking accuracy on validation set
# Got 615 / 1000 correct (61.50)
# 3 epoch, 10000 iteration, loss:1.192
# Checking accuracy on validation set
# Got 606 / 1000 correct (60.60)
# 3 epoch, 11000 iteration, loss:1.208
# Checking accuracy on validation set
# Got 608 / 1000 correct (60.80)
# 3 epoch, 12000 iteration, loss:1.179
#  num 2 epoch
# ####### Training Loss #######
# [1.2133401]
# Checking accuracy on validation set
# Got 634 / 1000 correct (63.40)
# 4 epoch,  1000 iteration, loss:1.136
# Checking accuracy on validation set
# Got 641 / 1000 correct (64.10)
# 4 epoch,  2000 iteration, loss:1.140
# Checking accuracy on validation set
# Got 643 / 1000 correct (64.30)
# 4 epoch,  3000 iteration, loss:1.124
# Checking accuracy on validation set
# Got 648 / 1000 correct (64.80)
# 4 epoch,  4000 iteration, loss:1.109
# Checking accuracy on validation set
# Got 624 / 1000 correct (62.40)
# 4 epoch,  5000 iteration, loss:1.116
# Checking accuracy on validation set
# Got 657 / 1000 correct (65.70)
# 4 epoch,  6000 iteration, loss:1.105
# Checking accuracy on validation set
# Got 608 / 1000 correct (60.80)
# 4 epoch,  7000 iteration, loss:1.077
# Checking accuracy on validation set
# Got 671 / 1000 correct (67.10)
# 4 epoch,  8000 iteration, loss:1.077
# Checking accuracy on validation set
# Got 650 / 1000 correct (65.00)
# 4 epoch,  9000 iteration, loss:1.115
# Checking accuracy on validation set
# Got 651 / 1000 correct (65.10)
# 4 epoch, 10000 iteration, loss:1.082
# Checking accuracy on validation set
# Got 634 / 1000 correct (63.40)
# 4 epoch, 11000 iteration, loss:1.055
# Checking accuracy on validation set
# Got 651 / 1000 correct (65.10)
# 4 epoch, 12000 iteration, loss:1.071
#  num 3 epoch
# ####### Training Loss #######
# [1.07955079]
# Checking accuracy on validation set
# Got 682 / 1000 correct (68.20)
# 5 epoch,  1000 iteration, loss:1.051
# Checking accuracy on validation set
# Got 668 / 1000 correct (66.80)
# 5 epoch,  2000 iteration, loss:1.034
# Checking accuracy on validation set
# Got 651 / 1000 correct (65.10)
# 5 epoch,  3000 iteration, loss:1.006
# Checking accuracy on validation set
# Got 683 / 1000 correct (68.30)
# 5 epoch,  4000 iteration, loss:1.015
# Checking accuracy on validation set
# Got 680 / 1000 correct (68.00)
# 5 epoch,  5000 iteration, loss:0.968
# Checking accuracy on validation set
# Got 687 / 1000 correct (68.70)
# 5 epoch,  6000 iteration, loss:1.006
# Checking accuracy on validation set
# Got 652 / 1000 correct (65.20)
# 5 epoch,  7000 iteration, loss:1.019
# Checking accuracy on validation set
# Got 683 / 1000 correct (68.30)
# 5 epoch,  8000 iteration, loss:0.988
# Checking accuracy on validation set
# Got 696 / 1000 correct (69.60)
# 5 epoch,  9000 iteration, loss:0.996
# Checking accuracy on validation set
# Got 706 / 1000 correct (70.60)
# 5 epoch, 10000 iteration, loss:1.007
# Checking accuracy on validation set
# Got 696 / 1000 correct (69.60)
# 5 epoch, 11000 iteration, loss:0.995
# Checking accuracy on validation set
# Got 696 / 1000 correct (69.60)
# 5 epoch, 12000 iteration, loss:0.974
#  num 4 epoch
# ####### Training Loss #######
# [0.984149]
# Checking accuracy on validation set
# Got 683 / 1000 correct (68.30)
# 6 epoch,  1000 iteration, loss:0.958
# Checking accuracy on validation set
# Got 695 / 1000 correct (69.50)
# 6 epoch,  2000 iteration, loss:0.943
# Checking accuracy on validation set
# Got 703 / 1000 correct (70.30)
# 6 epoch,  3000 iteration, loss:0.923
# Checking accuracy on validation set
# Got 698 / 1000 correct (69.80)
# 6 epoch,  4000 iteration, loss:0.949
# Checking accuracy on validation set
# Got 700 / 1000 correct (70.00)
# 6 epoch,  5000 iteration, loss:0.946
# Checking accuracy on validation set
# Got 672 / 1000 correct (67.20)
# 6 epoch,  6000 iteration, loss:0.961
# Checking accuracy on validation set
# Got 708 / 1000 correct (70.80)
# 6 epoch,  7000 iteration, loss:0.897
# Checking accuracy on validation set
# Got 688 / 1000 correct (68.80)
# 6 epoch,  8000 iteration, loss:0.939
# Checking accuracy on validation set
# Got 707 / 1000 correct (70.70)
# 6 epoch,  9000 iteration, loss:0.938
# Checking accuracy on validation set
# Got 702 / 1000 correct (70.20)
# 6 epoch, 10000 iteration, loss:0.938
# Checking accuracy on validation set
# Got 714 / 1000 correct (71.40)
# 6 epoch, 11000 iteration, loss:0.906
# Checking accuracy on validation set
# Got 708 / 1000 correct (70.80)
# 6 epoch, 12000 iteration, loss:0.905
#  num 5 epoch
# ####### Training Loss #######
# [0.91368114]
# Checking accuracy on validation set
# Got 707 / 1000 correct (70.70)
# 7 epoch,  1000 iteration, loss:0.868
# Checking accuracy on validation set
# Got 710 / 1000 correct (71.00)
# 7 epoch,  2000 iteration, loss:0.869
# Checking accuracy on validation set
# Got 721 / 1000 correct (72.10)
# 7 epoch,  3000 iteration, loss:0.857
# Checking accuracy on validation set
# Got 727 / 1000 correct (72.70)
# 7 epoch,  4000 iteration, loss:0.878
# Checking accuracy on validation set
# Got 731 / 1000 correct (73.10)
# 7 epoch,  5000 iteration, loss:0.897
# Checking accuracy on validation set
# Got 732 / 1000 correct (73.20)
# 7 epoch,  6000 iteration, loss:0.884
# Checking accuracy on validation set
# Got 710 / 1000 correct (71.00)
# 7 epoch,  7000 iteration, loss:0.878
# Checking accuracy on validation set
# Got 719 / 1000 correct (71.90)
# 7 epoch,  8000 iteration, loss:0.859
# Checking accuracy on validation set
# Got 702 / 1000 correct (70.20)
# 7 epoch,  9000 iteration, loss:0.882
# Checking accuracy on validation set
# Got 702 / 1000 correct (70.20)
# 7 epoch, 10000 iteration, loss:0.873
# Checking accuracy on validation set
# Got 710 / 1000 correct (71.00)
# 7 epoch, 11000 iteration, loss:0.871
# Checking accuracy on validation set
# Got 744 / 1000 correct (74.40)
# 7 epoch, 12000 iteration, loss:0.857
#  num 6 epoch
# ####### Training Loss #######
# [0.85620636]
# Checking accuracy on validation set
# Got 694 / 1000 correct (69.40)
# 8 epoch,  1000 iteration, loss:0.841
# Checking accuracy on validation set
# Got 714 / 1000 correct (71.40)
# 8 epoch,  2000 iteration, loss:0.843
# Checking accuracy on validation set
# Got 743 / 1000 correct (74.30)
# 8 epoch,  3000 iteration, loss:0.844
# Checking accuracy on validation set
# Got 732 / 1000 correct (73.20)
# 8 epoch,  4000 iteration, loss:0.804
# Checking accuracy on validation set
# Got 749 / 1000 correct (74.90)
# 8 epoch,  5000 iteration, loss:0.842
# Checking accuracy on validation set
# Got 744 / 1000 correct (74.40)
# 8 epoch,  6000 iteration, loss:0.846
# Checking accuracy on validation set
# Got 719 / 1000 correct (71.90)
# 8 epoch,  7000 iteration, loss:0.825
# Checking accuracy on validation set
# Got 726 / 1000 correct (72.60)
# 8 epoch,  8000 iteration, loss:0.824
# Checking accuracy on validation set
# Got 759 / 1000 correct (75.90)
# 8 epoch,  9000 iteration, loss:0.810
# Checking accuracy on validation set
# Got 709 / 1000 correct (70.90)
# 8 epoch, 10000 iteration, loss:0.853
# Checking accuracy on validation set
# Got 749 / 1000 correct (74.90)
# 8 epoch, 11000 iteration, loss:0.824
# Checking accuracy on validation set
# Got 761 / 1000 correct (76.10)
# 8 epoch, 12000 iteration, loss:0.783
#  num 7 epoch
# ####### Training Loss #######
# [0.8108778]
# Checking accuracy on validation set
# Got 742 / 1000 correct (74.20)
# 9 epoch,  1000 iteration, loss:0.790
# Checking accuracy on validation set
# Got 739 / 1000 correct (73.90)
# 9 epoch,  2000 iteration, loss:0.780
# Checking accuracy on validation set
# Got 737 / 1000 correct (73.70)
# 9 epoch,  3000 iteration, loss:0.807
# Checking accuracy on validation set
# Got 739 / 1000 correct (73.90)
# 9 epoch,  4000 iteration, loss:0.786
# Checking accuracy on validation set
# Got 753 / 1000 correct (75.30)
# 9 epoch,  5000 iteration, loss:0.797
# Checking accuracy on validation set
# Got 741 / 1000 correct (74.10)
# 9 epoch,  6000 iteration, loss:0.783
# Checking accuracy on validation set
# Got 740 / 1000 correct (74.00)
# 9 epoch,  7000 iteration, loss:0.779
# Checking accuracy on validation set
# Got 730 / 1000 correct (73.00)
# 9 epoch,  8000 iteration, loss:0.785
# Checking accuracy on validation set
# Got 749 / 1000 correct (74.90)
# 9 epoch,  9000 iteration, loss:0.778
# Checking accuracy on validation set
# Got 738 / 1000 correct (73.80)
# 9 epoch, 10000 iteration, loss:0.810
# Checking accuracy on validation set
# Got 751 / 1000 correct (75.10)
# 9 epoch, 11000 iteration, loss:0.788
# Checking accuracy on validation set
# Got 736 / 1000 correct (73.60)
# 9 epoch, 12000 iteration, loss:0.768
#  num 8 epoch
# ####### Training Loss #######
# [0.77210318]
# Checking accuracy on validation set
# Got 750 / 1000 correct (75.00)
# 10 epoch,  1000 iteration, loss:0.741
# Checking accuracy on validation set
# Got 753 / 1000 correct (75.30)
# 10 epoch,  2000 iteration, loss:0.746
# Checking accuracy on validation set
# Got 747 / 1000 correct (74.70)
# 10 epoch,  3000 iteration, loss:0.769
# Checking accuracy on validation set
# Got 744 / 1000 correct (74.40)
# 10 epoch,  4000 iteration, loss:0.750
# Checking accuracy on validation set
# Got 762 / 1000 correct (76.20)
# 10 epoch,  5000 iteration, loss:0.745
# Checking accuracy on validation set
# Got 766 / 1000 correct (76.60)
# 10 epoch,  6000 iteration, loss:0.761
# Checking accuracy on validation set
# Got 736 / 1000 correct (73.60)
# 10 epoch,  7000 iteration, loss:0.746
# Checking accuracy on validation set
# Got 765 / 1000 correct (76.50)
# 10 epoch,  8000 iteration, loss:0.764
# Checking accuracy on validation set
# Got 762 / 1000 correct (76.20)
# 10 epoch,  9000 iteration, loss:0.759
# Checking accuracy on validation set
# Got 766 / 1000 correct (76.60)
# 10 epoch, 10000 iteration, loss:0.754
# Checking accuracy on validation set
# Got 753 / 1000 correct (75.30)
# 10 epoch, 11000 iteration, loss:0.775
# Checking accuracy on validation set
# Got 747 / 1000 correct (74.70)
# 10 epoch, 12000 iteration, loss:0.758
#  num 9 epoch
# ####### Training Loss #######
# [0.74040433]
# Checking accuracy on validation set
# Got 759 / 1000 correct (75.90)
# 11 epoch,  1000 iteration, loss:0.721
# Checking accuracy on validation set
# Got 744 / 1000 correct (74.40)
# 11 epoch,  2000 iteration, loss:0.690
# Checking accuracy on validation set
# Got 754 / 1000 correct (75.40)
# 11 epoch,  3000 iteration, loss:0.726
# Checking accuracy on validation set
# Got 751 / 1000 correct (75.10)
# 11 epoch,  4000 iteration, loss:0.714
# Checking accuracy on validation set
# Got 745 / 1000 correct (74.50)
# 11 epoch,  5000 iteration, loss:0.723
# Checking accuracy on validation set
# Got 773 / 1000 correct (77.30)
# 11 epoch,  6000 iteration, loss:0.735
# Checking accuracy on validation set
# Got 749 / 1000 correct (74.90)
# 11 epoch,  7000 iteration, loss:0.711
# Checking accuracy on validation set
# Got 752 / 1000 correct (75.20)
# 11 epoch,  8000 iteration, loss:0.764
# Checking accuracy on validation set
# Got 763 / 1000 correct (76.30)
# 11 epoch,  9000 iteration, loss:0.714
# Checking accuracy on validation set
# Got 753 / 1000 correct (75.30)
# 11 epoch, 10000 iteration, loss:0.739
# Checking accuracy on validation set
# Got 765 / 1000 correct (76.50)
# 11 epoch, 11000 iteration, loss:0.718
# Checking accuracy on validation set
# Got 753 / 1000 correct (75.30)
# 11 epoch, 12000 iteration, loss:0.747
#  num 10 epoch
# ####### Training Loss #######
# [0.71001676]
# Checking accuracy on validation set
# Got 741 / 1000 correct (74.10)
# 12 epoch,  1000 iteration, loss:0.689
# Checking accuracy on validation set
# Got 789 / 1000 correct (78.90)
# 12 epoch,  2000 iteration, loss:0.677
# Checking accuracy on validation set
# Got 777 / 1000 correct (77.70)
# 12 epoch,  3000 iteration, loss:0.717
# Checking accuracy on validation set
# Got 755 / 1000 correct (75.50)
# 12 epoch,  4000 iteration, loss:0.671
# Checking accuracy on validation set
# Got 770 / 1000 correct (77.00)
# 12 epoch,  5000 iteration, loss:0.690
# Checking accuracy on validation set
# Got 781 / 1000 correct (78.10)
# 12 epoch,  6000 iteration, loss:0.721
# Checking accuracy on validation set
# Got 764 / 1000 correct (76.40)
# 12 epoch,  7000 iteration, loss:0.705
# Checking accuracy on validation set
# Got 771 / 1000 correct (77.10)
# 12 epoch,  8000 iteration, loss:0.709
# Checking accuracy on validation set
# Got 777 / 1000 correct (77.70)
# 12 epoch,  9000 iteration, loss:0.720
# Checking accuracy on validation set
# Got 763 / 1000 correct (76.30)
# 12 epoch, 10000 iteration, loss:0.719
# Checking accuracy on validation set
# Got 785 / 1000 correct (78.50)
# 12 epoch, 11000 iteration, loss:0.705
# Checking accuracy on validation set
# Got 775 / 1000 correct (77.50)
# 12 epoch, 12000 iteration, loss:0.685
#  num 11 epoch
# ####### Training Loss #######
# [0.68781125]
# Checking accuracy on validation set
# Got 765 / 1000 correct (76.50)
# 13 epoch,  1000 iteration, loss:0.650
# Checking accuracy on validation set
# Got 771 / 1000 correct (77.10)
# 13 epoch,  2000 iteration, loss:0.639
# Checking accuracy on validation set
# Got 774 / 1000 correct (77.40)
# 13 epoch,  3000 iteration, loss:0.696
# Checking accuracy on validation set
# Got 760 / 1000 correct (76.00)
# 13 epoch,  4000 iteration, loss:0.663
# Checking accuracy on validation set
# Got 759 / 1000 correct (75.90)
# 13 epoch,  5000 iteration, loss:0.656
# Checking accuracy on validation set
# Got 778 / 1000 correct (77.80)
# 13 epoch,  6000 iteration, loss:0.693
# Checking accuracy on validation set
# Got 750 / 1000 correct (75.00)
# 13 epoch,  7000 iteration, loss:0.678
# Checking accuracy on validation set
# Got 776 / 1000 correct (77.60)
# 13 epoch,  8000 iteration, loss:0.706
# Checking accuracy on validation set
# Got 785 / 1000 correct (78.50)
# 13 epoch,  9000 iteration, loss:0.691
# Checking accuracy on validation set
# Got 764 / 1000 correct (76.40)
# 13 epoch, 10000 iteration, loss:0.681
# Checking accuracy on validation set
# Got 768 / 1000 correct (76.80)
# 13 epoch, 11000 iteration, loss:0.674
# Checking accuracy on validation set
# Got 773 / 1000 correct (77.30)
# 13 epoch, 12000 iteration, loss:0.698
#  num 12 epoch
# ####### Training Loss #######
# [0.66227996]
# Checking accuracy on validation set
# Got 783 / 1000 correct (78.30)
# 14 epoch,  1000 iteration, loss:0.632
# Checking accuracy on validation set
# Got 780 / 1000 correct (78.00)
# 14 epoch,  2000 iteration, loss:0.650
# Checking accuracy on validation set
# Got 749 / 1000 correct (74.90)
# 14 epoch,  3000 iteration, loss:0.634
# Checking accuracy on validation set
# Got 790 / 1000 correct (79.00)
# 14 epoch,  4000 iteration, loss:0.654
# Checking accuracy on validation set
# Got 751 / 1000 correct (75.10)
# 14 epoch,  5000 iteration, loss:0.656
# Checking accuracy on validation set
# Got 775 / 1000 correct (77.50)
# 14 epoch,  6000 iteration, loss:0.656
# Checking accuracy on validation set
# Got 760 / 1000 correct (76.00)
# 14 epoch,  7000 iteration, loss:0.676
# Checking accuracy on validation set
# Got 788 / 1000 correct (78.80)
# 14 epoch,  8000 iteration, loss:0.656
# Checking accuracy on validation set
# Got 783 / 1000 correct (78.30)
# 14 epoch,  9000 iteration, loss:0.663
# Checking accuracy on validation set
# Got 784 / 1000 correct (78.40)
# 14 epoch, 10000 iteration, loss:0.657
# Checking accuracy on validation set
# Got 786 / 1000 correct (78.60)
# 14 epoch, 11000 iteration, loss:0.689
# Checking accuracy on validation set
# Got 789 / 1000 correct (78.90)
# 14 epoch, 12000 iteration, loss:0.659
#  num 13 epoch
# ####### Training Loss #######
# [0.64418287]
# Checking accuracy on validation set
# Got 790 / 1000 correct (79.00)
# 15 epoch,  1000 iteration, loss:0.637
# Checking accuracy on validation set
# Got 793 / 1000 correct (79.30)
# 15 epoch,  2000 iteration, loss:0.602
# Checking accuracy on validation set
# Got 762 / 1000 correct (76.20)
# 15 epoch,  3000 iteration, loss:0.633
# Checking accuracy on validation set
# Got 793 / 1000 correct (79.30)
# 15 epoch,  4000 iteration, loss:0.636
# Checking accuracy on validation set
# Got 785 / 1000 correct (78.50)
# 15 epoch,  5000 iteration, loss:0.603
# Checking accuracy on validation set
# Got 759 / 1000 correct (75.90)
# 15 epoch,  6000 iteration, loss:0.677
# Checking accuracy on validation set
# Got 790 / 1000 correct (79.00)
# 15 epoch,  7000 iteration, loss:0.638
# Checking accuracy on validation set
# Got 759 / 1000 correct (75.90)
# 15 epoch,  8000 iteration, loss:0.671
# Checking accuracy on validation set
# Got 785 / 1000 correct (78.50)
# 15 epoch,  9000 iteration, loss:0.660
# Checking accuracy on validation set
# Got 790 / 1000 correct (79.00)
# 15 epoch, 10000 iteration, loss:0.626
# Checking accuracy on validation set
# Got 779 / 1000 correct (77.90)
# 15 epoch, 11000 iteration, loss:0.655
# Checking accuracy on validation set
# Got 783 / 1000 correct (78.30)
# 15 epoch, 12000 iteration, loss:0.647
#  num 14 epoch
# ####### Training Loss #######
# [0.62666895]
# Checking accuracy on validation set
# Got 771 / 1000 correct (77.10)
# 16 epoch,  1000 iteration, loss:0.610
# Checking accuracy on validation set
# Got 771 / 1000 correct (77.10)
# 16 epoch,  2000 iteration, loss:0.642
# Checking accuracy on validation set
# Got 765 / 1000 correct (76.50)
# 16 epoch,  3000 iteration, loss:0.609
# Checking accuracy on validation set
# Got 781 / 1000 correct (78.10)
# 16 epoch,  4000 iteration, loss:0.585
# Checking accuracy on validation set
# Got 784 / 1000 correct (78.40)
# 16 epoch,  5000 iteration, loss:0.637
# Checking accuracy on validation set
# Got 773 / 1000 correct (77.30)
# 16 epoch,  6000 iteration, loss:0.624
# Checking accuracy on validation set
# Got 755 / 1000 correct (75.50)
# 16 epoch,  7000 iteration, loss:0.632
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
# 16 epoch,  8000 iteration, loss:0.632
# Checking accuracy on validation set
# Got 777 / 1000 correct (77.70)
# 16 epoch,  9000 iteration, loss:0.630
# Checking accuracy on validation set
# Got 776 / 1000 correct (77.60)
# 16 epoch, 10000 iteration, loss:0.633
# Checking accuracy on validation set
# Got 766 / 1000 correct (76.60)
# 16 epoch, 11000 iteration, loss:0.641
# Checking accuracy on validation set
# Got 767 / 1000 correct (76.70)
# 16 epoch, 12000 iteration, loss:0.646
#  num 15 epoch
# ####### Training Loss #######
# [0.61366155]
# Checking accuracy on validation set
# Got 760 / 1000 correct (76.00)
# 17 epoch,  1000 iteration, loss:0.572
# Checking accuracy on validation set
# Got 788 / 1000 correct (78.80)
# 17 epoch,  2000 iteration, loss:0.591
# Checking accuracy on validation set
# Got 785 / 1000 correct (78.50)
# 17 epoch,  3000 iteration, loss:0.622
# Checking accuracy on validation set
# Got 776 / 1000 correct (77.60)
# 17 epoch,  4000 iteration, loss:0.592
# Checking accuracy on validation set
# Got 798 / 1000 correct (79.80)
# 17 epoch,  5000 iteration, loss:0.627
# Checking accuracy on validation set
# Got 769 / 1000 correct (76.90)
# 17 epoch,  6000 iteration, loss:0.596
# Checking accuracy on validation set
# Got 745 / 1000 correct (74.50)
# 17 epoch,  7000 iteration, loss:0.590
# Checking accuracy on validation set
# Got 763 / 1000 correct (76.30)
# 17 epoch,  8000 iteration, loss:0.623
# Checking accuracy on validation set
# Got 760 / 1000 correct (76.00)
# 17 epoch,  9000 iteration, loss:0.629
# Checking accuracy on validation set
# Got 789 / 1000 correct (78.90)
# 17 epoch, 10000 iteration, loss:0.651
# Checking accuracy on validation set
# Got 782 / 1000 correct (78.20)
# 17 epoch, 11000 iteration, loss:0.598
# Checking accuracy on validation set
# Got 758 / 1000 correct (75.80)
# 17 epoch, 12000 iteration, loss:0.616
#  num 16 epoch
# ####### Training Loss #######
# [0.59752294]
# Checking accuracy on validation set
# Got 794 / 1000 correct (79.40)
# 18 epoch,  1000 iteration, loss:0.563
# Checking accuracy on validation set
# Got 750 / 1000 correct (75.00)
# 18 epoch,  2000 iteration, loss:0.573
# Checking accuracy on validation set
# Got 806 / 1000 correct (80.60)
# 18 epoch,  3000 iteration, loss:0.615
# Checking accuracy on validation set
# Got 765 / 1000 correct (76.50)
# 18 epoch,  4000 iteration, loss:0.580
# Checking accuracy on validation set
# Got 773 / 1000 correct (77.30)
# 18 epoch,  5000 iteration, loss:0.590
# Checking accuracy on validation set
# Got 787 / 1000 correct (78.70)
# 18 epoch,  6000 iteration, loss:0.595
# Checking accuracy on validation set
# Got 791 / 1000 correct (79.10)
# 18 epoch,  7000 iteration, loss:0.607
# Checking accuracy on validation set
# Got 755 / 1000 correct (75.50)
# 18 epoch,  8000 iteration, loss:0.621
# Checking accuracy on validation set
# Got 787 / 1000 correct (78.70)
# 18 epoch,  9000 iteration, loss:0.627
# Checking accuracy on validation set
# Got 760 / 1000 correct (76.00)
# 18 epoch, 10000 iteration, loss:0.589
# Checking accuracy on validation set
# Got 787 / 1000 correct (78.70)
# 18 epoch, 11000 iteration, loss:0.592
# Checking accuracy on validation set
# Got 772 / 1000 correct (77.20)
# 18 epoch, 12000 iteration, loss:0.587
#  num 17 epoch
# ####### Training Loss #######
# [0.58428821]
# Checking accuracy on validation set
# Got 801 / 1000 correct (80.10)
# 19 epoch,  1000 iteration, loss:0.551
# Checking accuracy on validation set
# Got 777 / 1000 correct (77.70)
# 19 epoch,  2000 iteration, loss:0.555
# Checking accuracy on validation set
# Got 794 / 1000 correct (79.40)
# 19 epoch,  3000 iteration, loss:0.571
# Checking accuracy on validation set
# Got 784 / 1000 correct (78.40)
# 19 epoch,  4000 iteration, loss:0.569
# Checking accuracy on validation set
# Got 792 / 1000 correct (79.20)
# 19 epoch,  5000 iteration, loss:0.603
# Checking accuracy on validation set
# Got 789 / 1000 correct (78.90)
# 19 epoch,  6000 iteration, loss:0.585
# Checking accuracy on validation set
# Got 773 / 1000 correct (77.30)
# 19 epoch,  7000 iteration, loss:0.568
# Checking accuracy on validation set
# Got 786 / 1000 correct (78.60)
# 19 epoch,  8000 iteration, loss:0.604
# Checking accuracy on validation set
# Got 789 / 1000 correct (78.90)
# 19 epoch,  9000 iteration, loss:0.589
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
# 19 epoch, 10000 iteration, loss:0.627
# Checking accuracy on validation set
# Got 793 / 1000 correct (79.30)
# 19 epoch, 11000 iteration, loss:0.606
# Checking accuracy on validation set
# Got 789 / 1000 correct (78.90)
# 19 epoch, 12000 iteration, loss:0.594
#  num 18 epoch
# ####### Training Loss #######
# [0.57325656]
# Checking accuracy on validation set
# Got 799 / 1000 correct (79.90)
# 20 epoch,  1000 iteration, loss:0.555
# Checking accuracy on validation set
# Got 787 / 1000 correct (78.70)
# 20 epoch,  2000 iteration, loss:0.540
# Checking accuracy on validation set
# Got 790 / 1000 correct (79.00)
# 20 epoch,  3000 iteration, loss:0.534
# Checking accuracy on validation set
# Got 766 / 1000 correct (76.60)
# 20 epoch,  4000 iteration, loss:0.573
# Checking accuracy on validation set
# Got 768 / 1000 correct (76.80)
# 20 epoch,  5000 iteration, loss:0.549
# Checking accuracy on validation set
# Got 781 / 1000 correct (78.10)
# 20 epoch,  6000 iteration, loss:0.581
# Checking accuracy on validation set
# Got 765 / 1000 correct (76.50)
# 20 epoch,  7000 iteration, loss:0.580
# Checking accuracy on validation set
# Got 785 / 1000 correct (78.50)
# 20 epoch,  8000 iteration, loss:0.607
# Checking accuracy on validation set
# Got 782 / 1000 correct (78.20)
# 20 epoch,  9000 iteration, loss:0.571
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
# 20 epoch, 10000 iteration, loss:0.581
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
# 20 epoch, 11000 iteration, loss:0.600
# Checking accuracy on validation set
# Got 778 / 1000 correct (77.80)
# 20 epoch, 12000 iteration, loss:0.596
#  num 19 epoch
# ####### Training Loss #######
# [0.56070269]
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
# 21 epoch,  1000 iteration, loss:0.536
# Checking accuracy on validation set
# Got 801 / 1000 correct (80.10)
# 21 epoch,  2000 iteration, loss:0.540
# Checking accuracy on validation set
# Got 801 / 1000 correct (80.10)
# 21 epoch,  3000 iteration, loss:0.565
# Checking accuracy on validation set
# Got 770 / 1000 correct (77.00)
# 21 epoch,  4000 iteration, loss:0.541
# Checking accuracy on validation set
# Got 807 / 1000 correct (80.70)
# 21 epoch,  5000 iteration, loss:0.533
# Checking accuracy on validation set
# Got 784 / 1000 correct (78.40)
# 21 epoch,  6000 iteration, loss:0.562
# Checking accuracy on validation set
# Got 798 / 1000 correct (79.80)
# 21 epoch,  7000 iteration, loss:0.580
# Checking accuracy on validation set
# Got 799 / 1000 correct (79.90)
# 21 epoch,  8000 iteration, loss:0.578
# Checking accuracy on validation set
# Got 788 / 1000 correct (78.80)
# 21 epoch,  9000 iteration, loss:0.584
# Checking accuracy on validation set
# Got 790 / 1000 correct (79.00)
# 21 epoch, 10000 iteration, loss:0.571
# Checking accuracy on validation set
# Got 800 / 1000 correct (80.00)
# 21 epoch, 11000 iteration, loss:0.592
# Checking accuracy on validation set
# Got 781 / 1000 correct (78.10)
# 21 epoch, 12000 iteration, loss:0.591
#  num 20 epoch
# ####### Training Loss #######
# [0.55338867]
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
# 22 epoch,  1000 iteration, loss:0.531
# Checking accuracy on validation set
# Got 779 / 1000 correct (77.90)
# 22 epoch,  2000 iteration, loss:0.543
# Checking accuracy on validation set
# Got 781 / 1000 correct (78.10)
# 22 epoch,  3000 iteration, loss:0.526
# Checking accuracy on validation set
# Got 766 / 1000 correct (76.60)
# 22 epoch,  4000 iteration, loss:0.525
# Checking accuracy on validation set
# Got 802 / 1000 correct (80.20)
# 22 epoch,  5000 iteration, loss:0.554
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
# 22 epoch,  6000 iteration, loss:0.557
# Checking accuracy on validation set
# Got 787 / 1000 correct (78.70)
# 22 epoch,  7000 iteration, loss:0.563
# Checking accuracy on validation set
# Got 763 / 1000 correct (76.30)
# 22 epoch,  8000 iteration, loss:0.551
# Checking accuracy on validation set
# Got 776 / 1000 correct (77.60)
# 22 epoch,  9000 iteration, loss:0.561
# Checking accuracy on validation set
# Got 777 / 1000 correct (77.70)
# 22 epoch, 10000 iteration, loss:0.563
# Checking accuracy on validation set
# Got 789 / 1000 correct (78.90)
# 22 epoch, 11000 iteration, loss:0.569
# Checking accuracy on validation set
# Got 766 / 1000 correct (76.60)
# 22 epoch, 12000 iteration, loss:0.555
#  num 21 epoch
# ####### Training Loss #######
# [0.53787709]
# Checking accuracy on validation set
# Got 775 / 1000 correct (77.50)
# 23 epoch,  1000 iteration, loss:0.513
# Checking accuracy on validation set
# Got 778 / 1000 correct (77.80)
# 23 epoch,  2000 iteration, loss:0.522
# Checking accuracy on validation set
# Got 762 / 1000 correct (76.20)
# 23 epoch,  3000 iteration, loss:0.528
# Checking accuracy on validation set
# Got 783 / 1000 correct (78.30)
# 23 epoch,  4000 iteration, loss:0.522
# Checking accuracy on validation set
# Got 794 / 1000 correct (79.40)
# 23 epoch,  5000 iteration, loss:0.526
# Checking accuracy on validation set
# Got 789 / 1000 correct (78.90)
# 23 epoch,  6000 iteration, loss:0.567
# Checking accuracy on validation set
# Got 792 / 1000 correct (79.20)
# 23 epoch,  7000 iteration, loss:0.583
# Checking accuracy on validation set
# Got 790 / 1000 correct (79.00)
# 23 epoch,  8000 iteration, loss:0.554
# Checking accuracy on validation set
# Got 802 / 1000 correct (80.20)
# 23 epoch,  9000 iteration, loss:0.534
# Checking accuracy on validation set
# Got 798 / 1000 correct (79.80)
# 23 epoch, 10000 iteration, loss:0.578
# Checking accuracy on validation set
# Got 788 / 1000 correct (78.80)
# 23 epoch, 11000 iteration, loss:0.555
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
# 23 epoch, 12000 iteration, loss:0.559
#  num 22 epoch
# ####### Training Loss #######
# [0.53370735]
# Checking accuracy on validation set
# Got 799 / 1000 correct (79.90)
# 24 epoch,  1000 iteration, loss:0.503
# Checking accuracy on validation set
# Got 786 / 1000 correct (78.60)
# 24 epoch,  2000 iteration, loss:0.509
# Checking accuracy on validation set
# Got 790 / 1000 correct (79.00)
# 24 epoch,  3000 iteration, loss:0.531
# Checking accuracy on validation set
# Got 771 / 1000 correct (77.10)
# 24 epoch,  4000 iteration, loss:0.534
# Checking accuracy on validation set
# Got 793 / 1000 correct (79.30)
# 24 epoch,  5000 iteration, loss:0.542
# Checking accuracy on validation set
# Got 770 / 1000 correct (77.00)
# 24 epoch,  6000 iteration, loss:0.520
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
# 24 epoch,  7000 iteration, loss:0.565
# Checking accuracy on validation set
# Got 815 / 1000 correct (81.50)
# 24 epoch,  8000 iteration, loss:0.532
# Checking accuracy on validation set
# Got 791 / 1000 correct (79.10)
# 24 epoch,  9000 iteration, loss:0.562
# Checking accuracy on validation set
# Got 798 / 1000 correct (79.80)
# 24 epoch, 10000 iteration, loss:0.557
# Checking accuracy on validation set
# Got 789 / 1000 correct (78.90)
# 24 epoch, 11000 iteration, loss:0.566
# Checking accuracy on validation set
# Got 791 / 1000 correct (79.10)
# 24 epoch, 12000 iteration, loss:0.536
#  num 23 epoch
# ####### Training Loss #######
# [0.52647747]
# Checking accuracy on validation set
# Got 794 / 1000 correct (79.40)
# 25 epoch,  1000 iteration, loss:0.491
# Checking accuracy on validation set
# Got 763 / 1000 correct (76.30)
# 25 epoch,  2000 iteration, loss:0.511
# Checking accuracy on validation set
# Got 789 / 1000 correct (78.90)
# 25 epoch,  3000 iteration, loss:0.520
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
# 25 epoch,  4000 iteration, loss:0.532
# Checking accuracy on validation set
# Got 760 / 1000 correct (76.00)
# 25 epoch,  5000 iteration, loss:0.511
# Checking accuracy on validation set
# Got 806 / 1000 correct (80.60)
# 25 epoch,  6000 iteration, loss:0.527
# Checking accuracy on validation set
# Got 787 / 1000 correct (78.70)
# 25 epoch,  7000 iteration, loss:0.549
# Checking accuracy on validation set
# Got 790 / 1000 correct (79.00)
# 25 epoch,  8000 iteration, loss:0.532
# Checking accuracy on validation set
# Got 792 / 1000 correct (79.20)
# 25 epoch,  9000 iteration, loss:0.562
# Checking accuracy on validation set
# Got 782 / 1000 correct (78.20)
# 25 epoch, 10000 iteration, loss:0.537
# Checking accuracy on validation set
# Got 785 / 1000 correct (78.50)
# 25 epoch, 11000 iteration, loss:0.546
# Checking accuracy on validation set
# Got 771 / 1000 correct (77.10)
# 25 epoch, 12000 iteration, loss:0.558
#  num 24 epoch
# ####### Training Loss #######
# [0.52103916]
# Checking accuracy on validation set
# Got 817 / 1000 correct (81.70)
# 26 epoch,  1000 iteration, loss:0.488
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
# 26 epoch,  2000 iteration, loss:0.482
# Checking accuracy on validation set
# Got 792 / 1000 correct (79.20)
# 26 epoch,  3000 iteration, loss:0.523
# Checking accuracy on validation set
# Got 789 / 1000 correct (78.90)
# 26 epoch,  4000 iteration, loss:0.489
# Checking accuracy on validation set
# Got 803 / 1000 correct (80.30)
# 26 epoch,  5000 iteration, loss:0.519
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
# 26 epoch,  6000 iteration, loss:0.528
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
# 26 epoch,  7000 iteration, loss:0.513
# Checking accuracy on validation set
# Got 794 / 1000 correct (79.40)
# 26 epoch,  8000 iteration, loss:0.539
# Checking accuracy on validation set
# Got 805 / 1000 correct (80.50)
# 26 epoch,  9000 iteration, loss:0.540
# Checking accuracy on validation set
# Got 802 / 1000 correct (80.20)
# 26 epoch, 10000 iteration, loss:0.520
# Checking accuracy on validation set
# Got 806 / 1000 correct (80.60)
# 26 epoch, 11000 iteration, loss:0.554
# Checking accuracy on validation set
# Got 784 / 1000 correct (78.40)
# 26 epoch, 12000 iteration, loss:0.557
#  num 25 epoch
# ####### Training Loss #######
# [0.51227541]
# Checking accuracy on validation set
# Got 798 / 1000 correct (79.80)
# 27 epoch,  1000 iteration, loss:0.484
# Checking accuracy on validation set
# Got 805 / 1000 correct (80.50)
# 27 epoch,  2000 iteration, loss:0.491
# Checking accuracy on validation set
# Got 769 / 1000 correct (76.90)
# 27 epoch,  3000 iteration, loss:0.486
# Checking accuracy on validation set
# Got 792 / 1000 correct (79.20)
# 27 epoch,  4000 iteration, loss:0.481
# Checking accuracy on validation set
# Got 796 / 1000 correct (79.60)
# 27 epoch,  5000 iteration, loss:0.511
# Checking accuracy on validation set
# Got 758 / 1000 correct (75.80)
# 27 epoch,  6000 iteration, loss:0.513
# Checking accuracy on validation set
# Got 801 / 1000 correct (80.10)
# 27 epoch,  7000 iteration, loss:0.534
# Checking accuracy on validation set
# Got 784 / 1000 correct (78.40)
# 27 epoch,  8000 iteration, loss:0.507
# Checking accuracy on validation set
# Got 784 / 1000 correct (78.40)
# 27 epoch,  9000 iteration, loss:0.535
# Checking accuracy on validation set
# Got 781 / 1000 correct (78.10)
# 27 epoch, 10000 iteration, loss:0.536
# Checking accuracy on validation set
# Got 780 / 1000 correct (78.00)
# 27 epoch, 11000 iteration, loss:0.526
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
# 27 epoch, 12000 iteration, loss:0.558
#  num 26 epoch
# ####### Training Loss #######
# [0.50369971]
# Checking accuracy on validation set
# Got 796 / 1000 correct (79.60)
# 28 epoch,  1000 iteration, loss:0.466
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
# 28 epoch,  2000 iteration, loss:0.456
# Checking accuracy on validation set
# Got 788 / 1000 correct (78.80)
# 28 epoch,  3000 iteration, loss:0.506
# Checking accuracy on validation set
# Got 782 / 1000 correct (78.20)
# 28 epoch,  4000 iteration, loss:0.516
# Checking accuracy on validation set
# Got 779 / 1000 correct (77.90)
# 28 epoch,  5000 iteration, loss:0.498
# Checking accuracy on validation set
# Got 794 / 1000 correct (79.40)
# 28 epoch,  6000 iteration, loss:0.519
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
# 28 epoch,  7000 iteration, loss:0.497
# Checking accuracy on validation set
# Got 783 / 1000 correct (78.30)
# 28 epoch,  8000 iteration, loss:0.539
# Checking accuracy on validation set
# Got 776 / 1000 correct (77.60)
# 28 epoch,  9000 iteration, loss:0.542
# Checking accuracy on validation set
# Got 799 / 1000 correct (79.90)
# 28 epoch, 10000 iteration, loss:0.532
# Checking accuracy on validation set
# Got 798 / 1000 correct (79.80)
# 28 epoch, 11000 iteration, loss:0.502
# Checking accuracy on validation set
# Got 798 / 1000 correct (79.80)
# 28 epoch, 12000 iteration, loss:0.546
#  num 27 epoch
# ####### Training Loss #######
# [0.50012882]
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
# 29 epoch,  1000 iteration, loss:0.467
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
# 29 epoch,  2000 iteration, loss:0.483
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
# 29 epoch,  3000 iteration, loss:0.493
# Checking accuracy on validation set
# Got 793 / 1000 correct (79.30)
# 29 epoch,  4000 iteration, loss:0.509
# Checking accuracy on validation set
# Got 787 / 1000 correct (78.70)
# 29 epoch,  5000 iteration, loss:0.502
# Checking accuracy on validation set
# Got 790 / 1000 correct (79.00)
# 29 epoch,  6000 iteration, loss:0.517
# Checking accuracy on validation set
# Got 803 / 1000 correct (80.30)
# 29 epoch,  7000 iteration, loss:0.532
# Checking accuracy on validation set
# Got 787 / 1000 correct (78.70)
# 29 epoch,  8000 iteration, loss:0.497
# Checking accuracy on validation set
# Got 799 / 1000 correct (79.90)
# 29 epoch,  9000 iteration, loss:0.522
# Checking accuracy on validation set
# Got 785 / 1000 correct (78.50)
# 29 epoch, 10000 iteration, loss:0.515
# Checking accuracy on validation set
# Got 786 / 1000 correct (78.60)
# 29 epoch, 11000 iteration, loss:0.532
# Checking accuracy on validation set
# Got 791 / 1000 correct (79.10)
# 29 epoch, 12000 iteration, loss:0.506
#  num 28 epoch
# ####### Training Loss #######
# [0.49580376]
# Checking accuracy on validation set
# Got 787 / 1000 correct (78.70)
# 30 epoch,  1000 iteration, loss:0.476
# Checking accuracy on validation set
# Got 805 / 1000 correct (80.50)
# 30 epoch,  2000 iteration, loss:0.472
# Checking accuracy on validation set
# Got 802 / 1000 correct (80.20)
# 30 epoch,  3000 iteration, loss:0.470
# Checking accuracy on validation set
# Got 803 / 1000 correct (80.30)
# 30 epoch,  4000 iteration, loss:0.484
# Checking accuracy on validation set
# Got 777 / 1000 correct (77.70)
# 30 epoch,  5000 iteration, loss:0.488
# Checking accuracy on validation set
# Got 776 / 1000 correct (77.60)
# 30 epoch,  6000 iteration, loss:0.484
# Checking accuracy on validation set
# Got 770 / 1000 correct (77.00)
# 30 epoch,  7000 iteration, loss:0.498
# Checking accuracy on validation set
# Got 780 / 1000 correct (78.00)
# 30 epoch,  8000 iteration, loss:0.503
# Checking accuracy on validation set
# Got 799 / 1000 correct (79.90)
# 30 epoch,  9000 iteration, loss:0.518
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
# 30 epoch, 10000 iteration, loss:0.535
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
# 30 epoch, 11000 iteration, loss:0.536
# Checking accuracy on validation set
# Got 800 / 1000 correct (80.00)
# 30 epoch, 12000 iteration, loss:0.540
#  num 29 epoch
# ####### Training Loss #######
# [0.49038182]
# Checking accuracy on validation set
# Got 800 / 1000 correct (80.00)
# 31 epoch,  1000 iteration, loss:0.457
# Checking accuracy on validation set
# Got 790 / 1000 correct (79.00)
# 31 epoch,  2000 iteration, loss:0.466
# Checking accuracy on validation set
# Got 781 / 1000 correct (78.10)
# 31 epoch,  3000 iteration, loss:0.465
# Checking accuracy on validation set
# Got 796 / 1000 correct (79.60)
# 31 epoch,  4000 iteration, loss:0.483
# Checking accuracy on validation set
# Got 788 / 1000 correct (78.80)
# 31 epoch,  5000 iteration, loss:0.480
# Checking accuracy on validation set
# Got 792 / 1000 correct (79.20)
# 31 epoch,  6000 iteration, loss:0.483
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
# 31 epoch,  7000 iteration, loss:0.519
# Checking accuracy on validation set
# Got 789 / 1000 correct (78.90)
# 31 epoch,  8000 iteration, loss:0.497
# Checking accuracy on validation set
# Got 788 / 1000 correct (78.80)
# 31 epoch,  9000 iteration, loss:0.505
# Checking accuracy on validation set
# Got 798 / 1000 correct (79.80)
# 31 epoch, 10000 iteration, loss:0.511
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
# 31 epoch, 11000 iteration, loss:0.523
# Checking accuracy on validation set
# Got 811 / 1000 correct (81.10)
# 31 epoch, 12000 iteration, loss:0.519
#  num 30 epoch
# ####### Training Loss #######
# [0.4819584]
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
# 32 epoch,  1000 iteration, loss:0.438
# Checking accuracy on validation set
# Got 799 / 1000 correct (79.90)
# 32 epoch,  2000 iteration, loss:0.475
# Checking accuracy on validation set
# Got 807 / 1000 correct (80.70)
# 32 epoch,  3000 iteration, loss:0.476
# Checking accuracy on validation set
# Got 786 / 1000 correct (78.60)
# 32 epoch,  4000 iteration, loss:0.496
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
# 32 epoch,  5000 iteration, loss:0.479
# Checking accuracy on validation set
# Got 787 / 1000 correct (78.70)
# 32 epoch,  6000 iteration, loss:0.478
# Checking accuracy on validation set
# Got 793 / 1000 correct (79.30)
# 32 epoch,  7000 iteration, loss:0.519
# Checking accuracy on validation set
# Got 776 / 1000 correct (77.60)
# 32 epoch,  8000 iteration, loss:0.490
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
# 32 epoch,  9000 iteration, loss:0.515
# Checking accuracy on validation set
# Got 825 / 1000 correct (82.50)
# 32 epoch, 10000 iteration, loss:0.524
# Checking accuracy on validation set
# Got 789 / 1000 correct (78.90)
# 32 epoch, 11000 iteration, loss:0.519
# Checking accuracy on validation set
# Got 800 / 1000 correct (80.00)
# 32 epoch, 12000 iteration, loss:0.526
#  num 31 epoch
# ####### Training Loss #######
# [0.48505923]
# Checking accuracy on validation set
# Got 764 / 1000 correct (76.40)
# 33 epoch,  1000 iteration, loss:0.427
# Checking accuracy on validation set
# Got 801 / 1000 correct (80.10)
# 33 epoch,  2000 iteration, loss:0.456
# Checking accuracy on validation set
# Got 810 / 1000 correct (81.00)
# 33 epoch,  3000 iteration, loss:0.455
# Checking accuracy on validation set
# Got 786 / 1000 correct (78.60)
# 33 epoch,  4000 iteration, loss:0.442
# Checking accuracy on validation set
# Got 779 / 1000 correct (77.90)
# 33 epoch,  5000 iteration, loss:0.463
# Checking accuracy on validation set
# Got 794 / 1000 correct (79.40)
# 33 epoch,  6000 iteration, loss:0.488
# Checking accuracy on validation set
# Got 773 / 1000 correct (77.30)
# 33 epoch,  7000 iteration, loss:0.503
# Checking accuracy on validation set
# Got 796 / 1000 correct (79.60)
# 33 epoch,  8000 iteration, loss:0.478
# Checking accuracy on validation set
# Got 790 / 1000 correct (79.00)
# 33 epoch,  9000 iteration, loss:0.499
# Checking accuracy on validation set
# Got 803 / 1000 correct (80.30)
# 33 epoch, 10000 iteration, loss:0.506
# Checking accuracy on validation set
# Got 813 / 1000 correct (81.30)
# 33 epoch, 11000 iteration, loss:0.494
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
# 33 epoch, 12000 iteration, loss:0.536
#  num 32 epoch
# ####### Training Loss #######
# [0.46953256]
# Checking accuracy on validation set
# Got 780 / 1000 correct (78.00)
# 34 epoch,  1000 iteration, loss:0.454
# Checking accuracy on validation set
# Got 792 / 1000 correct (79.20)
# 34 epoch,  2000 iteration, loss:0.416
# Checking accuracy on validation set
# Got 789 / 1000 correct (78.90)
# 34 epoch,  3000 iteration, loss:0.458
# Checking accuracy on validation set
# Got 792 / 1000 correct (79.20)
# 34 epoch,  4000 iteration, loss:0.467
# Checking accuracy on validation set
# Got 791 / 1000 correct (79.10)
# 34 epoch,  5000 iteration, loss:0.491
# Checking accuracy on validation set
# Got 778 / 1000 correct (77.80)
# 34 epoch,  6000 iteration, loss:0.469
# Checking accuracy on validation set
# Got 767 / 1000 correct (76.70)
# 34 epoch,  7000 iteration, loss:0.491
# Checking accuracy on validation set
# Got 783 / 1000 correct (78.30)
# 34 epoch,  8000 iteration, loss:0.485
# Checking accuracy on validation set
# Got 791 / 1000 correct (79.10)
# 34 epoch,  9000 iteration, loss:0.513
# Checking accuracy on validation set
# Got 801 / 1000 correct (80.10)
# 34 epoch, 10000 iteration, loss:0.484
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
# 34 epoch, 11000 iteration, loss:0.513
# Checking accuracy on validation set
# Got 801 / 1000 correct (80.10)
# 34 epoch, 12000 iteration, loss:0.503
#  num 33 epoch
# ####### Training Loss #######
# [0.47054046]
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
# 35 epoch,  1000 iteration, loss:0.436
# Checking accuracy on validation set
# Got 807 / 1000 correct (80.70)
# 35 epoch,  2000 iteration, loss:0.461
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
# 35 epoch,  3000 iteration, loss:0.464
# Checking accuracy on validation set
# Got 796 / 1000 correct (79.60)
# 35 epoch,  4000 iteration, loss:0.467
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
# 35 epoch,  5000 iteration, loss:0.445
# Checking accuracy on validation set
# Got 784 / 1000 correct (78.40)
# 35 epoch,  6000 iteration, loss:0.487
# Checking accuracy on validation set
# Got 806 / 1000 correct (80.60)
# 35 epoch,  7000 iteration, loss:0.483
# Checking accuracy on validation set
# Got 805 / 1000 correct (80.50)
# 35 epoch,  8000 iteration, loss:0.478
# Checking accuracy on validation set
# Got 768 / 1000 correct (76.80)
# 35 epoch,  9000 iteration, loss:0.487
# Checking accuracy on validation set
# Got 790 / 1000 correct (79.00)
# 35 epoch, 10000 iteration, loss:0.504
# Checking accuracy on validation set
# Got 780 / 1000 correct (78.00)
# 35 epoch, 11000 iteration, loss:0.498
# Checking accuracy on validation set
# Got 779 / 1000 correct (77.90)
# 35 epoch, 12000 iteration, loss:0.519
#  num 34 epoch
# ####### Training Loss #######
# [0.46855889]
# Checking accuracy on validation set
# Got 819 / 1000 correct (81.90)
# 36 epoch,  1000 iteration, loss:0.446
# Checking accuracy on validation set
# Got 788 / 1000 correct (78.80)
# 36 epoch,  2000 iteration, loss:0.428
# Checking accuracy on validation set
# Got 802 / 1000 correct (80.20)
# 36 epoch,  3000 iteration, loss:0.451
# Checking accuracy on validation set
# Got 782 / 1000 correct (78.20)
# 36 epoch,  4000 iteration, loss:0.476
# Checking accuracy on validation set
# Got 792 / 1000 correct (79.20)
# 36 epoch,  5000 iteration, loss:0.470
# Checking accuracy on validation set
# Got 805 / 1000 correct (80.50)
# 36 epoch,  6000 iteration, loss:0.482
# Checking accuracy on validation set
# Got 786 / 1000 correct (78.60)
# 36 epoch,  7000 iteration, loss:0.462
# Checking accuracy on validation set
# Got 799 / 1000 correct (79.90)
# 36 epoch,  8000 iteration, loss:0.486
# Checking accuracy on validation set
# Got 779 / 1000 correct (77.90)
# 36 epoch,  9000 iteration, loss:0.492
# Checking accuracy on validation set
# Got 779 / 1000 correct (77.90)
# 36 epoch, 10000 iteration, loss:0.487
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
# 36 epoch, 11000 iteration, loss:0.471
# Checking accuracy on validation set
# Got 784 / 1000 correct (78.40)
# 36 epoch, 12000 iteration, loss:0.497
#  num 35 epoch
# ####### Training Loss #######
# [0.46181569]
# Checking accuracy on validation set
# Got 806 / 1000 correct (80.60)
# 37 epoch,  1000 iteration, loss:0.451
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
# 37 epoch,  2000 iteration, loss:0.421
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
# 37 epoch,  3000 iteration, loss:0.454
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
# 37 epoch,  4000 iteration, loss:0.454
# Checking accuracy on validation set
# Got 792 / 1000 correct (79.20)
# 37 epoch,  5000 iteration, loss:0.502
# Checking accuracy on validation set
# Got 801 / 1000 correct (80.10)
# 37 epoch,  6000 iteration, loss:0.458
# ...
# Checking accuracy on validation set
# Got 802 / 1000 correct (80.20)
# 341 epoch,  7000 iteration, loss:0.404
# Checking accuracy on validation set
# Got 807 / 1000 correct (80.70)
# 341 epoch,  8000 iteration, loss:0.371
# Checking accuracy on validation set
# Got 803 / 1000 correct (80.30)
# 341 epoch,  9000 iteration, loss:0.389
# Checking accuracy on validation set
# Got 805 / 1000 correct (80.50)
# 341 epoch, 10000 iteration, loss:0.401
# Checking accuracy on validation set
# Got 799 / 1000 correct (79.90)
# 341 epoch, 11000 iteration, loss:0.411
# Checking accuracy on validation set
# Got 798 / 1000 correct (79.80)
# 341 epoch, 12000 iteration, loss:0.417
#  num 340 epoch
# ####### Training Loss #######
# [0.3714364]
# Checking accuracy on validation set
# Got 800 / 1000 correct (80.00)
# 342 epoch,  1000 iteration, loss:0.327
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
# 342 epoch,  2000 iteration, loss:0.339
# Checking accuracy on validation set
# Got 801 / 1000 correct (80.10)
# 342 epoch,  3000 iteration, loss:0.372
# Checking accuracy on validation set
# Got 800 / 1000 correct (80.00)
# 342 epoch,  4000 iteration, loss:0.394
# Checking accuracy on validation set
# Got 806 / 1000 correct (80.60)
# 342 epoch,  5000 iteration, loss:0.367
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
# 342 epoch,  6000 iteration, loss:0.381
# Checking accuracy on validation set
# Got 794 / 1000 correct (79.40)
# 342 epoch,  7000 iteration, loss:0.400
# Checking accuracy on validation set
# Got 792 / 1000 correct (79.20)
# 342 epoch,  8000 iteration, loss:0.388
# Checking accuracy on validation set
# Got 807 / 1000 correct (80.70)
# 342 epoch,  9000 iteration, loss:0.386
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
# 342 epoch, 10000 iteration, loss:0.405
# Checking accuracy on validation set
# Got 789 / 1000 correct (78.90)
# 342 epoch, 11000 iteration, loss:0.397
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
# 342 epoch, 12000 iteration, loss:0.402
#  num 341 epoch
# ####### Training Loss #######
# [0.37307854]
# Checking accuracy on validation set
# Got 805 / 1000 correct (80.50)
# 343 epoch,  1000 iteration, loss:0.332
# Checking accuracy on validation set
# Got 798 / 1000 correct (79.80)
# 343 epoch,  2000 iteration, loss:0.362
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
# 343 epoch,  3000 iteration, loss:0.354
# Checking accuracy on validation set
# Got 799 / 1000 correct (79.90)
# 343 epoch,  4000 iteration, loss:0.364
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
# 343 epoch,  5000 iteration, loss:0.364
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
# 343 epoch,  6000 iteration, loss:0.398
# Checking accuracy on validation set
# Got 783 / 1000 correct (78.30)
# 343 epoch,  7000 iteration, loss:0.386
# Checking accuracy on validation set
# Got 783 / 1000 correct (78.30)
# 343 epoch,  8000 iteration, loss:0.416
# Checking accuracy on validation set
# Got 802 / 1000 correct (80.20)
# 343 epoch,  9000 iteration, loss:0.380
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
# 343 epoch, 10000 iteration, loss:0.406
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
# 343 epoch, 11000 iteration, loss:0.384
# Checking accuracy on validation set
# Got 828 / 1000 correct (82.80)
# 343 epoch, 12000 iteration, loss:0.425
#  num 342 epoch
# ####### Training Loss #######
# [0.37413828]
# Checking accuracy on validation set
# Got 817 / 1000 correct (81.70)
# 344 epoch,  1000 iteration, loss:0.322
# Checking accuracy on validation set
# Got 819 / 1000 correct (81.90)
# 344 epoch,  2000 iteration, loss:0.352
# Checking accuracy on validation set
# Got 816 / 1000 correct (81.60)
# 344 epoch,  3000 iteration, loss:0.359
# Checking accuracy on validation set
# Got 817 / 1000 correct (81.70)
# 344 epoch,  4000 iteration, loss:0.351
# Checking accuracy on validation set
# Got 799 / 1000 correct (79.90)
# 344 epoch,  5000 iteration, loss:0.363
# Checking accuracy on validation set
# Got 783 / 1000 correct (78.30)
# 344 epoch,  6000 iteration, loss:0.379
# Checking accuracy on validation set
# Got 810 / 1000 correct (81.00)
# 344 epoch,  7000 iteration, loss:0.387
# Checking accuracy on validation set
# Got 773 / 1000 correct (77.30)
# 344 epoch,  8000 iteration, loss:0.418
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
# 344 epoch,  9000 iteration, loss:0.400
# Checking accuracy on validation set
# Got 806 / 1000 correct (80.60)
# 344 epoch, 10000 iteration, loss:0.392
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
# 344 epoch, 11000 iteration, loss:0.399
# Checking accuracy on validation set
# Got 789 / 1000 correct (78.90)
# 344 epoch, 12000 iteration, loss:0.412
#  num 343 epoch
# ####### Training Loss #######
# [0.37111636]
# Checking accuracy on validation set
# Got 805 / 1000 correct (80.50)
# 345 epoch,  1000 iteration, loss:0.323
# Checking accuracy on validation set
# Got 825 / 1000 correct (82.50)
# 345 epoch,  2000 iteration, loss:0.353
# Checking accuracy on validation set
# Got 824 / 1000 correct (82.40)
# 345 epoch,  3000 iteration, loss:0.350
# Checking accuracy on validation set
# Got 807 / 1000 correct (80.70)
# 345 epoch,  4000 iteration, loss:0.368
# Checking accuracy on validation set
# Got 799 / 1000 correct (79.90)
# 345 epoch,  5000 iteration, loss:0.378
# Checking accuracy on validation set
# Got 806 / 1000 correct (80.60)
# 345 epoch,  6000 iteration, loss:0.384
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
# 345 epoch,  7000 iteration, loss:0.395
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
# 345 epoch,  8000 iteration, loss:0.378
# Checking accuracy on validation set
# Got 803 / 1000 correct (80.30)
# 345 epoch,  9000 iteration, loss:0.398
# Checking accuracy on validation set
# Got 787 / 1000 correct (78.70)
# 345 epoch, 10000 iteration, loss:0.409
# Checking accuracy on validation set
# Got 805 / 1000 correct (80.50)
# 345 epoch, 11000 iteration, loss:0.416
# Checking accuracy on validation set
# Got 801 / 1000 correct (80.10)
# 345 epoch, 12000 iteration, loss:0.410
#  num 344 epoch
# ####### Training Loss #######
# [0.37430691]
# Checking accuracy on validation set
# Got 833 / 1000 correct (83.30)
# 346 epoch,  1000 iteration, loss:0.337
# Checking accuracy on validation set
# Got 803 / 1000 correct (80.30)
# 346 epoch,  2000 iteration, loss:0.355
# Checking accuracy on validation set
# Got 815 / 1000 correct (81.50)
# 346 epoch,  3000 iteration, loss:0.365
# Checking accuracy on validation set
# Got 801 / 1000 correct (80.10)
# 346 epoch,  4000 iteration, loss:0.359
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
# 346 epoch,  5000 iteration, loss:0.381
# Checking accuracy on validation set
# Got 805 / 1000 correct (80.50)
# 346 epoch,  6000 iteration, loss:0.379
# Checking accuracy on validation set
# Got 817 / 1000 correct (81.70)
# 346 epoch,  7000 iteration, loss:0.365
# Checking accuracy on validation set
# Got 805 / 1000 correct (80.50)
# 346 epoch,  8000 iteration, loss:0.388
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
# 346 epoch,  9000 iteration, loss:0.384
# Checking accuracy on validation set
# Got 762 / 1000 correct (76.20)
# 346 epoch, 10000 iteration, loss:0.396
# Checking accuracy on validation set
# Got 805 / 1000 correct (80.50)
# 346 epoch, 11000 iteration, loss:0.424
# Checking accuracy on validation set
# Got 786 / 1000 correct (78.60)
# 346 epoch, 12000 iteration, loss:0.421
#  num 345 epoch
# ####### Training Loss #######
# [0.37173162]
# Checking accuracy on validation set
# Got 807 / 1000 correct (80.70)
# 347 epoch,  1000 iteration, loss:0.320
# Checking accuracy on validation set
# Got 807 / 1000 correct (80.70)
# 347 epoch,  2000 iteration, loss:0.362
# Checking accuracy on validation set
# Got 813 / 1000 correct (81.30)
# 347 epoch,  3000 iteration, loss:0.350
# Checking accuracy on validation set
# Got 792 / 1000 correct (79.20)
# 347 epoch,  4000 iteration, loss:0.386
# Checking accuracy on validation set
# Got 805 / 1000 correct (80.50)
# 347 epoch,  5000 iteration, loss:0.374
# Checking accuracy on validation set
# Got 807 / 1000 correct (80.70)
# 347 epoch,  6000 iteration, loss:0.379
# Checking accuracy on validation set
# Got 790 / 1000 correct (79.00)
# 347 epoch,  7000 iteration, loss:0.388
# Checking accuracy on validation set
# Got 785 / 1000 correct (78.50)
# 347 epoch,  8000 iteration, loss:0.391
# Checking accuracy on validation set
# Got 802 / 1000 correct (80.20)
# 347 epoch,  9000 iteration, loss:0.413
# Checking accuracy on validation set
# Got 811 / 1000 correct (81.10)
# 347 epoch, 10000 iteration, loss:0.405
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
# 347 epoch, 11000 iteration, loss:0.404
# Checking accuracy on validation set
# Got 802 / 1000 correct (80.20)
# 347 epoch, 12000 iteration, loss:0.395
#  num 346 epoch
# ####### Training Loss #######
# [0.37304733]
# Checking accuracy on validation set
# Got 799 / 1000 correct (79.90)
# 348 epoch,  1000 iteration, loss:0.331
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
# 348 epoch,  2000 iteration, loss:0.355
# Checking accuracy on validation set
# Got 818 / 1000 correct (81.80)
# 348 epoch,  3000 iteration, loss:0.350
# Checking accuracy on validation set
# Got 787 / 1000 correct (78.70)
# 348 epoch,  4000 iteration, loss:0.351
# Checking accuracy on validation set
# Got 782 / 1000 correct (78.20)
# 348 epoch,  5000 iteration, loss:0.366
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
# 348 epoch,  6000 iteration, loss:0.368
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
# 348 epoch,  7000 iteration, loss:0.381
# Checking accuracy on validation set
# Got 813 / 1000 correct (81.30)
# 348 epoch,  8000 iteration, loss:0.399
# Checking accuracy on validation set
# Got 803 / 1000 correct (80.30)
# 348 epoch,  9000 iteration, loss:0.406
# Checking accuracy on validation set
# Got 806 / 1000 correct (80.60)
# 348 epoch, 10000 iteration, loss:0.400
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
# 348 epoch, 11000 iteration, loss:0.405
# Checking accuracy on validation set
# Got 815 / 1000 correct (81.50)
# 348 epoch, 12000 iteration, loss:0.411
#  num 347 epoch
# ####### Training Loss #######
# [0.36914493]
# Checking accuracy on validation set
# Got 800 / 1000 correct (80.00)
# 349 epoch,  1000 iteration, loss:0.336
# Checking accuracy on validation set
# Got 820 / 1000 correct (82.00)
# 349 epoch,  2000 iteration, loss:0.336
# Checking accuracy on validation set
# Got 810 / 1000 correct (81.00)
# 349 epoch,  3000 iteration, loss:0.356
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
# 349 epoch,  4000 iteration, loss:0.343
# Checking accuracy on validation set
# Got 810 / 1000 correct (81.00)
# 349 epoch,  5000 iteration, loss:0.345
# Checking accuracy on validation set
# Got 801 / 1000 correct (80.10)
# 349 epoch,  6000 iteration, loss:0.378
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
# 349 epoch,  7000 iteration, loss:0.391
# Checking accuracy on validation set
# Got 817 / 1000 correct (81.70)
# 349 epoch,  8000 iteration, loss:0.401
# Checking accuracy on validation set
# Got 822 / 1000 correct (82.20)
# 349 epoch,  9000 iteration, loss:0.400
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
# 349 epoch, 10000 iteration, loss:0.418
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
# 349 epoch, 11000 iteration, loss:0.409
# Checking accuracy on validation set
# Got 790 / 1000 correct (79.00)
# 349 epoch, 12000 iteration, loss:0.419
#  num 348 epoch
# ####### Training Loss #######
# [0.37071893]
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
# 350 epoch,  1000 iteration, loss:0.343
# Checking accuracy on validation set
# Got 796 / 1000 correct (79.60)
# 350 epoch,  2000 iteration, loss:0.350
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
# 350 epoch,  3000 iteration, loss:0.355
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
# 350 epoch,  4000 iteration, loss:0.368
# Checking accuracy on validation set
# Got 784 / 1000 correct (78.40)
# 350 epoch,  5000 iteration, loss:0.364
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
# 350 epoch,  6000 iteration, loss:0.379
# Checking accuracy on validation set
# Got 801 / 1000 correct (80.10)
# 350 epoch,  7000 iteration, loss:0.390
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
# 350 epoch,  8000 iteration, loss:0.403
# Checking accuracy on validation set
# Got 800 / 1000 correct (80.00)
# 350 epoch,  9000 iteration, loss:0.426
# Checking accuracy on validation set
# Got 813 / 1000 correct (81.30)
# 350 epoch, 10000 iteration, loss:0.409
# Checking accuracy on validation set
# Got 811 / 1000 correct (81.10)
# 350 epoch, 11000 iteration, loss:0.384
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
# 350 epoch, 12000 iteration, loss:0.406
#  num 349 epoch
# ####### Training Loss #######
# [0.37420765]
# finish training
#
# Checking accuracy on test set
# Got 8005 / 10000 correct (80.05)
# #####################################
# Accuracy on testing set 8005.00
# #####################################
# now begin saving datum for next step plotting
# now plotting accuracies and losses
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-7b349f2888bd> in <module>()
#       7
#       8 ALL_CNN_A = help_func.running_model(run_num, ALL_CNN_A, net_name, lr, epoch,
# ----> 9                         loader_train, loader_val, loader_test)
#
# ~/DL_course/midterm-Quant95/Nets/help_func.py in running_model(run_num, net, net_name, lr_list, epoch_list, loader_train, loader_val, loader_test)
#     271     a /= 100
#     272     length = a.shape[0]
# --> 273     acc_axis_test = np.array(np.linspace(1,length, num=max_epoch))
#     274     plt.plot(acc_axis_test, a.reshape(-1,1), '--r', label='Test')
#     275     plt.xlabel('iteration')
#
# ~/Anacondas/anaconda3/envs/cs231n/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2747 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
#    2748     return gca().plot(
# -> 2749         *args, scalex=scalex, scaley=scaley, data=data, **kwargs)
#    2750
#    2751 # Autogenerated by boilerplate.py.  Do not edit as changes will be lost.
#
# ~/Anacondas/anaconda3/envs/cs231n/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1783                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1784                         RuntimeWarning, stacklevel=2)
# -> 1785             return func(ax, *args, **kwargs)
#    1786
#    1787         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/Anacondas/anaconda3/envs/cs231n/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, *args, **kwargs)
#    1602         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
#    1603
# -> 1604         for line in self._get_lines(*args, **kwargs):
#    1605             self.add_line(line)
#    1606             lines.append(line)
#
# ~/Anacondas/anaconda3/envs/cs231n/lib/python3.6/site-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     391                 this += args[0],
#     392                 args = args[1:]
# --> 393             yield from self._plot_args(this, kwargs)
#     394
#     395
#
# ~/Anacondas/anaconda3/envs/cs231n/lib/python3.6/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     368             x, y = index_of(tup[-1])
#     369
# --> 370         x, y = self._xy_from_xy(x, y)
#     371
#     372         if self.command == 'plot':
#
# ~/Anacondas/anaconda3/envs/cs231n/lib/python3.6/site-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     229         if x.shape[0] != y.shape[0]:
#     230             raise ValueError("x and y must have same first dimension, but "
# --> 231                              "have shapes {} and {}".format(x.shape, y.shape))
#     232         if x.ndim > 2 or y.ndim > 2:
#     233             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (350,) and (4200, 1)
