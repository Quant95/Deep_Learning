# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F 
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.autograd import Variable
from torch.utils.data import sampler

import help_func
import new_ALL_Conv
# Out:
# finish
# right

# %%
train_batch_size = 4
test_batch_size = 4

NUM_TRAIN = 49000

transform = transforms.Compose(
          [transforms.ToTensor(),
           transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))])

cifar10_train = torchvision.datasets.CIFAR10('./cs231n/datasets', train=True, download=True,
                             transform=transform)
loader_train = torch.utils.data.DataLoader(cifar10_train, batch_size=train_batch_size, 
                          sampler=sampler.SubsetRandomSampler(range(NUM_TRAIN)))

cifar10_val = torchvision.datasets.CIFAR10('./cs231n/datasets', train=True, download=True,
                           transform=transform)
loader_val = torch.utils.data.DataLoader(cifar10_val, batch_size=train_batch_size, 
                        sampler=sampler.SubsetRandomSampler(range(NUM_TRAIN, 50000)))

cifar10_test = torchvision.datasets.CIFAR10('./cs231n/datasets', train=False, download=True, 
                            transform=transform)
loader_test = torch.utils.data.DataLoader(cifar10_test, batch_size=test_batch_size)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %%
ALL_CNN_B = new_ALL_Conv.ALL_CNN_B()

# %%
#lr = [0.025, 0.01, 0.005, 0.001] 
lr = [0.1, 0.05, 0.01, 0.001]
epoch = [200, 250, 300]
run_num = 50
net_name = 'ALL_CNN_B'

#torch.cuda.set_device(2)

ALL_CNN_B = help_func.running_model(run_num, ALL_CNN_B, net_name, lr, epoch, 
                        loader_train, loader_val, loader_test)
# Out:
# using device: cuda
# begin training
# Checking accuracy on validation set
# Got 106 / 1000 correct (10.60)
# 1 epoch,  1000 iteration, loss:2.301
# Checking accuracy on validation set
# Got 152 / 1000 correct (15.20)
# 1 epoch,  2000 iteration, loss:2.294
# Checking accuracy on validation set
# Got 234 / 1000 correct (23.40)
# 1 epoch,  3000 iteration, loss:2.243
# Checking accuracy on validation set
# Got 241 / 1000 correct (24.10)
# 1 epoch,  4000 iteration, loss:2.114
# Checking accuracy on validation set
# Got 280 / 1000 correct (28.00)
# 1 epoch,  5000 iteration, loss:2.031
# Checking accuracy on validation set
# Got 358 / 1000 correct (35.80)
# 1 epoch,  6000 iteration, loss:1.945
# Checking accuracy on validation set
# Got 378 / 1000 correct (37.80)
# 1 epoch,  7000 iteration, loss:1.847
# Checking accuracy on validation set
# Got 369 / 1000 correct (36.90)
# 1 epoch,  8000 iteration, loss:1.796
# Checking accuracy on validation set
# Got 425 / 1000 correct (42.50)
# 1 epoch,  9000 iteration, loss:1.793
# Checking accuracy on validation set
# Got 436 / 1000 correct (43.60)
# 1 epoch, 10000 iteration, loss:1.689
# Checking accuracy on validation set
# Got 420 / 1000 correct (42.00)
# 1 epoch, 11000 iteration, loss:1.686
# Checking accuracy on validation set
# Got 449 / 1000 correct (44.90)
# 1 epoch, 12000 iteration, loss:1.666
#  num 0 epoch
# ####### Training Loss #######
# [1.90512671]
# Checking accuracy on validation set
# Got 436 / 1000 correct (43.60)
# 2 epoch,  1000 iteration, loss:1.609
# Checking accuracy on validation set
# Got 455 / 1000 correct (45.50)
# 2 epoch,  2000 iteration, loss:1.586
# Checking accuracy on validation set
# Got 473 / 1000 correct (47.30)
# 2 epoch,  3000 iteration, loss:1.567
# Checking accuracy on validation set
# Got 488 / 1000 correct (48.80)
# 2 epoch,  4000 iteration, loss:1.528
# Checking accuracy on validation set
# Got 481 / 1000 correct (48.10)
# 2 epoch,  5000 iteration, loss:1.537
# Checking accuracy on validation set
# Got 463 / 1000 correct (46.30)
# 2 epoch,  6000 iteration, loss:1.517
# Checking accuracy on validation set
# Got 488 / 1000 correct (48.80)
# 2 epoch,  7000 iteration, loss:1.497
# Checking accuracy on validation set
# Got 465 / 1000 correct (46.50)
# 2 epoch,  8000 iteration, loss:1.498
# Checking accuracy on validation set
# Got 501 / 1000 correct (50.10)
# 2 epoch,  9000 iteration, loss:1.506
# Checking accuracy on validation set
# Got 513 / 1000 correct (51.30)
# 2 epoch, 10000 iteration, loss:1.459
# Checking accuracy on validation set
# Got 522 / 1000 correct (52.20)
# 2 epoch, 11000 iteration, loss:1.456
# Checking accuracy on validation set
# Got 499 / 1000 correct (49.90)
# 2 epoch, 12000 iteration, loss:1.418
#  num 1 epoch
# ####### Training Loss #######
# [1.48192953]
# Checking accuracy on validation set
# Got 544 / 1000 correct (54.40)
# 3 epoch,  1000 iteration, loss:1.395
# Checking accuracy on validation set
# Got 513 / 1000 correct (51.30)
# 3 epoch,  2000 iteration, loss:1.360
# Checking accuracy on validation set
# Got 530 / 1000 correct (53.00)
# 3 epoch,  3000 iteration, loss:1.372
# Checking accuracy on validation set
# Got 554 / 1000 correct (55.40)
# 3 epoch,  4000 iteration, loss:1.391
# Checking accuracy on validation set
# Got 547 / 1000 correct (54.70)
# 3 epoch,  5000 iteration, loss:1.367
# Checking accuracy on validation set
# Got 553 / 1000 correct (55.30)
# 3 epoch,  6000 iteration, loss:1.302
# Checking accuracy on validation set
# Got 545 / 1000 correct (54.50)
# 3 epoch,  7000 iteration, loss:1.309
# Checking accuracy on validation set
# Got 548 / 1000 correct (54.80)
# 3 epoch,  8000 iteration, loss:1.302
# Checking accuracy on validation set
# Got 558 / 1000 correct (55.80)
# 3 epoch,  9000 iteration, loss:1.309
# Checking accuracy on validation set
# Got 565 / 1000 correct (56.50)
# 3 epoch, 10000 iteration, loss:1.307
# Checking accuracy on validation set
# Got 578 / 1000 correct (57.80)
# 3 epoch, 11000 iteration, loss:1.288
# Checking accuracy on validation set
# Got 598 / 1000 correct (59.80)
# 3 epoch, 12000 iteration, loss:1.281
#  num 2 epoch
# ####### Training Loss #######
# [1.30420888]
# Checking accuracy on validation set
# Got 547 / 1000 correct (54.70)
# 4 epoch,  1000 iteration, loss:1.240
# Checking accuracy on validation set
# Got 576 / 1000 correct (57.60)
# 4 epoch,  2000 iteration, loss:1.211
# Checking accuracy on validation set
# Got 607 / 1000 correct (60.70)
# 4 epoch,  3000 iteration, loss:1.213
# Checking accuracy on validation set
# Got 636 / 1000 correct (63.60)
# 4 epoch,  4000 iteration, loss:1.210
# Checking accuracy on validation set
# Got 600 / 1000 correct (60.00)
# 4 epoch,  5000 iteration, loss:1.228
# Checking accuracy on validation set
# Got 601 / 1000 correct (60.10)
# 4 epoch,  6000 iteration, loss:1.186
# Checking accuracy on validation set
# Got 579 / 1000 correct (57.90)
# 4 epoch,  7000 iteration, loss:1.218
# Checking accuracy on validation set
# Got 604 / 1000 correct (60.40)
# 4 epoch,  8000 iteration, loss:1.183
# Checking accuracy on validation set
# Got 597 / 1000 correct (59.70)
# 4 epoch,  9000 iteration, loss:1.179
# Checking accuracy on validation set
# Got 613 / 1000 correct (61.30)
# 4 epoch, 10000 iteration, loss:1.162
# Checking accuracy on validation set
# Got 646 / 1000 correct (64.60)
# 4 epoch, 11000 iteration, loss:1.163
# Checking accuracy on validation set
# Got 630 / 1000 correct (63.00)
# 4 epoch, 12000 iteration, loss:1.174
#  num 3 epoch
# ####### Training Loss #######
# [1.17179259]
# Checking accuracy on validation set
# Got 640 / 1000 correct (64.00)
# 5 epoch,  1000 iteration, loss:1.141
# Checking accuracy on validation set
# Got 636 / 1000 correct (63.60)
# 5 epoch,  2000 iteration, loss:1.125
# Checking accuracy on validation set
# Got 643 / 1000 correct (64.30)
# 5 epoch,  3000 iteration, loss:1.086
# Checking accuracy on validation set
# Got 652 / 1000 correct (65.20)
# 5 epoch,  4000 iteration, loss:1.085
# Checking accuracy on validation set
# Got 632 / 1000 correct (63.20)
# 5 epoch,  5000 iteration, loss:1.088
# Checking accuracy on validation set
# Got 671 / 1000 correct (67.10)
# 5 epoch,  6000 iteration, loss:1.097
# Checking accuracy on validation set
# Got 619 / 1000 correct (61.90)
# 5 epoch,  7000 iteration, loss:1.097
# Checking accuracy on validation set
# Got 629 / 1000 correct (62.90)
# 5 epoch,  8000 iteration, loss:1.080
# Checking accuracy on validation set
# Got 651 / 1000 correct (65.10)
# 5 epoch,  9000 iteration, loss:1.077
# Checking accuracy on validation set
# Got 675 / 1000 correct (67.50)
# 5 epoch, 10000 iteration, loss:1.096
# Checking accuracy on validation set
# Got 655 / 1000 correct (65.50)
# 5 epoch, 11000 iteration, loss:1.056
# Checking accuracy on validation set
# Got 654 / 1000 correct (65.40)
# 5 epoch, 12000 iteration, loss:1.087
#  num 4 epoch
# ####### Training Loss #######
# [1.06992251]
# Checking accuracy on validation set
# Got 645 / 1000 correct (64.50)
# 6 epoch,  1000 iteration, loss:1.020
# Checking accuracy on validation set
# Got 654 / 1000 correct (65.40)
# 6 epoch,  2000 iteration, loss:1.026
# Checking accuracy on validation set
# Got 668 / 1000 correct (66.80)
# 6 epoch,  3000 iteration, loss:1.002
# Checking accuracy on validation set
# Got 649 / 1000 correct (64.90)
# 6 epoch,  4000 iteration, loss:1.037
# Checking accuracy on validation set
# Got 664 / 1000 correct (66.40)
# 6 epoch,  5000 iteration, loss:0.996
# Checking accuracy on validation set
# Got 674 / 1000 correct (67.40)
# 6 epoch,  6000 iteration, loss:1.014
# Checking accuracy on validation set
# Got 703 / 1000 correct (70.30)
# 6 epoch,  7000 iteration, loss:1.015
# Checking accuracy on validation set
# Got 705 / 1000 correct (70.50)
# 6 epoch,  8000 iteration, loss:0.992
# Checking accuracy on validation set
# Got 660 / 1000 correct (66.00)
# 6 epoch,  9000 iteration, loss:0.993
# Checking accuracy on validation set
# Got 685 / 1000 correct (68.50)
# 6 epoch, 10000 iteration, loss:0.982
# Checking accuracy on validation set
# Got 684 / 1000 correct (68.40)
# 6 epoch, 11000 iteration, loss:0.978
# Checking accuracy on validation set
# Got 663 / 1000 correct (66.30)
# 6 epoch, 12000 iteration, loss:0.970
#  num 5 epoch
# ####### Training Loss #######
# [0.98095328]
# Checking accuracy on validation set
# Got 668 / 1000 correct (66.80)
# 7 epoch,  1000 iteration, loss:0.949
# Checking accuracy on validation set
# Got 703 / 1000 correct (70.30)
# 7 epoch,  2000 iteration, loss:0.926
# Checking accuracy on validation set
# Got 671 / 1000 correct (67.10)
# 7 epoch,  3000 iteration, loss:0.940
# Checking accuracy on validation set
# Got 671 / 1000 correct (67.10)
# 7 epoch,  4000 iteration, loss:0.916
# Checking accuracy on validation set
# Got 679 / 1000 correct (67.90)
# 7 epoch,  5000 iteration, loss:0.916
# Checking accuracy on validation set
# Got 703 / 1000 correct (70.30)
# 7 epoch,  6000 iteration, loss:0.916
# Checking accuracy on validation set
# Got 670 / 1000 correct (67.00)
# 7 epoch,  7000 iteration, loss:0.942
# Checking accuracy on validation set
# Got 697 / 1000 correct (69.70)
# 7 epoch,  8000 iteration, loss:0.907
# Checking accuracy on validation set
# Got 709 / 1000 correct (70.90)
# 7 epoch,  9000 iteration, loss:0.929
# Checking accuracy on validation set
# Got 709 / 1000 correct (70.90)
# 7 epoch, 10000 iteration, loss:0.893
# Checking accuracy on validation set
# Got 687 / 1000 correct (68.70)
# 7 epoch, 11000 iteration, loss:0.911
# Checking accuracy on validation set
# Got 689 / 1000 correct (68.90)
# 7 epoch, 12000 iteration, loss:0.928
#  num 6 epoch
# ####### Training Loss #######
# [0.90368516]
# Checking accuracy on validation set
# Got 700 / 1000 correct (70.00)
# 8 epoch,  1000 iteration, loss:0.853
# Checking accuracy on validation set
# Got 669 / 1000 correct (66.90)
# 8 epoch,  2000 iteration, loss:0.877
# Checking accuracy on validation set
# Got 711 / 1000 correct (71.10)
# 8 epoch,  3000 iteration, loss:0.877
# Checking accuracy on validation set
# Got 687 / 1000 correct (68.70)
# 8 epoch,  4000 iteration, loss:0.859
# Checking accuracy on validation set
# Got 726 / 1000 correct (72.60)
# 8 epoch,  5000 iteration, loss:0.870
# Checking accuracy on validation set
# Got 718 / 1000 correct (71.80)
# 8 epoch,  6000 iteration, loss:0.873
# Checking accuracy on validation set
# Got 713 / 1000 correct (71.30)
# 8 epoch,  7000 iteration, loss:0.856
# Checking accuracy on validation set
# Got 722 / 1000 correct (72.20)
# 8 epoch,  8000 iteration, loss:0.902
# Checking accuracy on validation set
# Got 727 / 1000 correct (72.70)
# 8 epoch,  9000 iteration, loss:0.887
# Checking accuracy on validation set
# Got 722 / 1000 correct (72.20)
# 8 epoch, 10000 iteration, loss:0.879
# Checking accuracy on validation set
# Got 721 / 1000 correct (72.10)
# 8 epoch, 11000 iteration, loss:0.852
# Checking accuracy on validation set
# Got 708 / 1000 correct (70.80)
# 8 epoch, 12000 iteration, loss:0.853
#  num 7 epoch
# ####### Training Loss #######
# [0.85234187]
# Checking accuracy on validation set
# Got 722 / 1000 correct (72.20)
# 9 epoch,  1000 iteration, loss:0.800
# Checking accuracy on validation set
# Got 712 / 1000 correct (71.20)
# 9 epoch,  2000 iteration, loss:0.834
# Checking accuracy on validation set
# Got 739 / 1000 correct (73.90)
# 9 epoch,  3000 iteration, loss:0.805
# Checking accuracy on validation set
# Got 739 / 1000 correct (73.90)
# 9 epoch,  4000 iteration, loss:0.837
# Checking accuracy on validation set
# Got 715 / 1000 correct (71.50)
# 9 epoch,  5000 iteration, loss:0.818
# Checking accuracy on validation set
# Got 744 / 1000 correct (74.40)
# 9 epoch,  6000 iteration, loss:0.825
# Checking accuracy on validation set
# Got 737 / 1000 correct (73.70)
# 9 epoch,  7000 iteration, loss:0.810
# Checking accuracy on validation set
# Got 748 / 1000 correct (74.80)
# 9 epoch,  8000 iteration, loss:0.816
# Checking accuracy on validation set
# Got 758 / 1000 correct (75.80)
# 9 epoch,  9000 iteration, loss:0.838
# Checking accuracy on validation set
# Got 732 / 1000 correct (73.20)
# 9 epoch, 10000 iteration, loss:0.789
# Checking accuracy on validation set
# Got 740 / 1000 correct (74.00)
# 9 epoch, 11000 iteration, loss:0.775
# Checking accuracy on validation set
# Got 743 / 1000 correct (74.30)
# 9 epoch, 12000 iteration, loss:0.807
#  num 8 epoch
# ####### Training Loss #######
# [0.79726848]
# Checking accuracy on validation set
# Got 726 / 1000 correct (72.60)
# 10 epoch,  1000 iteration, loss:0.772
# Checking accuracy on validation set
# Got 745 / 1000 correct (74.50)
# 10 epoch,  2000 iteration, loss:0.777
# Checking accuracy on validation set
# Got 760 / 1000 correct (76.00)
# 10 epoch,  3000 iteration, loss:0.752
# Checking accuracy on validation set
# Got 744 / 1000 correct (74.40)
# 10 epoch,  4000 iteration, loss:0.758
# Checking accuracy on validation set
# Got 703 / 1000 correct (70.30)
# 10 epoch,  5000 iteration, loss:0.765
# Checking accuracy on validation set
# Got 754 / 1000 correct (75.40)
# 10 epoch,  6000 iteration, loss:0.761
# Checking accuracy on validation set
# Got 750 / 1000 correct (75.00)
# 10 epoch,  7000 iteration, loss:0.782
# Checking accuracy on validation set
# Got 704 / 1000 correct (70.40)
# 10 epoch,  8000 iteration, loss:0.759
# Checking accuracy on validation set
# Got 737 / 1000 correct (73.70)
# 10 epoch,  9000 iteration, loss:0.777
# Checking accuracy on validation set
# Got 751 / 1000 correct (75.10)
# 10 epoch, 10000 iteration, loss:0.764
# Checking accuracy on validation set
# Got 746 / 1000 correct (74.60)
# 10 epoch, 11000 iteration, loss:0.768
# Checking accuracy on validation set
# Got 721 / 1000 correct (72.10)
# 10 epoch, 12000 iteration, loss:0.775
#  num 9 epoch
# ####### Training Loss #######
# [0.75163995]
# Checking accuracy on validation set
# Got 770 / 1000 correct (77.00)
# 11 epoch,  1000 iteration, loss:0.718
# Checking accuracy on validation set
# Got 754 / 1000 correct (75.40)
# 11 epoch,  2000 iteration, loss:0.724
# Checking accuracy on validation set
# Got 696 / 1000 correct (69.60)
# 11 epoch,  3000 iteration, loss:0.724
# Checking accuracy on validation set
# Got 726 / 1000 correct (72.60)
# 11 epoch,  4000 iteration, loss:0.744
# Checking accuracy on validation set
# Got 775 / 1000 correct (77.50)
# 11 epoch,  5000 iteration, loss:0.749
# Checking accuracy on validation set
# Got 743 / 1000 correct (74.30)
# 11 epoch,  6000 iteration, loss:0.735
# Checking accuracy on validation set
# Got 777 / 1000 correct (77.70)
# 11 epoch,  7000 iteration, loss:0.737
# Checking accuracy on validation set
# Got 759 / 1000 correct (75.90)
# 11 epoch,  8000 iteration, loss:0.711
# Checking accuracy on validation set
# Got 758 / 1000 correct (75.80)
# 11 epoch,  9000 iteration, loss:0.731
# Checking accuracy on validation set
# Got 757 / 1000 correct (75.70)
# 11 epoch, 10000 iteration, loss:0.720
# Checking accuracy on validation set
# Got 764 / 1000 correct (76.40)
# 11 epoch, 11000 iteration, loss:0.749
# Checking accuracy on validation set
# Got 744 / 1000 correct (74.40)
# 11 epoch, 12000 iteration, loss:0.750
#  num 10 epoch
# ####### Training Loss #######
# [0.71888813]
# Checking accuracy on validation set
# Got 764 / 1000 correct (76.40)
# 12 epoch,  1000 iteration, loss:0.708
# Checking accuracy on validation set
# Got 745 / 1000 correct (74.50)
# 12 epoch,  2000 iteration, loss:0.714
# Checking accuracy on validation set
# Got 704 / 1000 correct (70.40)
# 12 epoch,  3000 iteration, loss:0.677
# Checking accuracy on validation set
# Got 759 / 1000 correct (75.90)
# 12 epoch,  4000 iteration, loss:0.674
# Checking accuracy on validation set
# Got 766 / 1000 correct (76.60)
# 12 epoch,  5000 iteration, loss:0.698
# Checking accuracy on validation set
# Got 779 / 1000 correct (77.90)
# 12 epoch,  6000 iteration, loss:0.709
# Checking accuracy on validation set
# Got 775 / 1000 correct (77.50)
# 12 epoch,  7000 iteration, loss:0.705
# Checking accuracy on validation set
# Got 713 / 1000 correct (71.30)
# 12 epoch,  8000 iteration, loss:0.682
# Checking accuracy on validation set
# Got 760 / 1000 correct (76.00)
# 12 epoch,  9000 iteration, loss:0.699
# Checking accuracy on validation set
# Got 778 / 1000 correct (77.80)
# 12 epoch, 10000 iteration, loss:0.699
# Checking accuracy on validation set
# Got 774 / 1000 correct (77.40)
# 12 epoch, 11000 iteration, loss:0.720
# Checking accuracy on validation set
# Got 782 / 1000 correct (78.20)
# 12 epoch, 12000 iteration, loss:0.708
#  num 11 epoch
# ####### Training Loss #######
# [0.68552532]
# Checking accuracy on validation set
# Got 746 / 1000 correct (74.60)
# 13 epoch,  1000 iteration, loss:0.673
# Checking accuracy on validation set
# Got 780 / 1000 correct (78.00)
# 13 epoch,  2000 iteration, loss:0.658
# Checking accuracy on validation set
# Got 787 / 1000 correct (78.70)
# 13 epoch,  3000 iteration, loss:0.645
# Checking accuracy on validation set
# Got 778 / 1000 correct (77.80)
# 13 epoch,  4000 iteration, loss:0.666
# Checking accuracy on validation set
# Got 753 / 1000 correct (75.30)
# 13 epoch,  5000 iteration, loss:0.671
# Checking accuracy on validation set
# Got 780 / 1000 correct (78.00)
# 13 epoch,  6000 iteration, loss:0.680
# Checking accuracy on validation set
# Got 764 / 1000 correct (76.40)
# 13 epoch,  7000 iteration, loss:0.676
# Checking accuracy on validation set
# Got 800 / 1000 correct (80.00)
# 13 epoch,  8000 iteration, loss:0.684
# Checking accuracy on validation set
# Got 787 / 1000 correct (78.70)
# 13 epoch,  9000 iteration, loss:0.664
# Checking accuracy on validation set
# Got 789 / 1000 correct (78.90)
# 13 epoch, 10000 iteration, loss:0.695
# Checking accuracy on validation set
# Got 763 / 1000 correct (76.30)
# 13 epoch, 11000 iteration, loss:0.665
# Checking accuracy on validation set
# Got 784 / 1000 correct (78.40)
# 13 epoch, 12000 iteration, loss:0.691
#  num 12 epoch
# ####### Training Loss #######
# [0.65853003]
# Checking accuracy on validation set
# Got 782 / 1000 correct (78.20)
# 14 epoch,  1000 iteration, loss:0.641
# Checking accuracy on validation set
# Got 782 / 1000 correct (78.20)
# 14 epoch,  2000 iteration, loss:0.638
# Checking accuracy on validation set
# Got 781 / 1000 correct (78.10)
# 14 epoch,  3000 iteration, loss:0.613
# Checking accuracy on validation set
# Got 773 / 1000 correct (77.30)
# 14 epoch,  4000 iteration, loss:0.650
# Checking accuracy on validation set
# Got 770 / 1000 correct (77.00)
# 14 epoch,  5000 iteration, loss:0.655
# Checking accuracy on validation set
# Got 785 / 1000 correct (78.50)
# 14 epoch,  6000 iteration, loss:0.671
# Checking accuracy on validation set
# Got 785 / 1000 correct (78.50)
# 14 epoch,  7000 iteration, loss:0.641
# Checking accuracy on validation set
# Got 776 / 1000 correct (77.60)
# 14 epoch,  8000 iteration, loss:0.650
# Checking accuracy on validation set
# Got 786 / 1000 correct (78.60)
# 14 epoch,  9000 iteration, loss:0.642
# Checking accuracy on validation set
# Got 794 / 1000 correct (79.40)
# 14 epoch, 10000 iteration, loss:0.650
# Checking accuracy on validation set
# Got 786 / 1000 correct (78.60)
# 14 epoch, 11000 iteration, loss:0.654
# Checking accuracy on validation set
# Got 757 / 1000 correct (75.70)
# 14 epoch, 12000 iteration, loss:0.645
#  num 13 epoch
# ####### Training Loss #######
# [0.63319819]
# Checking accuracy on validation set
# Got 789 / 1000 correct (78.90)
# 15 epoch,  1000 iteration, loss:0.574
# Checking accuracy on validation set
# Got 799 / 1000 correct (79.90)
# 15 epoch,  2000 iteration, loss:0.600
# Checking accuracy on validation set
# Got 764 / 1000 correct (76.40)
# 15 epoch,  3000 iteration, loss:0.605
# Checking accuracy on validation set
# Got 794 / 1000 correct (79.40)
# 15 epoch,  4000 iteration, loss:0.597
# Checking accuracy on validation set
# Got 779 / 1000 correct (77.90)
# 15 epoch,  5000 iteration, loss:0.617
# Checking accuracy on validation set
# Got 777 / 1000 correct (77.70)
# 15 epoch,  6000 iteration, loss:0.622
# Checking accuracy on validation set
# Got 787 / 1000 correct (78.70)
# 15 epoch,  7000 iteration, loss:0.649
# Checking accuracy on validation set
# Got 772 / 1000 correct (77.20)
# 15 epoch,  8000 iteration, loss:0.620
# Checking accuracy on validation set
# Got 792 / 1000 correct (79.20)
# 15 epoch,  9000 iteration, loss:0.607
# Checking accuracy on validation set
# Got 811 / 1000 correct (81.10)
# 15 epoch, 10000 iteration, loss:0.649
# Checking accuracy on validation set
# Got 755 / 1000 correct (75.50)
# 15 epoch, 11000 iteration, loss:0.629
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
# 15 epoch, 12000 iteration, loss:0.647
#  num 14 epoch
# ####### Training Loss #######
# [0.60537911]
# Checking accuracy on validation set
# Got 776 / 1000 correct (77.60)
# 16 epoch,  1000 iteration, loss:0.590
# Checking accuracy on validation set
# Got 802 / 1000 correct (80.20)
# 16 epoch,  2000 iteration, loss:0.580
# Checking accuracy on validation set
# Got 806 / 1000 correct (80.60)
# 16 epoch,  3000 iteration, loss:0.584
# Checking accuracy on validation set
# Got 785 / 1000 correct (78.50)
# 16 epoch,  4000 iteration, loss:0.602
# Checking accuracy on validation set
# Got 802 / 1000 correct (80.20)
# 16 epoch,  5000 iteration, loss:0.583
# Checking accuracy on validation set
# Got 792 / 1000 correct (79.20)
# 16 epoch,  6000 iteration, loss:0.590
# Checking accuracy on validation set
# Got 789 / 1000 correct (78.90)
# 16 epoch,  7000 iteration, loss:0.611
# Checking accuracy on validation set
# Got 786 / 1000 correct (78.60)
# 16 epoch,  8000 iteration, loss:0.590
# Checking accuracy on validation set
# Got 773 / 1000 correct (77.30)
# 16 epoch,  9000 iteration, loss:0.606
# Checking accuracy on validation set
# Got 807 / 1000 correct (80.70)
# 16 epoch, 10000 iteration, loss:0.591
# Checking accuracy on validation set
# Got 787 / 1000 correct (78.70)
# 16 epoch, 11000 iteration, loss:0.628
# Checking accuracy on validation set
# Got 805 / 1000 correct (80.50)
# 16 epoch, 12000 iteration, loss:0.614
#  num 15 epoch
# ####### Training Loss #######
# [0.58627142]
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
# 17 epoch,  1000 iteration, loss:0.555
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
# 17 epoch,  2000 iteration, loss:0.544
# Checking accuracy on validation set
# Got 799 / 1000 correct (79.90)
# 17 epoch,  3000 iteration, loss:0.604
# Checking accuracy on validation set
# Got 787 / 1000 correct (78.70)
# 17 epoch,  4000 iteration, loss:0.589
# Checking accuracy on validation set
# Got 782 / 1000 correct (78.20)
# 17 epoch,  5000 iteration, loss:0.572
# Checking accuracy on validation set
# Got 779 / 1000 correct (77.90)
# 17 epoch,  6000 iteration, loss:0.605
# Checking accuracy on validation set
# Got 753 / 1000 correct (75.30)
# 17 epoch,  7000 iteration, loss:0.569
# Checking accuracy on validation set
# Got 791 / 1000 correct (79.10)
# 17 epoch,  8000 iteration, loss:0.578
# Checking accuracy on validation set
# Got 790 / 1000 correct (79.00)
# 17 epoch,  9000 iteration, loss:0.579
# Checking accuracy on validation set
# Got 798 / 1000 correct (79.80)
# 17 epoch, 10000 iteration, loss:0.575
# Checking accuracy on validation set
# Got 773 / 1000 correct (77.30)
# 17 epoch, 11000 iteration, loss:0.596
# Checking accuracy on validation set
# Got 793 / 1000 correct (79.30)
# 17 epoch, 12000 iteration, loss:0.573
#  num 16 epoch
# ####### Training Loss #######
# [0.56723355]
# Checking accuracy on validation set
# Got 788 / 1000 correct (78.80)
# 18 epoch,  1000 iteration, loss:0.534
# Checking accuracy on validation set
# Got 805 / 1000 correct (80.50)
# 18 epoch,  2000 iteration, loss:0.522
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
# 18 epoch,  3000 iteration, loss:0.548
# Checking accuracy on validation set
# Got 807 / 1000 correct (80.70)
# 18 epoch,  4000 iteration, loss:0.552
# Checking accuracy on validation set
# Got 776 / 1000 correct (77.60)
# 18 epoch,  5000 iteration, loss:0.599
# Checking accuracy on validation set
# Got 800 / 1000 correct (80.00)
# 18 epoch,  6000 iteration, loss:0.550
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
# 18 epoch,  7000 iteration, loss:0.584
# Checking accuracy on validation set
# Got 777 / 1000 correct (77.70)
# 18 epoch,  8000 iteration, loss:0.560
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
# 18 epoch,  9000 iteration, loss:0.571
# Checking accuracy on validation set
# Got 796 / 1000 correct (79.60)
# 18 epoch, 10000 iteration, loss:0.587
# Checking accuracy on validation set
# Got 822 / 1000 correct (82.20)
# 18 epoch, 11000 iteration, loss:0.563
# Checking accuracy on validation set
# Got 785 / 1000 correct (78.50)
# 18 epoch, 12000 iteration, loss:0.564
#  num 17 epoch
# ####### Training Loss #######
# [0.54937936]
# Checking accuracy on validation set
# Got 789 / 1000 correct (78.90)
# 19 epoch,  1000 iteration, loss:0.525
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
# 19 epoch,  2000 iteration, loss:0.527
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
# 19 epoch,  3000 iteration, loss:0.524
# Checking accuracy on validation set
# Got 776 / 1000 correct (77.60)
# 19 epoch,  4000 iteration, loss:0.536
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
# 19 epoch,  5000 iteration, loss:0.555
# Checking accuracy on validation set
# Got 803 / 1000 correct (80.30)
# 19 epoch,  6000 iteration, loss:0.519
# Checking accuracy on validation set
# Got 759 / 1000 correct (75.90)
# 19 epoch,  7000 iteration, loss:0.519
# Checking accuracy on validation set
# Got 803 / 1000 correct (80.30)
# 19 epoch,  8000 iteration, loss:0.564
# Checking accuracy on validation set
# Got 800 / 1000 correct (80.00)
# 19 epoch,  9000 iteration, loss:0.587
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
# 19 epoch, 10000 iteration, loss:0.577
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
# 19 epoch, 11000 iteration, loss:0.576
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
# 19 epoch, 12000 iteration, loss:0.537
#  num 18 epoch
# ####### Training Loss #######
# [0.5344861]
# Checking accuracy on validation set
# Got 813 / 1000 correct (81.30)
# 20 epoch,  1000 iteration, loss:0.493
# Checking accuracy on validation set
# Got 785 / 1000 correct (78.50)
# 20 epoch,  2000 iteration, loss:0.518
# Checking accuracy on validation set
# Got 820 / 1000 correct (82.00)
# 20 epoch,  3000 iteration, loss:0.519
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
# 20 epoch,  4000 iteration, loss:0.524
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
# 20 epoch,  5000 iteration, loss:0.547
# Checking accuracy on validation set
# Got 816 / 1000 correct (81.60)
# 20 epoch,  6000 iteration, loss:0.541
# Checking accuracy on validation set
# Got 770 / 1000 correct (77.00)
# 20 epoch,  7000 iteration, loss:0.522
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
# 20 epoch,  8000 iteration, loss:0.531
# Checking accuracy on validation set
# Got 778 / 1000 correct (77.80)
# 20 epoch,  9000 iteration, loss:0.525
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
# 20 epoch, 10000 iteration, loss:0.543
# Checking accuracy on validation set
# Got 815 / 1000 correct (81.50)
# 20 epoch, 11000 iteration, loss:0.528
# Checking accuracy on validation set
# Got 785 / 1000 correct (78.50)
# 20 epoch, 12000 iteration, loss:0.549
#  num 19 epoch
# ####### Training Loss #######
# [0.51814838]
# Checking accuracy on validation set
# Got 792 / 1000 correct (79.20)
# 21 epoch,  1000 iteration, loss:0.485
# Checking accuracy on validation set
# Got 798 / 1000 correct (79.80)
# 21 epoch,  2000 iteration, loss:0.470
# Checking accuracy on validation set
# Got 813 / 1000 correct (81.30)
# 21 epoch,  3000 iteration, loss:0.505
# Checking accuracy on validation set
# Got 784 / 1000 correct (78.40)
# 21 epoch,  4000 iteration, loss:0.508
# Checking accuracy on validation set
# Got 792 / 1000 correct (79.20)
# 21 epoch,  5000 iteration, loss:0.513
# Checking accuracy on validation set
# Got 803 / 1000 correct (80.30)
# 21 epoch,  6000 iteration, loss:0.505
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
# 21 epoch,  7000 iteration, loss:0.524
# Checking accuracy on validation set
# Got 776 / 1000 correct (77.60)
# 21 epoch,  8000 iteration, loss:0.504
# Checking accuracy on validation set
# Got 810 / 1000 correct (81.00)
# 21 epoch,  9000 iteration, loss:0.531
# Checking accuracy on validation set
# Got 806 / 1000 correct (80.60)
# 21 epoch, 10000 iteration, loss:0.531
# Checking accuracy on validation set
# Got 813 / 1000 correct (81.30)
# 21 epoch, 11000 iteration, loss:0.534
# Checking accuracy on validation set
# Got 771 / 1000 correct (77.10)
# 21 epoch, 12000 iteration, loss:0.534
#  num 20 epoch
# ####### Training Loss #######
# [0.50127021]
# Checking accuracy on validation set
# Got 768 / 1000 correct (76.80)
# 22 epoch,  1000 iteration, loss:0.460
# Checking accuracy on validation set
# Got 825 / 1000 correct (82.50)
# 22 epoch,  2000 iteration, loss:0.474
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
# 22 epoch,  3000 iteration, loss:0.490
# Checking accuracy on validation set
# Got 796 / 1000 correct (79.60)
# 22 epoch,  4000 iteration, loss:0.489
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
# 22 epoch,  5000 iteration, loss:0.498
# Checking accuracy on validation set
# Got 789 / 1000 correct (78.90)
# 22 epoch,  6000 iteration, loss:0.504
# Checking accuracy on validation set
# Got 802 / 1000 correct (80.20)
# 22 epoch,  7000 iteration, loss:0.518
# Checking accuracy on validation set
# Got 816 / 1000 correct (81.60)
# 22 epoch,  8000 iteration, loss:0.505
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
# 22 epoch,  9000 iteration, loss:0.504
# Checking accuracy on validation set
# Got 794 / 1000 correct (79.40)
# 22 epoch, 10000 iteration, loss:0.518
# Checking accuracy on validation set
# Got 772 / 1000 correct (77.20)
# 22 epoch, 11000 iteration, loss:0.507
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
# 22 epoch, 12000 iteration, loss:0.538
#  num 21 epoch
# ####### Training Loss #######
# [0.49110172]
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
# 23 epoch,  1000 iteration, loss:0.470
# Checking accuracy on validation set
# Got 810 / 1000 correct (81.00)
# 23 epoch,  2000 iteration, loss:0.476
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
# 23 epoch,  3000 iteration, loss:0.485
# Checking accuracy on validation set
# Got 792 / 1000 correct (79.20)
# 23 epoch,  4000 iteration, loss:0.480
# Checking accuracy on validation set
# Got 807 / 1000 correct (80.70)
# 23 epoch,  5000 iteration, loss:0.479
# Checking accuracy on validation set
# Got 778 / 1000 correct (77.80)
# 23 epoch,  6000 iteration, loss:0.476
# Checking accuracy on validation set
# Got 810 / 1000 correct (81.00)
# 23 epoch,  7000 iteration, loss:0.489
# Checking accuracy on validation set
# Got 820 / 1000 correct (82.00)
# 23 epoch,  8000 iteration, loss:0.503
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
# 23 epoch,  9000 iteration, loss:0.506
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
# 23 epoch, 10000 iteration, loss:0.518
# Checking accuracy on validation set
# Got 800 / 1000 correct (80.00)
# 23 epoch, 11000 iteration, loss:0.499
# Checking accuracy on validation set
# Got 818 / 1000 correct (81.80)
# 23 epoch, 12000 iteration, loss:0.483
#  num 22 epoch
# ####### Training Loss #######
# [0.47908383]
# Checking accuracy on validation set
# Got 825 / 1000 correct (82.50)
# 24 epoch,  1000 iteration, loss:0.456
# Checking accuracy on validation set
# Got 801 / 1000 correct (80.10)
# 24 epoch,  2000 iteration, loss:0.441
# Checking accuracy on validation set
# Got 803 / 1000 correct (80.30)
# 24 epoch,  3000 iteration, loss:0.456
# Checking accuracy on validation set
# Got 818 / 1000 correct (81.80)
# 24 epoch,  4000 iteration, loss:0.457
# Checking accuracy on validation set
# Got 800 / 1000 correct (80.00)
# 24 epoch,  5000 iteration, loss:0.482
# Checking accuracy on validation set
# Got 792 / 1000 correct (79.20)
# 24 epoch,  6000 iteration, loss:0.488
# Checking accuracy on validation set
# Got 824 / 1000 correct (82.40)
# 24 epoch,  7000 iteration, loss:0.465
# Checking accuracy on validation set
# Got 829 / 1000 correct (82.90)
# 24 epoch,  8000 iteration, loss:0.473
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
# 24 epoch,  9000 iteration, loss:0.481
# Checking accuracy on validation set
# Got 806 / 1000 correct (80.60)
# 24 epoch, 10000 iteration, loss:0.490
# Checking accuracy on validation set
# Got 802 / 1000 correct (80.20)
# 24 epoch, 11000 iteration, loss:0.509
# Checking accuracy on validation set
# Got 805 / 1000 correct (80.50)
# 24 epoch, 12000 iteration, loss:0.501
#  num 23 epoch
# ####### Training Loss #######
# [0.46515015]
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
# 25 epoch,  1000 iteration, loss:0.434
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
# 25 epoch,  2000 iteration, loss:0.422
# Checking accuracy on validation set
# Got 796 / 1000 correct (79.60)
# 25 epoch,  3000 iteration, loss:0.461
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
# 25 epoch,  4000 iteration, loss:0.449
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
# 25 epoch,  5000 iteration, loss:0.470
# Checking accuracy on validation set
# Got 815 / 1000 correct (81.50)
# 25 epoch,  6000 iteration, loss:0.474
# Checking accuracy on validation set
# Got 805 / 1000 correct (80.50)
# 25 epoch,  7000 iteration, loss:0.473
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
# 25 epoch,  8000 iteration, loss:0.469
# Checking accuracy on validation set
# Got 810 / 1000 correct (81.00)
# 25 epoch,  9000 iteration, loss:0.489
# Checking accuracy on validation set
# Got 817 / 1000 correct (81.70)
# 25 epoch, 10000 iteration, loss:0.469
# Checking accuracy on validation set
# Got 800 / 1000 correct (80.00)
# 25 epoch, 11000 iteration, loss:0.487
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
# 25 epoch, 12000 iteration, loss:0.481
#  num 24 epoch
# ####### Training Loss #######
# [0.45589817]
# Checking accuracy on validation set
# Got 779 / 1000 correct (77.90)
# 26 epoch,  1000 iteration, loss:0.407
# Checking accuracy on validation set
# Got 817 / 1000 correct (81.70)
# 26 epoch,  2000 iteration, loss:0.435
# Checking accuracy on validation set
# Got 792 / 1000 correct (79.20)
# 26 epoch,  3000 iteration, loss:0.450
# Checking accuracy on validation set
# Got 824 / 1000 correct (82.40)
# 26 epoch,  4000 iteration, loss:0.467
# Checking accuracy on validation set
# Got 791 / 1000 correct (79.10)
# 26 epoch,  5000 iteration, loss:0.449
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
# 26 epoch,  6000 iteration, loss:0.448
# Checking accuracy on validation set
# Got 820 / 1000 correct (82.00)
# 26 epoch,  7000 iteration, loss:0.459
# Checking accuracy on validation set
# Got 827 / 1000 correct (82.70)
# 26 epoch,  8000 iteration, loss:0.462
# Checking accuracy on validation set
# Got 801 / 1000 correct (80.10)
# 26 epoch,  9000 iteration, loss:0.450
# Checking accuracy on validation set
# Got 813 / 1000 correct (81.30)
# 26 epoch, 10000 iteration, loss:0.485
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
# 26 epoch, 11000 iteration, loss:0.454
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
# 26 epoch, 12000 iteration, loss:0.493
#  num 25 epoch
# ####### Training Loss #######
# [0.44713319]
# Checking accuracy on validation set
# Got 816 / 1000 correct (81.60)
# 27 epoch,  1000 iteration, loss:0.406
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
# 27 epoch,  2000 iteration, loss:0.412
# Checking accuracy on validation set
# Got 820 / 1000 correct (82.00)
# 27 epoch,  3000 iteration, loss:0.421
# Checking accuracy on validation set
# Got 799 / 1000 correct (79.90)
# 27 epoch,  4000 iteration, loss:0.439
# Checking accuracy on validation set
# Got 803 / 1000 correct (80.30)
# 27 epoch,  5000 iteration, loss:0.445
# Checking accuracy on validation set
# Got 803 / 1000 correct (80.30)
# 27 epoch,  6000 iteration, loss:0.457
# Checking accuracy on validation set
# Got 820 / 1000 correct (82.00)
# 27 epoch,  7000 iteration, loss:0.444
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
# 27 epoch,  8000 iteration, loss:0.426
# Checking accuracy on validation set
# Got 798 / 1000 correct (79.80)
# 27 epoch,  9000 iteration, loss:0.465
# Checking accuracy on validation set
# Got 798 / 1000 correct (79.80)
# 27 epoch, 10000 iteration, loss:0.428
# Checking accuracy on validation set
# Got 805 / 1000 correct (80.50)
# 27 epoch, 11000 iteration, loss:0.455
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
# 27 epoch, 12000 iteration, loss:0.468
#  num 26 epoch
# ####### Training Loss #######
# [0.43081403]
# Checking accuracy on validation set
# Got 824 / 1000 correct (82.40)
# 28 epoch,  1000 iteration, loss:0.414
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
# 28 epoch,  2000 iteration, loss:0.403
# Checking accuracy on validation set
# Got 805 / 1000 correct (80.50)
# 28 epoch,  3000 iteration, loss:0.417
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
# 28 epoch,  4000 iteration, loss:0.433
# Checking accuracy on validation set
# Got 816 / 1000 correct (81.60)
# 28 epoch,  5000 iteration, loss:0.420
# Checking accuracy on validation set
# Got 805 / 1000 correct (80.50)
# 28 epoch,  6000 iteration, loss:0.431
# Checking accuracy on validation set
# Got 803 / 1000 correct (80.30)
# 28 epoch,  7000 iteration, loss:0.428
# Checking accuracy on validation set
# Got 780 / 1000 correct (78.00)
# 28 epoch,  8000 iteration, loss:0.452
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
# 28 epoch,  9000 iteration, loss:0.432
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
# 28 epoch, 10000 iteration, loss:0.452
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
# 28 epoch, 11000 iteration, loss:0.452
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
# 28 epoch, 12000 iteration, loss:0.455
#  num 27 epoch
# ####### Training Loss #######
# [0.42407725]
# Checking accuracy on validation set
# Got 813 / 1000 correct (81.30)
# 29 epoch,  1000 iteration, loss:0.378
# Checking accuracy on validation set
# Got 811 / 1000 correct (81.10)
# 29 epoch,  2000 iteration, loss:0.414
# Checking accuracy on validation set
# Got 816 / 1000 correct (81.60)
# 29 epoch,  3000 iteration, loss:0.411
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
# 29 epoch,  4000 iteration, loss:0.407
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
# 29 epoch,  5000 iteration, loss:0.397
# Checking accuracy on validation set
# Got 773 / 1000 correct (77.30)
# 29 epoch,  6000 iteration, loss:0.419
# Checking accuracy on validation set
# Got 832 / 1000 correct (83.20)
# 29 epoch,  7000 iteration, loss:0.436
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
# 29 epoch,  8000 iteration, loss:0.419
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
# 29 epoch,  9000 iteration, loss:0.426
# Checking accuracy on validation set
# Got 815 / 1000 correct (81.50)
# 29 epoch, 10000 iteration, loss:0.432
# Checking accuracy on validation set
# Got 834 / 1000 correct (83.40)
# 29 epoch, 11000 iteration, loss:0.421
# Checking accuracy on validation set
# Got 810 / 1000 correct (81.00)
# 29 epoch, 12000 iteration, loss:0.459
#  num 28 epoch
# ####### Training Loss #######
# [0.4108204]
# Checking accuracy on validation set
# Got 806 / 1000 correct (80.60)
# 30 epoch,  1000 iteration, loss:0.370
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
# 30 epoch,  2000 iteration, loss:0.387
# Checking accuracy on validation set
# Got 803 / 1000 correct (80.30)
# 30 epoch,  3000 iteration, loss:0.400
# Checking accuracy on validation set
# Got 786 / 1000 correct (78.60)
# 30 epoch,  4000 iteration, loss:0.413
# Checking accuracy on validation set
# Got 791 / 1000 correct (79.10)
# 30 epoch,  5000 iteration, loss:0.403
# Checking accuracy on validation set
# Got 806 / 1000 correct (80.60)
# 30 epoch,  6000 iteration, loss:0.432
# Checking accuracy on validation set
# Got 803 / 1000 correct (80.30)
# 30 epoch,  7000 iteration, loss:0.404
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
# 30 epoch,  8000 iteration, loss:0.411
# Checking accuracy on validation set
# Got 816 / 1000 correct (81.60)
# 30 epoch,  9000 iteration, loss:0.425
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
# 30 epoch, 10000 iteration, loss:0.420
# Checking accuracy on validation set
# Got 770 / 1000 correct (77.00)
# 30 epoch, 11000 iteration, loss:0.445
# Checking accuracy on validation set
# Got 782 / 1000 correct (78.20)
# 30 epoch, 12000 iteration, loss:0.442
#  num 29 epoch
# ####### Training Loss #######
# [0.40458255]
# Checking accuracy on validation set
# Got 822 / 1000 correct (82.20)
# 31 epoch,  1000 iteration, loss:0.373
# Checking accuracy on validation set
# Got 805 / 1000 correct (80.50)
# 31 epoch,  2000 iteration, loss:0.366
# Checking accuracy on validation set
# Got 822 / 1000 correct (82.20)
# 31 epoch,  3000 iteration, loss:0.376
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
# 31 epoch,  4000 iteration, loss:0.401
# Checking accuracy on validation set
# Got 825 / 1000 correct (82.50)
# 31 epoch,  5000 iteration, loss:0.410
# Checking accuracy on validation set
# Got 816 / 1000 correct (81.60)
# 31 epoch,  6000 iteration, loss:0.390
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
# 31 epoch,  7000 iteration, loss:0.420
# Checking accuracy on validation set
# Got 806 / 1000 correct (80.60)
# 31 epoch,  8000 iteration, loss:0.425
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
# 31 epoch,  9000 iteration, loss:0.407
# Checking accuracy on validation set
# Got 832 / 1000 correct (83.20)
# 31 epoch, 10000 iteration, loss:0.401
# Checking accuracy on validation set
# Got 813 / 1000 correct (81.30)
# 31 epoch, 11000 iteration, loss:0.426
# Checking accuracy on validation set
# Got 799 / 1000 correct (79.90)
# 31 epoch, 12000 iteration, loss:0.434
#  num 30 epoch
# ####### Training Loss #######
# [0.39451018]
# Checking accuracy on validation set
# Got 819 / 1000 correct (81.90)
# 32 epoch,  1000 iteration, loss:0.370
# Checking accuracy on validation set
# Got 787 / 1000 correct (78.70)
# 32 epoch,  2000 iteration, loss:0.388
# Checking accuracy on validation set
# Got 789 / 1000 correct (78.90)
# 32 epoch,  3000 iteration, loss:0.391
# Checking accuracy on validation set
# Got 824 / 1000 correct (82.40)
# 32 epoch,  4000 iteration, loss:0.371
# Checking accuracy on validation set
# Got 824 / 1000 correct (82.40)
# 32 epoch,  5000 iteration, loss:0.405
# Checking accuracy on validation set
# Got 796 / 1000 correct (79.60)
# 32 epoch,  6000 iteration, loss:0.379
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
# 32 epoch,  7000 iteration, loss:0.404
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
# 32 epoch,  8000 iteration, loss:0.394
# Checking accuracy on validation set
# Got 828 / 1000 correct (82.80)
# 32 epoch,  9000 iteration, loss:0.437
# Checking accuracy on validation set
# Got 805 / 1000 correct (80.50)
# 32 epoch, 10000 iteration, loss:0.411
# Checking accuracy on validation set
# Got 820 / 1000 correct (82.00)
# 32 epoch, 11000 iteration, loss:0.416
# Checking accuracy on validation set
# Got 787 / 1000 correct (78.70)
# 32 epoch, 12000 iteration, loss:0.410
#  num 31 epoch
# ####### Training Loss #######
# [0.39071653]
# Checking accuracy on validation set
# Got 803 / 1000 correct (80.30)
# 33 epoch,  1000 iteration, loss:0.348
# Checking accuracy on validation set
# Got 819 / 1000 correct (81.90)
# 33 epoch,  2000 iteration, loss:0.338
# Checking accuracy on validation set
# Got 828 / 1000 correct (82.80)
# 33 epoch,  3000 iteration, loss:0.375
# Checking accuracy on validation set
# Got 816 / 1000 correct (81.60)
# 33 epoch,  4000 iteration, loss:0.375
# Checking accuracy on validation set
# Got 811 / 1000 correct (81.10)
# 33 epoch,  5000 iteration, loss:0.390
# Checking accuracy on validation set
# Got 785 / 1000 correct (78.50)
# 33 epoch,  6000 iteration, loss:0.393
# Checking accuracy on validation set
# Got 844 / 1000 correct (84.40)
# 33 epoch,  7000 iteration, loss:0.417
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
# 33 epoch,  8000 iteration, loss:0.387
# Checking accuracy on validation set
# Got 788 / 1000 correct (78.80)
# 33 epoch,  9000 iteration, loss:0.401
# Checking accuracy on validation set
# Got 816 / 1000 correct (81.60)
# 33 epoch, 10000 iteration, loss:0.392
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
# 33 epoch, 11000 iteration, loss:0.410
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
# 33 epoch, 12000 iteration, loss:0.413
#  num 32 epoch
# ####### Training Loss #######
# [0.38015657]
# Checking accuracy on validation set
# Got 806 / 1000 correct (80.60)
# 34 epoch,  1000 iteration, loss:0.313
# Checking accuracy on validation set
# Got 802 / 1000 correct (80.20)
# 34 epoch,  2000 iteration, loss:0.344
# Checking accuracy on validation set
# Got 817 / 1000 correct (81.70)
# 34 epoch,  3000 iteration, loss:0.359
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
# 34 epoch,  4000 iteration, loss:0.384
# Checking accuracy on validation set
# Got 813 / 1000 correct (81.30)
# 34 epoch,  5000 iteration, loss:0.383
# Checking accuracy on validation set
# Got 811 / 1000 correct (81.10)
# 34 epoch,  6000 iteration, loss:0.405
# Checking accuracy on validation set
# Got 828 / 1000 correct (82.80)
# 34 epoch,  7000 iteration, loss:0.384
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
# 34 epoch,  8000 iteration, loss:0.393
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
# 34 epoch,  9000 iteration, loss:0.382
# Checking accuracy on validation set
# Got 815 / 1000 correct (81.50)
# 34 epoch, 10000 iteration, loss:0.399
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
# 34 epoch, 11000 iteration, loss:0.414
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
# 34 epoch, 12000 iteration, loss:0.385
#  num 33 epoch
# ####### Training Loss #######
# [0.37183161]
# Checking accuracy on validation set
# Got 825 / 1000 correct (82.50)
# 35 epoch,  1000 iteration, loss:0.345
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
# 35 epoch,  2000 iteration, loss:0.339
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
# 35 epoch,  3000 iteration, loss:0.350
# Checking accuracy on validation set
# Got 827 / 1000 correct (82.70)
# 35 epoch,  4000 iteration, loss:0.347
# Checking accuracy on validation set
# Got 815 / 1000 correct (81.50)
# 35 epoch,  5000 iteration, loss:0.366
# Checking accuracy on validation set
# Got 792 / 1000 correct (79.20)
# 35 epoch,  6000 iteration, loss:0.373
# Checking accuracy on validation set
# Got 820 / 1000 correct (82.00)
# 35 epoch,  7000 iteration, loss:0.388
# Checking accuracy on validation set
# Got 833 / 1000 correct (83.30)
# 35 epoch,  8000 iteration, loss:0.389
# Checking accuracy on validation set
# Got 794 / 1000 correct (79.40)
# 35 epoch,  9000 iteration, loss:0.399
# Checking accuracy on validation set
# Got 819 / 1000 correct (81.90)
# 35 epoch, 10000 iteration, loss:0.412
# Checking accuracy on validation set
# Got 802 / 1000 correct (80.20)
# 35 epoch, 11000 iteration, loss:0.391
# Checking accuracy on validation set
# Got 811 / 1000 correct (81.10)
# 35 epoch, 12000 iteration, loss:0.399
#  num 34 epoch
# ####### Training Loss #######
# [0.36783388]
# Checking accuracy on validation set
# Got 816 / 1000 correct (81.60)
# 36 epoch,  1000 iteration, loss:0.324
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
# 36 epoch,  2000 iteration, loss:0.321
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
# 36 epoch,  3000 iteration, loss:0.343
# Checking accuracy on validation set
# Got 801 / 1000 correct (80.10)
# 36 epoch,  4000 iteration, loss:0.331
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
# 36 epoch,  5000 iteration, loss:0.366
# Checking accuracy on validation set
# Got 802 / 1000 correct (80.20)
# 36 epoch,  6000 iteration, loss:0.387
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
# 36 epoch,  7000 iteration, loss:0.358
# Checking accuracy on validation set
# Got 807 / 1000 correct (80.70)
# 36 epoch,  8000 iteration, loss:0.377
# Checking accuracy on validation set
# Got 822 / 1000 correct (82.20)
# 36 epoch,  9000 iteration, loss:0.381
# Checking accuracy on validation set
# Got 824 / 1000 correct (82.40)
# 36 epoch, 10000 iteration, loss:0.398
# Checking accuracy on validation set
# Got 793 / 1000 correct (79.30)
# 36 epoch, 11000 iteration, loss:0.375
# Checking accuracy on validation set
# Got 800 / 1000 correct (80.00)
# 36 epoch, 12000 iteration, loss:0.387
#  num 35 epoch
# ####### Training Loss #######
# [0.35615698]
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
# 37 epoch,  1000 iteration, loss:0.318
# Checking accuracy on validation set
# Got 813 / 1000 correct (81.30)
# 37 epoch,  2000 iteration, loss:0.319
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
# 37 epoch,  3000 iteration, loss:0.356
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
# 37 epoch,  4000 iteration, loss:0.369
# Checking accuracy on validation set
# Got 813 / 1000 correct (81.30)
# 37 epoch,  5000 iteration, loss:0.335
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
# 37 epoch,  6000 iteration, loss:0.354
# ...
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
# 341 epoch,  7000 iteration, loss:0.218
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
# 341 epoch,  8000 iteration, loss:0.225
# Checking accuracy on validation set
# Got 772 / 1000 correct (77.20)
# 341 epoch,  9000 iteration, loss:0.242
# Checking accuracy on validation set
# Got 796 / 1000 correct (79.60)
# 341 epoch, 10000 iteration, loss:0.239
# Checking accuracy on validation set
# Got 790 / 1000 correct (79.00)
# 341 epoch, 11000 iteration, loss:0.241
# Checking accuracy on validation set
# Got 782 / 1000 correct (78.20)
# 341 epoch, 12000 iteration, loss:0.239
#  num 340 epoch
# ####### Training Loss #######
# [0.21195389]
# Checking accuracy on validation set
# Got 776 / 1000 correct (77.60)
# 342 epoch,  1000 iteration, loss:0.159
# Checking accuracy on validation set
# Got 783 / 1000 correct (78.30)
# 342 epoch,  2000 iteration, loss:0.213
# Checking accuracy on validation set
# Got 799 / 1000 correct (79.90)
# 342 epoch,  3000 iteration, loss:0.174
# Checking accuracy on validation set
# Got 779 / 1000 correct (77.90)
# 342 epoch,  4000 iteration, loss:0.195
# Checking accuracy on validation set
# Got 806 / 1000 correct (80.60)
# 342 epoch,  5000 iteration, loss:0.203
# Checking accuracy on validation set
# Got 791 / 1000 correct (79.10)
# 342 epoch,  6000 iteration, loss:0.204
# Checking accuracy on validation set
# Got 786 / 1000 correct (78.60)
# 342 epoch,  7000 iteration, loss:0.212
# Checking accuracy on validation set
# Got 772 / 1000 correct (77.20)
# 342 epoch,  8000 iteration, loss:0.211
# Checking accuracy on validation set
# Got 776 / 1000 correct (77.60)
# 342 epoch,  9000 iteration, loss:0.244
# Checking accuracy on validation set
# Got 778 / 1000 correct (77.80)
# 342 epoch, 10000 iteration, loss:0.238
# Checking accuracy on validation set
# Got 778 / 1000 correct (77.80)
# 342 epoch, 11000 iteration, loss:0.248
# Checking accuracy on validation set
# Got 784 / 1000 correct (78.40)
# 342 epoch, 12000 iteration, loss:0.241
#  num 341 epoch
# ####### Training Loss #######
# [0.20786936]
# Checking accuracy on validation set
# Got 801 / 1000 correct (80.10)
# 343 epoch,  1000 iteration, loss:0.163
# Checking accuracy on validation set
# Got 792 / 1000 correct (79.20)
# 343 epoch,  2000 iteration, loss:0.195
# Checking accuracy on validation set
# Got 783 / 1000 correct (78.30)
# 343 epoch,  3000 iteration, loss:0.184
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
# 343 epoch,  4000 iteration, loss:0.206
# Checking accuracy on validation set
# Got 803 / 1000 correct (80.30)
# 343 epoch,  5000 iteration, loss:0.197
# Checking accuracy on validation set
# Got 794 / 1000 correct (79.40)
# 343 epoch,  6000 iteration, loss:0.197
# Checking accuracy on validation set
# Got 798 / 1000 correct (79.80)
# 343 epoch,  7000 iteration, loss:0.202
# Checking accuracy on validation set
# Got 788 / 1000 correct (78.80)
# 343 epoch,  8000 iteration, loss:0.216
# Checking accuracy on validation set
# Got 786 / 1000 correct (78.60)
# 343 epoch,  9000 iteration, loss:0.236
# Checking accuracy on validation set
# Got 780 / 1000 correct (78.00)
# 343 epoch, 10000 iteration, loss:0.240
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
# 343 epoch, 11000 iteration, loss:0.237
# Checking accuracy on validation set
# Got 782 / 1000 correct (78.20)
# 343 epoch, 12000 iteration, loss:0.246
#  num 342 epoch
# ####### Training Loss #######
# [0.20564367]
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
# 344 epoch,  1000 iteration, loss:0.163
# Checking accuracy on validation set
# Got 790 / 1000 correct (79.00)
# 344 epoch,  2000 iteration, loss:0.148
# Checking accuracy on validation set
# Got 793 / 1000 correct (79.30)
# 344 epoch,  3000 iteration, loss:0.218
# Checking accuracy on validation set
# Got 787 / 1000 correct (78.70)
# 344 epoch,  4000 iteration, loss:0.205
# Checking accuracy on validation set
# Got 799 / 1000 correct (79.90)
# 344 epoch,  5000 iteration, loss:0.189
# Checking accuracy on validation set
# Got 796 / 1000 correct (79.60)
# 344 epoch,  6000 iteration, loss:0.231
# Checking accuracy on validation set
# Got 786 / 1000 correct (78.60)
# 344 epoch,  7000 iteration, loss:0.213
# Checking accuracy on validation set
# Got 790 / 1000 correct (79.00)
# 344 epoch,  8000 iteration, loss:0.223
# Checking accuracy on validation set
# Got 802 / 1000 correct (80.20)
# 344 epoch,  9000 iteration, loss:0.237
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
# 344 epoch, 10000 iteration, loss:0.228
# Checking accuracy on validation set
# Got 787 / 1000 correct (78.70)
# 344 epoch, 11000 iteration, loss:0.244
# Checking accuracy on validation set
# Got 749 / 1000 correct (74.90)
# 344 epoch, 12000 iteration, loss:0.247
#  num 343 epoch
# ####### Training Loss #######
# [0.20875449]
# Checking accuracy on validation set
# Got 785 / 1000 correct (78.50)
# 345 epoch,  1000 iteration, loss:0.165
# Checking accuracy on validation set
# Got 781 / 1000 correct (78.10)
# 345 epoch,  2000 iteration, loss:0.186
# Checking accuracy on validation set
# Got 803 / 1000 correct (80.30)
# 345 epoch,  3000 iteration, loss:0.183
# Checking accuracy on validation set
# Got 774 / 1000 correct (77.40)
# 345 epoch,  4000 iteration, loss:0.200
# Checking accuracy on validation set
# Got 772 / 1000 correct (77.20)
# 345 epoch,  5000 iteration, loss:0.200
# Checking accuracy on validation set
# Got 768 / 1000 correct (76.80)
# 345 epoch,  6000 iteration, loss:0.218
# Checking accuracy on validation set
# Got 756 / 1000 correct (75.60)
# 345 epoch,  7000 iteration, loss:0.209
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
# 345 epoch,  8000 iteration, loss:0.227
# Checking accuracy on validation set
# Got 761 / 1000 correct (76.10)
# 345 epoch,  9000 iteration, loss:0.228
# Checking accuracy on validation set
# Got 784 / 1000 correct (78.40)
# 345 epoch, 10000 iteration, loss:0.234
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
# 345 epoch, 11000 iteration, loss:0.231
# Checking accuracy on validation set
# Got 780 / 1000 correct (78.00)
# 345 epoch, 12000 iteration, loss:0.258
#  num 344 epoch
# ####### Training Loss #######
# [0.20755991]
# Checking accuracy on validation set
# Got 784 / 1000 correct (78.40)
# 346 epoch,  1000 iteration, loss:0.169
# Checking accuracy on validation set
# Got 781 / 1000 correct (78.10)
# 346 epoch,  2000 iteration, loss:0.179
# Checking accuracy on validation set
# Got 782 / 1000 correct (78.20)
# 346 epoch,  3000 iteration, loss:0.202
# Checking accuracy on validation set
# Got 778 / 1000 correct (77.80)
# 346 epoch,  4000 iteration, loss:0.192
# Checking accuracy on validation set
# Got 792 / 1000 correct (79.20)
# 346 epoch,  5000 iteration, loss:0.208
# Checking accuracy on validation set
# Got 791 / 1000 correct (79.10)
# 346 epoch,  6000 iteration, loss:0.213
# Checking accuracy on validation set
# Got 768 / 1000 correct (76.80)
# 346 epoch,  7000 iteration, loss:0.232
# Checking accuracy on validation set
# Got 772 / 1000 correct (77.20)
# 346 epoch,  8000 iteration, loss:0.243
# Checking accuracy on validation set
# Got 775 / 1000 correct (77.50)
# 346 epoch,  9000 iteration, loss:0.221
# Checking accuracy on validation set
# Got 785 / 1000 correct (78.50)
# 346 epoch, 10000 iteration, loss:0.248
# Checking accuracy on validation set
# Got 801 / 1000 correct (80.10)
# 346 epoch, 11000 iteration, loss:0.263
# Checking accuracy on validation set
# Got 777 / 1000 correct (77.70)
# 346 epoch, 12000 iteration, loss:0.261
#  num 345 epoch
# ####### Training Loss #######
# [0.21550876]
# Checking accuracy on validation set
# Got 767 / 1000 correct (76.70)
# 347 epoch,  1000 iteration, loss:0.187
# Checking accuracy on validation set
# Got 776 / 1000 correct (77.60)
# 347 epoch,  2000 iteration, loss:0.182
# Checking accuracy on validation set
# Got 786 / 1000 correct (78.60)
# 347 epoch,  3000 iteration, loss:0.188
# Checking accuracy on validation set
# Got 788 / 1000 correct (78.80)
# 347 epoch,  4000 iteration, loss:0.192
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
# 347 epoch,  5000 iteration, loss:0.214
# Checking accuracy on validation set
# Got 775 / 1000 correct (77.50)
# 347 epoch,  6000 iteration, loss:0.215
# Checking accuracy on validation set
# Got 805 / 1000 correct (80.50)
# 347 epoch,  7000 iteration, loss:0.223
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
# 347 epoch,  8000 iteration, loss:0.217
# Checking accuracy on validation set
# Got 758 / 1000 correct (75.80)
# 347 epoch,  9000 iteration, loss:0.215
# Checking accuracy on validation set
# Got 762 / 1000 correct (76.20)
# 347 epoch, 10000 iteration, loss:0.234
# Checking accuracy on validation set
# Got 773 / 1000 correct (77.30)
# 347 epoch, 11000 iteration, loss:0.258
# Checking accuracy on validation set
# Got 765 / 1000 correct (76.50)
# 347 epoch, 12000 iteration, loss:0.263
#  num 346 epoch
# ####### Training Loss #######
# [0.21186981]
# Checking accuracy on validation set
# Got 780 / 1000 correct (78.00)
# 348 epoch,  1000 iteration, loss:0.161
# Checking accuracy on validation set
# Got 787 / 1000 correct (78.70)
# 348 epoch,  2000 iteration, loss:0.205
# Checking accuracy on validation set
# Got 770 / 1000 correct (77.00)
# 348 epoch,  3000 iteration, loss:0.187
# Checking accuracy on validation set
# Got 792 / 1000 correct (79.20)
# 348 epoch,  4000 iteration, loss:0.193
# Checking accuracy on validation set
# Got 793 / 1000 correct (79.30)
# 348 epoch,  5000 iteration, loss:0.223
# Checking accuracy on validation set
# Got 786 / 1000 correct (78.60)
# 348 epoch,  6000 iteration, loss:0.204
# Checking accuracy on validation set
# Got 756 / 1000 correct (75.60)
# 348 epoch,  7000 iteration, loss:0.214
# Checking accuracy on validation set
# Got 782 / 1000 correct (78.20)
# 348 epoch,  8000 iteration, loss:0.225
# Checking accuracy on validation set
# Got 766 / 1000 correct (76.60)
# 348 epoch,  9000 iteration, loss:0.228
# Checking accuracy on validation set
# Got 778 / 1000 correct (77.80)
# 348 epoch, 10000 iteration, loss:0.239
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
# 348 epoch, 11000 iteration, loss:0.242
# Checking accuracy on validation set
# Got 779 / 1000 correct (77.90)
# 348 epoch, 12000 iteration, loss:0.248
#  num 347 epoch
# ####### Training Loss #######
# [0.2114998]
# Checking accuracy on validation set
# Got 807 / 1000 correct (80.70)
# 349 epoch,  1000 iteration, loss:0.167
# Checking accuracy on validation set
# Got 794 / 1000 correct (79.40)
# 349 epoch,  2000 iteration, loss:0.186
# Checking accuracy on validation set
# Got 787 / 1000 correct (78.70)
# 349 epoch,  3000 iteration, loss:0.186
# Checking accuracy on validation set
# Got 764 / 1000 correct (76.40)
# 349 epoch,  4000 iteration, loss:0.207
# Checking accuracy on validation set
# Got 779 / 1000 correct (77.90)
# 349 epoch,  5000 iteration, loss:0.200
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
# 349 epoch,  6000 iteration, loss:0.219
# Checking accuracy on validation set
# Got 788 / 1000 correct (78.80)
# 349 epoch,  7000 iteration, loss:0.220
# Checking accuracy on validation set
# Got 784 / 1000 correct (78.40)
# 349 epoch,  8000 iteration, loss:0.222
# Checking accuracy on validation set
# Got 775 / 1000 correct (77.50)
# 349 epoch,  9000 iteration, loss:0.249
# Checking accuracy on validation set
# Got 792 / 1000 correct (79.20)
# 349 epoch, 10000 iteration, loss:0.261
# Checking accuracy on validation set
# Got 789 / 1000 correct (78.90)
# 349 epoch, 11000 iteration, loss:0.265
# Checking accuracy on validation set
# Got 793 / 1000 correct (79.30)
# 349 epoch, 12000 iteration, loss:0.263
#  num 348 epoch
# ####### Training Loss #######
# [0.21661185]
# Checking accuracy on validation set
# Got 765 / 1000 correct (76.50)
# 350 epoch,  1000 iteration, loss:0.155
# Checking accuracy on validation set
# Got 779 / 1000 correct (77.90)
# 350 epoch,  2000 iteration, loss:0.176
# Checking accuracy on validation set
# Got 798 / 1000 correct (79.80)
# 350 epoch,  3000 iteration, loss:0.198
# Checking accuracy on validation set
# Got 788 / 1000 correct (78.80)
# 350 epoch,  4000 iteration, loss:0.202
# Checking accuracy on validation set
# Got 786 / 1000 correct (78.60)
# 350 epoch,  5000 iteration, loss:0.187
# Checking accuracy on validation set
# Got 798 / 1000 correct (79.80)
# 350 epoch,  6000 iteration, loss:0.202
# Checking accuracy on validation set
# Got 779 / 1000 correct (77.90)
# 350 epoch,  7000 iteration, loss:0.213
# Checking accuracy on validation set
# Got 784 / 1000 correct (78.40)
# 350 epoch,  8000 iteration, loss:0.226
# Checking accuracy on validation set
# Got 789 / 1000 correct (78.90)
# 350 epoch,  9000 iteration, loss:0.237
# Checking accuracy on validation set
# Got 767 / 1000 correct (76.70)
# 350 epoch, 10000 iteration, loss:0.228
# Checking accuracy on validation set
# Got 786 / 1000 correct (78.60)
# 350 epoch, 11000 iteration, loss:0.233
# Checking accuracy on validation set
# Got 783 / 1000 correct (78.30)
# 350 epoch, 12000 iteration, loss:0.250
#  num 349 epoch
# ####### Training Loss #######
# [0.20509975]
# finish training
#
# Checking accuracy on test set
# Got 7911 / 10000 correct (79.11)
# #####################################
# Accuracy on testing set 7911.00
# #####################################
# now begin saving datum for next step plotting
# now plotting accuracies and losses
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-27f6ba109f56> in <module>()
#       8
#       9 ALL_CNN_B = help_func.running_model(run_num, ALL_CNN_B, net_name, lr, epoch,
# ---> 10                         loader_train, loader_val, loader_test)
#
# ~/DL_course/midterm-Quant95/Nets/help_func.py in running_model(run_num, net, net_name, lr_list, epoch_list, loader_train, loader_val, loader_test)
#     271     a /= 100
#     272     length = a.shape[0]
# --> 273     acc_axis_test = np.array(np.linspace(1,length, num=max_epoch))
#     274     plt.plot(acc_axis_test, a.reshape(-1,1), '--r', label='Test')
#     275     plt.xlabel('iteration')
#
# ~/Anacondas/anaconda3/envs/cs231n/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2747 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
#    2748     return gca().plot(
# -> 2749         *args, scalex=scalex, scaley=scaley, data=data, **kwargs)
#    2750
#    2751 # Autogenerated by boilerplate.py.  Do not edit as changes will be lost.
#
# ~/Anacondas/anaconda3/envs/cs231n/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1783                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1784                         RuntimeWarning, stacklevel=2)
# -> 1785             return func(ax, *args, **kwargs)
#    1786
#    1787         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/Anacondas/anaconda3/envs/cs231n/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, *args, **kwargs)
#    1602         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
#    1603
# -> 1604         for line in self._get_lines(*args, **kwargs):
#    1605             self.add_line(line)
#    1606             lines.append(line)
#
# ~/Anacondas/anaconda3/envs/cs231n/lib/python3.6/site-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     391                 this += args[0],
#     392                 args = args[1:]
# --> 393             yield from self._plot_args(this, kwargs)
#     394
#     395
#
# ~/Anacondas/anaconda3/envs/cs231n/lib/python3.6/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     368             x, y = index_of(tup[-1])
#     369
# --> 370         x, y = self._xy_from_xy(x, y)
#     371
#     372         if self.command == 'plot':
#
# ~/Anacondas/anaconda3/envs/cs231n/lib/python3.6/site-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     229         if x.shape[0] != y.shape[0]:
#     230             raise ValueError("x and y must have same first dimension, but "
# --> 231                              "have shapes {} and {}".format(x.shape, y.shape))
#     232         if x.ndim > 2 or y.ndim > 2:
#     233             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (350,) and (4200, 1)
