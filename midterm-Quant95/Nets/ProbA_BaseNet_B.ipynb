# %% [markdown]
# ## This notebook is the running results for base network B

# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F 
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.autograd import Variable
from torch.utils.data import sampler

import help_func
import new_ALL_Conv
# Out:
# right

# %%
train_batch_size = 4
test_batch_size = 4

NUM_TRAIN = 49000

transform = transforms.Compose(
          [transforms.ToTensor(),
           transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))])

cifar10_train = torchvision.datasets.CIFAR10('./cs231n/datasets', train=True, download=True,
                             transform=transform)
loader_train = torch.utils.data.DataLoader(cifar10_train, batch_size=train_batch_size, 
                          sampler=sampler.SubsetRandomSampler(range(NUM_TRAIN)))

cifar10_val = torchvision.datasets.CIFAR10('./cs231n/datasets', train=True, download=True,
                           transform=transform)
loader_val = torch.utils.data.DataLoader(cifar10_val, batch_size=train_batch_size, 
                        sampler=sampler.SubsetRandomSampler(range(NUM_TRAIN, 50000)))

cifar10_test = torchvision.datasets.CIFAR10('./cs231n/datasets', train=False, download=True, 
                            transform=transform)
loader_test = torch.utils.data.DataLoader(cifar10_test, batch_size=test_batch_size)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %%
net_a = new_ALL_Conv.BaseNet_A()
net_b = new_ALL_Conv.BaseNet_B()
net_c = new_ALL_Conv.BaseNet_C()

# %%
#lr = [0.025, 0.01, 0.005, 0.001]  too bad
#  lr = [0.01, 0.005, 0.001, 0.0005] bad
lr = [0.1, 0.05, 0.01, 0.001] 
epoch = [200, 250, 300]
run_num = 3 #1
net_name = 'BaseNet_B'

help_func.running_model(run_num, net_b, net_name, lr, epoch, 
                        loader_train, loader_val, loader_test)
# Out:
# using device: cuda
# begin training
# Checking accuracy on validation set
# Got 109 / 1000 correct (10.90)
# 1 epoch,  1000 iteration, loss:2.309
# Checking accuracy on validation set
# Got 117 / 1000 correct (11.70)
# 1 epoch,  2000 iteration, loss:2.302
# Checking accuracy on validation set
# Got 126 / 1000 correct (12.60)
# 1 epoch,  3000 iteration, loss:2.303
# Checking accuracy on validation set
# Got 126 / 1000 correct (12.60)
# 1 epoch,  4000 iteration, loss:2.302
# Checking accuracy on validation set
# Got 137 / 1000 correct (13.70)
# 1 epoch,  5000 iteration, loss:2.302
# Checking accuracy on validation set
# Got 123 / 1000 correct (12.30)
# 1 epoch,  6000 iteration, loss:2.303
# Checking accuracy on validation set
# Got 90 / 1000 correct (9.00)
# 1 epoch,  7000 iteration, loss:2.299
# Checking accuracy on validation set
# Got 161 / 1000 correct (16.10)
# 1 epoch,  8000 iteration, loss:2.293
# Checking accuracy on validation set
# Got 104 / 1000 correct (10.40)
# 1 epoch,  9000 iteration, loss:2.285
# Checking accuracy on validation set
# Got 99 / 1000 correct (9.90)
# 1 epoch, 10000 iteration, loss:2.283
# Checking accuracy on validation set
# Got 164 / 1000 correct (16.40)
# 1 epoch, 11000 iteration, loss:2.267
# Checking accuracy on validation set
# Got 184 / 1000 correct (18.40)
# 1 epoch, 12000 iteration, loss:2.266
#  num 0 epoch
# ####### Training Loss #######
# [2.24615227]
# Checking accuracy on validation set
# Got 178 / 1000 correct (17.80)
# 2 epoch,  1000 iteration, loss:2.254
# Checking accuracy on validation set
# Got 177 / 1000 correct (17.70)
# 2 epoch,  2000 iteration, loss:2.235
# Checking accuracy on validation set
# Got 182 / 1000 correct (18.20)
# 2 epoch,  3000 iteration, loss:2.215
# Checking accuracy on validation set
# Got 223 / 1000 correct (22.30)
# 2 epoch,  4000 iteration, loss:2.208
# Checking accuracy on validation set
# Got 226 / 1000 correct (22.60)
# 2 epoch,  5000 iteration, loss:2.180
# Checking accuracy on validation set
# Got 269 / 1000 correct (26.90)
# 2 epoch,  6000 iteration, loss:2.188
# Checking accuracy on validation set
# Got 324 / 1000 correct (32.40)
# 2 epoch,  7000 iteration, loss:2.129
# Checking accuracy on validation set
# Got 370 / 1000 correct (37.00)
# 2 epoch,  8000 iteration, loss:2.048
# Checking accuracy on validation set
# Got 385 / 1000 correct (38.50)
# 2 epoch,  9000 iteration, loss:2.005
# Checking accuracy on validation set
# Got 361 / 1000 correct (36.10)
# 2 epoch, 10000 iteration, loss:1.969
# Checking accuracy on validation set
# Got 414 / 1000 correct (41.40)
# 2 epoch, 11000 iteration, loss:1.908
# Checking accuracy on validation set
# Got 433 / 1000 correct (43.30)
# 2 epoch, 12000 iteration, loss:1.809
#  num 1 epoch
# ####### Training Loss #######
# [2.04838806]
# Checking accuracy on validation set
# Got 416 / 1000 correct (41.60)
# 3 epoch,  1000 iteration, loss:1.755
# Checking accuracy on validation set
# Got 467 / 1000 correct (46.70)
# 3 epoch,  2000 iteration, loss:1.677
# Checking accuracy on validation set
# Got 453 / 1000 correct (45.30)
# 3 epoch,  3000 iteration, loss:1.602
# Checking accuracy on validation set
# Got 480 / 1000 correct (48.00)
# 3 epoch,  4000 iteration, loss:1.566
# Checking accuracy on validation set
# Got 464 / 1000 correct (46.40)
# 3 epoch,  5000 iteration, loss:1.543
# Checking accuracy on validation set
# Got 481 / 1000 correct (48.10)
# 3 epoch,  6000 iteration, loss:1.501
# Checking accuracy on validation set
# Got 483 / 1000 correct (48.30)
# 3 epoch,  7000 iteration, loss:1.483
# Checking accuracy on validation set
# Got 520 / 1000 correct (52.00)
# 3 epoch,  8000 iteration, loss:1.459
# Checking accuracy on validation set
# Got 478 / 1000 correct (47.80)
# 3 epoch,  9000 iteration, loss:1.426
# Checking accuracy on validation set
# Got 546 / 1000 correct (54.60)
# 3 epoch, 10000 iteration, loss:1.420
# Checking accuracy on validation set
# Got 522 / 1000 correct (52.20)
# 3 epoch, 11000 iteration, loss:1.407
# Checking accuracy on validation set
# Got 554 / 1000 correct (55.40)
# 3 epoch, 12000 iteration, loss:1.363
#  num 2 epoch
# ####### Training Loss #######
# [1.48313978]
# Checking accuracy on validation set
# Got 540 / 1000 correct (54.00)
# 4 epoch,  1000 iteration, loss:1.340
# Checking accuracy on validation set
# Got 540 / 1000 correct (54.00)
# 4 epoch,  2000 iteration, loss:1.315
# Checking accuracy on validation set
# Got 561 / 1000 correct (56.10)
# 4 epoch,  3000 iteration, loss:1.312
# Checking accuracy on validation set
# Got 531 / 1000 correct (53.10)
# 4 epoch,  4000 iteration, loss:1.305
# Checking accuracy on validation set
# Got 575 / 1000 correct (57.50)
# 4 epoch,  5000 iteration, loss:1.273
# Checking accuracy on validation set
# Got 583 / 1000 correct (58.30)
# 4 epoch,  6000 iteration, loss:1.281
# Checking accuracy on validation set
# Got 595 / 1000 correct (59.50)
# 4 epoch,  7000 iteration, loss:1.267
# Checking accuracy on validation set
# Got 576 / 1000 correct (57.60)
# 4 epoch,  8000 iteration, loss:1.244
# Checking accuracy on validation set
# Got 567 / 1000 correct (56.70)
# 4 epoch,  9000 iteration, loss:1.256
# Checking accuracy on validation set
# Got 626 / 1000 correct (62.60)
# 4 epoch, 10000 iteration, loss:1.233
# Checking accuracy on validation set
# Got 594 / 1000 correct (59.40)
# 4 epoch, 11000 iteration, loss:1.230
# Checking accuracy on validation set
# Got 626 / 1000 correct (62.60)
# 4 epoch, 12000 iteration, loss:1.219
#  num 3 epoch
# ####### Training Loss #######
# [1.24670798]
# Checking accuracy on validation set
# Got 588 / 1000 correct (58.80)
# 5 epoch,  1000 iteration, loss:1.171
# Checking accuracy on validation set
# Got 628 / 1000 correct (62.80)
# 5 epoch,  2000 iteration, loss:1.168
# Checking accuracy on validation set
# Got 618 / 1000 correct (61.80)
# 5 epoch,  3000 iteration, loss:1.141
# Checking accuracy on validation set
# Got 645 / 1000 correct (64.50)
# 5 epoch,  4000 iteration, loss:1.141
# Checking accuracy on validation set
# Got 654 / 1000 correct (65.40)
# 5 epoch,  5000 iteration, loss:1.150
# Checking accuracy on validation set
# Got 611 / 1000 correct (61.10)
# 5 epoch,  6000 iteration, loss:1.118
# Checking accuracy on validation set
# Got 624 / 1000 correct (62.40)
# 5 epoch,  7000 iteration, loss:1.064
# Checking accuracy on validation set
# Got 622 / 1000 correct (62.20)
# 5 epoch,  8000 iteration, loss:1.120
# Checking accuracy on validation set
# Got 639 / 1000 correct (63.90)
# 5 epoch,  9000 iteration, loss:1.116
# Checking accuracy on validation set
# Got 626 / 1000 correct (62.60)
# 5 epoch, 10000 iteration, loss:1.097
# Checking accuracy on validation set
# Got 657 / 1000 correct (65.70)
# 5 epoch, 11000 iteration, loss:1.091
# Checking accuracy on validation set
# Got 672 / 1000 correct (67.20)
# 5 epoch, 12000 iteration, loss:1.077
#  num 4 epoch
# ####### Training Loss #######
# [1.0977311]
# Checking accuracy on validation set
# Got 637 / 1000 correct (63.70)
# 6 epoch,  1000 iteration, loss:1.033
# Checking accuracy on validation set
# Got 669 / 1000 correct (66.90)
# 6 epoch,  2000 iteration, loss:1.036
# Checking accuracy on validation set
# Got 687 / 1000 correct (68.70)
# 6 epoch,  3000 iteration, loss:1.026
# Checking accuracy on validation set
# Got 653 / 1000 correct (65.30)
# 6 epoch,  4000 iteration, loss:1.026
# Checking accuracy on validation set
# Got 667 / 1000 correct (66.70)
# 6 epoch,  5000 iteration, loss:1.026
# Checking accuracy on validation set
# Got 668 / 1000 correct (66.80)
# 6 epoch,  6000 iteration, loss:1.054
# Checking accuracy on validation set
# Got 654 / 1000 correct (65.40)
# 6 epoch,  7000 iteration, loss:1.014
# Checking accuracy on validation set
# Got 674 / 1000 correct (67.40)
# 6 epoch,  8000 iteration, loss:0.995
# Checking accuracy on validation set
# Got 676 / 1000 correct (67.60)
# 6 epoch,  9000 iteration, loss:1.026
# Checking accuracy on validation set
# Got 684 / 1000 correct (68.40)
# 6 epoch, 10000 iteration, loss:0.992
# Checking accuracy on validation set
# Got 682 / 1000 correct (68.20)
# 6 epoch, 11000 iteration, loss:0.972
# Checking accuracy on validation set
# Got 679 / 1000 correct (67.90)
# 6 epoch, 12000 iteration, loss:0.976
#  num 5 epoch
# ####### Training Loss #######
# [0.99302208]
# Checking accuracy on validation set
# Got 680 / 1000 correct (68.00)
# 7 epoch,  1000 iteration, loss:0.937
# Checking accuracy on validation set
# Got 681 / 1000 correct (68.10)
# 7 epoch,  2000 iteration, loss:0.928
# Checking accuracy on validation set
# Got 650 / 1000 correct (65.00)
# 7 epoch,  3000 iteration, loss:0.942
# Checking accuracy on validation set
# Got 675 / 1000 correct (67.50)
# 7 epoch,  4000 iteration, loss:0.953
# Checking accuracy on validation set
# Got 665 / 1000 correct (66.50)
# 7 epoch,  5000 iteration, loss:0.938
# Checking accuracy on validation set
# Got 706 / 1000 correct (70.60)
# 7 epoch,  6000 iteration, loss:0.952
# Checking accuracy on validation set
# Got 723 / 1000 correct (72.30)
# 7 epoch,  7000 iteration, loss:0.931
# Checking accuracy on validation set
# Got 659 / 1000 correct (65.90)
# 7 epoch,  8000 iteration, loss:0.929
# Checking accuracy on validation set
# Got 692 / 1000 correct (69.20)
# 7 epoch,  9000 iteration, loss:0.923
# Checking accuracy on validation set
# Got 672 / 1000 correct (67.20)
# 7 epoch, 10000 iteration, loss:0.916
# Checking accuracy on validation set
# Got 700 / 1000 correct (70.00)
# 7 epoch, 11000 iteration, loss:0.903
# Checking accuracy on validation set
# Got 696 / 1000 correct (69.60)
# 7 epoch, 12000 iteration, loss:0.917
#  num 6 epoch
# ####### Training Loss #######
# [0.91079561]
# Checking accuracy on validation set
# Got 702 / 1000 correct (70.20)
# 8 epoch,  1000 iteration, loss:0.875
# Checking accuracy on validation set
# Got 701 / 1000 correct (70.10)
# 8 epoch,  2000 iteration, loss:0.872
# Checking accuracy on validation set
# Got 683 / 1000 correct (68.30)
# 8 epoch,  3000 iteration, loss:0.888
# Checking accuracy on validation set
# Got 701 / 1000 correct (70.10)
# 8 epoch,  4000 iteration, loss:0.865
# Checking accuracy on validation set
# Got 730 / 1000 correct (73.00)
# 8 epoch,  5000 iteration, loss:0.902
# Checking accuracy on validation set
# Got 683 / 1000 correct (68.30)
# 8 epoch,  6000 iteration, loss:0.856
# Checking accuracy on validation set
# Got 709 / 1000 correct (70.90)
# 8 epoch,  7000 iteration, loss:0.900
# Checking accuracy on validation set
# Got 733 / 1000 correct (73.30)
# 8 epoch,  8000 iteration, loss:0.861
# Checking accuracy on validation set
# Got 726 / 1000 correct (72.60)
# 8 epoch,  9000 iteration, loss:0.841
# Checking accuracy on validation set
# Got 701 / 1000 correct (70.10)
# 8 epoch, 10000 iteration, loss:0.857
# Checking accuracy on validation set
# Got 733 / 1000 correct (73.30)
# 8 epoch, 11000 iteration, loss:0.863
# Checking accuracy on validation set
# Got 689 / 1000 correct (68.90)
# 8 epoch, 12000 iteration, loss:0.831
#  num 7 epoch
# ####### Training Loss #######
# [0.84922286]
# Checking accuracy on validation set
# Got 732 / 1000 correct (73.20)
# 9 epoch,  1000 iteration, loss:0.805
# Checking accuracy on validation set
# Got 704 / 1000 correct (70.40)
# 9 epoch,  2000 iteration, loss:0.816
# Checking accuracy on validation set
# Got 723 / 1000 correct (72.30)
# 9 epoch,  3000 iteration, loss:0.833
# Checking accuracy on validation set
# Got 705 / 1000 correct (70.50)
# 9 epoch,  4000 iteration, loss:0.827
# Checking accuracy on validation set
# Got 758 / 1000 correct (75.80)
# 9 epoch,  5000 iteration, loss:0.816
# Checking accuracy on validation set
# Got 734 / 1000 correct (73.40)
# 9 epoch,  6000 iteration, loss:0.839
# Checking accuracy on validation set
# Got 734 / 1000 correct (73.40)
# 9 epoch,  7000 iteration, loss:0.807
# Checking accuracy on validation set
# Got 731 / 1000 correct (73.10)
# 9 epoch,  8000 iteration, loss:0.826
# Checking accuracy on validation set
# Got 752 / 1000 correct (75.20)
# 9 epoch,  9000 iteration, loss:0.779
# Checking accuracy on validation set
# Got 730 / 1000 correct (73.00)
# 9 epoch, 10000 iteration, loss:0.823
# Checking accuracy on validation set
# Got 723 / 1000 correct (72.30)
# 9 epoch, 11000 iteration, loss:0.805
# Checking accuracy on validation set
# Got 737 / 1000 correct (73.70)
# 9 epoch, 12000 iteration, loss:0.807
#  num 8 epoch
# ####### Training Loss #######
# [0.79801298]
# Checking accuracy on validation set
# Got 736 / 1000 correct (73.60)
# 10 epoch,  1000 iteration, loss:0.782
# Checking accuracy on validation set
# Got 745 / 1000 correct (74.50)
# 10 epoch,  2000 iteration, loss:0.784
# Checking accuracy on validation set
# Got 743 / 1000 correct (74.30)
# 10 epoch,  3000 iteration, loss:0.799
# Checking accuracy on validation set
# Got 750 / 1000 correct (75.00)
# 10 epoch,  4000 iteration, loss:0.754
# Checking accuracy on validation set
# Got 746 / 1000 correct (74.60)
# 10 epoch,  5000 iteration, loss:0.740
# Checking accuracy on validation set
# Got 735 / 1000 correct (73.50)
# 10 epoch,  6000 iteration, loss:0.777
# Checking accuracy on validation set
# Got 753 / 1000 correct (75.30)
# 10 epoch,  7000 iteration, loss:0.764
# Checking accuracy on validation set
# Got 752 / 1000 correct (75.20)
# 10 epoch,  8000 iteration, loss:0.771
# Checking accuracy on validation set
# Got 756 / 1000 correct (75.60)
# 10 epoch,  9000 iteration, loss:0.759
# Checking accuracy on validation set
# Got 743 / 1000 correct (74.30)
# 10 epoch, 10000 iteration, loss:0.768
# Checking accuracy on validation set
# Got 757 / 1000 correct (75.70)
# 10 epoch, 11000 iteration, loss:0.793
# Checking accuracy on validation set
# Got 737 / 1000 correct (73.70)
# 10 epoch, 12000 iteration, loss:0.798
#  num 9 epoch
# ####### Training Loss #######
# [0.7585179]
# Checking accuracy on validation set
# Got 761 / 1000 correct (76.10)
# 11 epoch,  1000 iteration, loss:0.742
# Checking accuracy on validation set
# Got 745 / 1000 correct (74.50)
# 11 epoch,  2000 iteration, loss:0.739
# Checking accuracy on validation set
# Got 736 / 1000 correct (73.60)
# 11 epoch,  3000 iteration, loss:0.745
# Checking accuracy on validation set
# Got 758 / 1000 correct (75.80)
# 11 epoch,  4000 iteration, loss:0.736
# Checking accuracy on validation set
# Got 719 / 1000 correct (71.90)
# 11 epoch,  5000 iteration, loss:0.741
# Checking accuracy on validation set
# Got 754 / 1000 correct (75.40)
# 11 epoch,  6000 iteration, loss:0.731
# Checking accuracy on validation set
# Got 747 / 1000 correct (74.70)
# 11 epoch,  7000 iteration, loss:0.736
# Checking accuracy on validation set
# Got 733 / 1000 correct (73.30)
# 11 epoch,  8000 iteration, loss:0.753
# Checking accuracy on validation set
# Got 767 / 1000 correct (76.70)
# 11 epoch,  9000 iteration, loss:0.758
# Checking accuracy on validation set
# Got 736 / 1000 correct (73.60)
# 11 epoch, 10000 iteration, loss:0.729
# Checking accuracy on validation set
# Got 774 / 1000 correct (77.40)
# 11 epoch, 11000 iteration, loss:0.743
# Checking accuracy on validation set
# Got 758 / 1000 correct (75.80)
# 11 epoch, 12000 iteration, loss:0.747
#  num 10 epoch
# ####### Training Loss #######
# [0.7267062]
# Checking accuracy on validation set
# Got 757 / 1000 correct (75.70)
# 12 epoch,  1000 iteration, loss:0.692
# Checking accuracy on validation set
# Got 752 / 1000 correct (75.20)
# 12 epoch,  2000 iteration, loss:0.692
# Checking accuracy on validation set
# Got 748 / 1000 correct (74.80)
# 12 epoch,  3000 iteration, loss:0.712
# Checking accuracy on validation set
# Got 763 / 1000 correct (76.30)
# 12 epoch,  4000 iteration, loss:0.713
# Checking accuracy on validation set
# Got 773 / 1000 correct (77.30)
# 12 epoch,  5000 iteration, loss:0.718
# Checking accuracy on validation set
# Got 759 / 1000 correct (75.90)
# 12 epoch,  6000 iteration, loss:0.725
# Checking accuracy on validation set
# Got 755 / 1000 correct (75.50)
# 12 epoch,  7000 iteration, loss:0.707
# Checking accuracy on validation set
# Got 755 / 1000 correct (75.50)
# 12 epoch,  8000 iteration, loss:0.694
# Checking accuracy on validation set
# Got 746 / 1000 correct (74.60)
# 12 epoch,  9000 iteration, loss:0.727
# Checking accuracy on validation set
# Got 771 / 1000 correct (77.10)
# 12 epoch, 10000 iteration, loss:0.702
# Checking accuracy on validation set
# Got 748 / 1000 correct (74.80)
# 12 epoch, 11000 iteration, loss:0.707
# Checking accuracy on validation set
# Got 769 / 1000 correct (76.90)
# 12 epoch, 12000 iteration, loss:0.726
#  num 11 epoch
# ####### Training Loss #######
# [0.69540735]
# Checking accuracy on validation set
# Got 757 / 1000 correct (75.70)
# 13 epoch,  1000 iteration, loss:0.687
# Checking accuracy on validation set
# Got 754 / 1000 correct (75.40)
# 13 epoch,  2000 iteration, loss:0.669
# Checking accuracy on validation set
# Got 752 / 1000 correct (75.20)
# 13 epoch,  3000 iteration, loss:0.714
# Checking accuracy on validation set
# Got 756 / 1000 correct (75.60)
# 13 epoch,  4000 iteration, loss:0.656
# Checking accuracy on validation set
# Got 773 / 1000 correct (77.30)
# 13 epoch,  5000 iteration, loss:0.677
# Checking accuracy on validation set
# Got 730 / 1000 correct (73.00)
# 13 epoch,  6000 iteration, loss:0.694
# Checking accuracy on validation set
# Got 750 / 1000 correct (75.00)
# 13 epoch,  7000 iteration, loss:0.695
# Checking accuracy on validation set
# Got 754 / 1000 correct (75.40)
# 13 epoch,  8000 iteration, loss:0.714
# Checking accuracy on validation set
# Got 767 / 1000 correct (76.70)
# 13 epoch,  9000 iteration, loss:0.686
# Checking accuracy on validation set
# Got 778 / 1000 correct (77.80)
# 13 epoch, 10000 iteration, loss:0.723
# Checking accuracy on validation set
# Got 749 / 1000 correct (74.90)
# 13 epoch, 11000 iteration, loss:0.681
# Checking accuracy on validation set
# Got 769 / 1000 correct (76.90)
# 13 epoch, 12000 iteration, loss:0.677
#  num 12 epoch
# ####### Training Loss #######
# [0.67590672]
# Checking accuracy on validation set
# Got 759 / 1000 correct (75.90)
# 14 epoch,  1000 iteration, loss:0.632
# Checking accuracy on validation set
# Got 772 / 1000 correct (77.20)
# 14 epoch,  2000 iteration, loss:0.673
# Checking accuracy on validation set
# Got 787 / 1000 correct (78.70)
# 14 epoch,  3000 iteration, loss:0.659
# Checking accuracy on validation set
# Got 790 / 1000 correct (79.00)
# 14 epoch,  4000 iteration, loss:0.647
# Checking accuracy on validation set
# Got 784 / 1000 correct (78.40)
# 14 epoch,  5000 iteration, loss:0.664
# Checking accuracy on validation set
# Got 775 / 1000 correct (77.50)
# 14 epoch,  6000 iteration, loss:0.658
# Checking accuracy on validation set
# Got 782 / 1000 correct (78.20)
# 14 epoch,  7000 iteration, loss:0.681
# Checking accuracy on validation set
# Got 732 / 1000 correct (73.20)
# 14 epoch,  8000 iteration, loss:0.665
# Checking accuracy on validation set
# Got 736 / 1000 correct (73.60)
# 14 epoch,  9000 iteration, loss:0.674
# Checking accuracy on validation set
# Got 758 / 1000 correct (75.80)
# 14 epoch, 10000 iteration, loss:0.654
# Checking accuracy on validation set
# Got 785 / 1000 correct (78.50)
# 14 epoch, 11000 iteration, loss:0.683
# Checking accuracy on validation set
# Got 794 / 1000 correct (79.40)
# 14 epoch, 12000 iteration, loss:0.675
#  num 13 epoch
# ####### Training Loss #######
# [0.65056904]
# Checking accuracy on validation set
# Got 770 / 1000 correct (77.00)
# 15 epoch,  1000 iteration, loss:0.659
# Checking accuracy on validation set
# Got 792 / 1000 correct (79.20)
# 15 epoch,  2000 iteration, loss:0.630
# Checking accuracy on validation set
# Got 762 / 1000 correct (76.20)
# 15 epoch,  3000 iteration, loss:0.633
# Checking accuracy on validation set
# Got 774 / 1000 correct (77.40)
# 15 epoch,  4000 iteration, loss:0.632
# Checking accuracy on validation set
# Got 773 / 1000 correct (77.30)
# 15 epoch,  5000 iteration, loss:0.632
# Checking accuracy on validation set
# Got 777 / 1000 correct (77.70)
# 15 epoch,  6000 iteration, loss:0.635
# Checking accuracy on validation set
# Got 777 / 1000 correct (77.70)
# 15 epoch,  7000 iteration, loss:0.650
# Checking accuracy on validation set
# Got 757 / 1000 correct (75.70)
# 15 epoch,  8000 iteration, loss:0.642
# Checking accuracy on validation set
# Got 770 / 1000 correct (77.00)
# 15 epoch,  9000 iteration, loss:0.636
# Checking accuracy on validation set
# Got 794 / 1000 correct (79.40)
# 15 epoch, 10000 iteration, loss:0.661
# Checking accuracy on validation set
# Got 747 / 1000 correct (74.70)
# 15 epoch, 11000 iteration, loss:0.666
# Checking accuracy on validation set
# Got 790 / 1000 correct (79.00)
# 15 epoch, 12000 iteration, loss:0.642
#  num 14 epoch
# ####### Training Loss #######
# [0.62958207]
# Checking accuracy on validation set
# Got 775 / 1000 correct (77.50)
# 16 epoch,  1000 iteration, loss:0.604
# Checking accuracy on validation set
# Got 772 / 1000 correct (77.20)
# 16 epoch,  2000 iteration, loss:0.618
# Checking accuracy on validation set
# Got 791 / 1000 correct (79.10)
# 16 epoch,  3000 iteration, loss:0.615
# Checking accuracy on validation set
# Got 776 / 1000 correct (77.60)
# 16 epoch,  4000 iteration, loss:0.623
# Checking accuracy on validation set
# Got 800 / 1000 correct (80.00)
# 16 epoch,  5000 iteration, loss:0.638
# Checking accuracy on validation set
# Got 792 / 1000 correct (79.20)
# 16 epoch,  6000 iteration, loss:0.625
# Checking accuracy on validation set
# Got 778 / 1000 correct (77.80)
# 16 epoch,  7000 iteration, loss:0.622
# Checking accuracy on validation set
# Got 784 / 1000 correct (78.40)
# 16 epoch,  8000 iteration, loss:0.622
# Checking accuracy on validation set
# Got 803 / 1000 correct (80.30)
# 16 epoch,  9000 iteration, loss:0.671
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
# 16 epoch, 10000 iteration, loss:0.652
# Checking accuracy on validation set
# Got 776 / 1000 correct (77.60)
# 16 epoch, 11000 iteration, loss:0.639
# Checking accuracy on validation set
# Got 769 / 1000 correct (76.90)
# 16 epoch, 12000 iteration, loss:0.622
#  num 15 epoch
# ####### Training Loss #######
# [0.61712139]
# Checking accuracy on validation set
# Got 789 / 1000 correct (78.90)
# 17 epoch,  1000 iteration, loss:0.585
# Checking accuracy on validation set
# Got 781 / 1000 correct (78.10)
# 17 epoch,  2000 iteration, loss:0.588
# Checking accuracy on validation set
# Got 771 / 1000 correct (77.10)
# 17 epoch,  3000 iteration, loss:0.587
# Checking accuracy on validation set
# Got 771 / 1000 correct (77.10)
# 17 epoch,  4000 iteration, loss:0.606
# Checking accuracy on validation set
# Got 736 / 1000 correct (73.60)
# 17 epoch,  5000 iteration, loss:0.579
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
# 17 epoch,  6000 iteration, loss:0.637
# Checking accuracy on validation set
# Got 810 / 1000 correct (81.00)
# 17 epoch,  7000 iteration, loss:0.624
# Checking accuracy on validation set
# Got 799 / 1000 correct (79.90)
# 17 epoch,  8000 iteration, loss:0.607
# Checking accuracy on validation set
# Got 793 / 1000 correct (79.30)
# 17 epoch,  9000 iteration, loss:0.616
# Checking accuracy on validation set
# Got 765 / 1000 correct (76.50)
# 17 epoch, 10000 iteration, loss:0.609
# Checking accuracy on validation set
# Got 779 / 1000 correct (77.90)
# 17 epoch, 11000 iteration, loss:0.625
# Checking accuracy on validation set
# Got 755 / 1000 correct (75.50)
# 17 epoch, 12000 iteration, loss:0.622
#  num 16 epoch
# ####### Training Loss #######
# [0.59559902]
# Checking accuracy on validation set
# Got 781 / 1000 correct (78.10)
# 18 epoch,  1000 iteration, loss:0.566
# Checking accuracy on validation set
# Got 787 / 1000 correct (78.70)
# 18 epoch,  2000 iteration, loss:0.596
# Checking accuracy on validation set
# Got 803 / 1000 correct (80.30)
# 18 epoch,  3000 iteration, loss:0.577
# Checking accuracy on validation set
# Got 798 / 1000 correct (79.80)
# 18 epoch,  4000 iteration, loss:0.598
# Checking accuracy on validation set
# Got 792 / 1000 correct (79.20)
# 18 epoch,  5000 iteration, loss:0.599
# Checking accuracy on validation set
# Got 800 / 1000 correct (80.00)
# 18 epoch,  6000 iteration, loss:0.595
# Checking accuracy on validation set
# Got 773 / 1000 correct (77.30)
# 18 epoch,  7000 iteration, loss:0.623
# Checking accuracy on validation set
# Got 815 / 1000 correct (81.50)
# 18 epoch,  8000 iteration, loss:0.575
# Checking accuracy on validation set
# Got 800 / 1000 correct (80.00)
# 18 epoch,  9000 iteration, loss:0.625
# Checking accuracy on validation set
# Got 754 / 1000 correct (75.40)
# 18 epoch, 10000 iteration, loss:0.613
# Checking accuracy on validation set
# Got 791 / 1000 correct (79.10)
# 18 epoch, 11000 iteration, loss:0.589
# Checking accuracy on validation set
# Got 789 / 1000 correct (78.90)
# 18 epoch, 12000 iteration, loss:0.612
#  num 17 epoch
# ####### Training Loss #######
# [0.58640287]
# Checking accuracy on validation set
# Got 805 / 1000 correct (80.50)
# 19 epoch,  1000 iteration, loss:0.547
# Checking accuracy on validation set
# Got 785 / 1000 correct (78.50)
# 19 epoch,  2000 iteration, loss:0.583
# Checking accuracy on validation set
# Got 772 / 1000 correct (77.20)
# 19 epoch,  3000 iteration, loss:0.581
# Checking accuracy on validation set
# Got 782 / 1000 correct (78.20)
# 19 epoch,  4000 iteration, loss:0.551
# Checking accuracy on validation set
# Got 800 / 1000 correct (80.00)
# 19 epoch,  5000 iteration, loss:0.582
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
# 19 epoch,  6000 iteration, loss:0.612
# Checking accuracy on validation set
# Got 783 / 1000 correct (78.30)
# 19 epoch,  7000 iteration, loss:0.593
# Checking accuracy on validation set
# Got 783 / 1000 correct (78.30)
# 19 epoch,  8000 iteration, loss:0.585
# Checking accuracy on validation set
# Got 778 / 1000 correct (77.80)
# 19 epoch,  9000 iteration, loss:0.582
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
# 19 epoch, 10000 iteration, loss:0.578
# Checking accuracy on validation set
# Got 777 / 1000 correct (77.70)
# 19 epoch, 11000 iteration, loss:0.596
# Checking accuracy on validation set
# Got 792 / 1000 correct (79.20)
# 19 epoch, 12000 iteration, loss:0.600
#  num 18 epoch
# ####### Training Loss #######
# [0.5698952]
# Checking accuracy on validation set
# Got 793 / 1000 correct (79.30)
# 20 epoch,  1000 iteration, loss:0.535
# Checking accuracy on validation set
# Got 801 / 1000 correct (80.10)
# 20 epoch,  2000 iteration, loss:0.570
# Checking accuracy on validation set
# Got 792 / 1000 correct (79.20)
# 20 epoch,  3000 iteration, loss:0.569
# Checking accuracy on validation set
# Got 753 / 1000 correct (75.30)
# 20 epoch,  4000 iteration, loss:0.584
# Checking accuracy on validation set
# Got 801 / 1000 correct (80.10)
# 20 epoch,  5000 iteration, loss:0.540
# Checking accuracy on validation set
# Got 782 / 1000 correct (78.20)
# 20 epoch,  6000 iteration, loss:0.560
# Checking accuracy on validation set
# Got 803 / 1000 correct (80.30)
# 20 epoch,  7000 iteration, loss:0.583
# Checking accuracy on validation set
# Got 788 / 1000 correct (78.80)
# 20 epoch,  8000 iteration, loss:0.557
# Checking accuracy on validation set
# Got 786 / 1000 correct (78.60)
# 20 epoch,  9000 iteration, loss:0.587
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
# 20 epoch, 10000 iteration, loss:0.584
# Checking accuracy on validation set
# Got 816 / 1000 correct (81.60)
# 20 epoch, 11000 iteration, loss:0.579
# Checking accuracy on validation set
# Got 786 / 1000 correct (78.60)
# 20 epoch, 12000 iteration, loss:0.547
#  num 19 epoch
# ####### Training Loss #######
# [0.55523578]
# Checking accuracy on validation set
# Got 787 / 1000 correct (78.70)
# 21 epoch,  1000 iteration, loss:0.518
# Checking accuracy on validation set
# Got 775 / 1000 correct (77.50)
# 21 epoch,  2000 iteration, loss:0.579
# Checking accuracy on validation set
# Got 770 / 1000 correct (77.00)
# 21 epoch,  3000 iteration, loss:0.527
# Checking accuracy on validation set
# Got 789 / 1000 correct (78.90)
# 21 epoch,  4000 iteration, loss:0.552
# Checking accuracy on validation set
# Got 799 / 1000 correct (79.90)
# 21 epoch,  5000 iteration, loss:0.576
# Checking accuracy on validation set
# Got 794 / 1000 correct (79.40)
# 21 epoch,  6000 iteration, loss:0.549
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
# 21 epoch,  7000 iteration, loss:0.587
# Checking accuracy on validation set
# Got 796 / 1000 correct (79.60)
# 21 epoch,  8000 iteration, loss:0.536
# Checking accuracy on validation set
# Got 775 / 1000 correct (77.50)
# 21 epoch,  9000 iteration, loss:0.560
# Checking accuracy on validation set
# Got 778 / 1000 correct (77.80)
# 21 epoch, 10000 iteration, loss:0.559
# Checking accuracy on validation set
# Got 800 / 1000 correct (80.00)
# 21 epoch, 11000 iteration, loss:0.568
# Checking accuracy on validation set
# Got 792 / 1000 correct (79.20)
# 21 epoch, 12000 iteration, loss:0.584
#  num 20 epoch
# ####### Training Loss #######
# [0.5472543]
# Checking accuracy on validation set
# Got 775 / 1000 correct (77.50)
# 22 epoch,  1000 iteration, loss:0.529
# Checking accuracy on validation set
# Got 799 / 1000 correct (79.90)
# 22 epoch,  2000 iteration, loss:0.551
# Checking accuracy on validation set
# Got 791 / 1000 correct (79.10)
# 22 epoch,  3000 iteration, loss:0.510
# Checking accuracy on validation set
# Got 792 / 1000 correct (79.20)
# 22 epoch,  4000 iteration, loss:0.553
# Checking accuracy on validation set
# Got 810 / 1000 correct (81.00)
# 22 epoch,  5000 iteration, loss:0.562
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
# 22 epoch,  6000 iteration, loss:0.552
# Checking accuracy on validation set
# Got 794 / 1000 correct (79.40)
# 22 epoch,  7000 iteration, loss:0.553
# Checking accuracy on validation set
# Got 801 / 1000 correct (80.10)
# 22 epoch,  8000 iteration, loss:0.555
# Checking accuracy on validation set
# Got 800 / 1000 correct (80.00)
# 22 epoch,  9000 iteration, loss:0.579
# Checking accuracy on validation set
# Got 806 / 1000 correct (80.60)
# 22 epoch, 10000 iteration, loss:0.567
# Checking accuracy on validation set
# Got 807 / 1000 correct (80.70)
# 22 epoch, 11000 iteration, loss:0.548
# Checking accuracy on validation set
# Got 803 / 1000 correct (80.30)
# 22 epoch, 12000 iteration, loss:0.566
#  num 21 epoch
# ####### Training Loss #######
# [0.5408713]
# Checking accuracy on validation set
# Got 772 / 1000 correct (77.20)
# 23 epoch,  1000 iteration, loss:0.509
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
# 23 epoch,  2000 iteration, loss:0.507
# Checking accuracy on validation set
# Got 792 / 1000 correct (79.20)
# 23 epoch,  3000 iteration, loss:0.523
# Checking accuracy on validation set
# Got 813 / 1000 correct (81.30)
# 23 epoch,  4000 iteration, loss:0.523
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
# 23 epoch,  5000 iteration, loss:0.540
# Checking accuracy on validation set
# Got 796 / 1000 correct (79.60)
# 23 epoch,  6000 iteration, loss:0.562
# Checking accuracy on validation set
# Got 806 / 1000 correct (80.60)
# 23 epoch,  7000 iteration, loss:0.526
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
# 23 epoch,  8000 iteration, loss:0.533
# Checking accuracy on validation set
# Got 811 / 1000 correct (81.10)
# 23 epoch,  9000 iteration, loss:0.543
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
# 23 epoch, 10000 iteration, loss:0.563
# Checking accuracy on validation set
# Got 805 / 1000 correct (80.50)
# 23 epoch, 11000 iteration, loss:0.556
# Checking accuracy on validation set
# Got 792 / 1000 correct (79.20)
# 23 epoch, 12000 iteration, loss:0.579
#  num 22 epoch
# ####### Training Loss #######
# [0.52827876]
# Checking accuracy on validation set
# Got 810 / 1000 correct (81.00)
# 24 epoch,  1000 iteration, loss:0.488
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
# 24 epoch,  2000 iteration, loss:0.514
# Checking accuracy on validation set
# Got 790 / 1000 correct (79.00)
# 24 epoch,  3000 iteration, loss:0.514
# Checking accuracy on validation set
# Got 818 / 1000 correct (81.80)
# 24 epoch,  4000 iteration, loss:0.524
# Checking accuracy on validation set
# Got 792 / 1000 correct (79.20)
# 24 epoch,  5000 iteration, loss:0.525
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
# 24 epoch,  6000 iteration, loss:0.542
# Checking accuracy on validation set
# Got 802 / 1000 correct (80.20)
# 24 epoch,  7000 iteration, loss:0.529
# Checking accuracy on validation set
# Got 800 / 1000 correct (80.00)
# 24 epoch,  8000 iteration, loss:0.547
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
# 24 epoch,  9000 iteration, loss:0.544
# Checking accuracy on validation set
# Got 805 / 1000 correct (80.50)
# 24 epoch, 10000 iteration, loss:0.547
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
# 24 epoch, 11000 iteration, loss:0.550
# Checking accuracy on validation set
# Got 810 / 1000 correct (81.00)
# 24 epoch, 12000 iteration, loss:0.552
#  num 23 epoch
# ####### Training Loss #######
# [0.52014438]
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
# 25 epoch,  1000 iteration, loss:0.495
# Checking accuracy on validation set
# Got 799 / 1000 correct (79.90)
# 25 epoch,  2000 iteration, loss:0.501
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
# 25 epoch,  3000 iteration, loss:0.486
# Checking accuracy on validation set
# Got 796 / 1000 correct (79.60)
# 25 epoch,  4000 iteration, loss:0.519
# Checking accuracy on validation set
# Got 805 / 1000 correct (80.50)
# 25 epoch,  5000 iteration, loss:0.519
# Checking accuracy on validation set
# Got 788 / 1000 correct (78.80)
# 25 epoch,  6000 iteration, loss:0.521
# Checking accuracy on validation set
# Got 790 / 1000 correct (79.00)
# 25 epoch,  7000 iteration, loss:0.525
# Checking accuracy on validation set
# Got 775 / 1000 correct (77.50)
# 25 epoch,  8000 iteration, loss:0.517
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
# 25 epoch,  9000 iteration, loss:0.533
# Checking accuracy on validation set
# Got 819 / 1000 correct (81.90)
# 25 epoch, 10000 iteration, loss:0.537
# Checking accuracy on validation set
# Got 787 / 1000 correct (78.70)
# 25 epoch, 11000 iteration, loss:0.539
# Checking accuracy on validation set
# Got 805 / 1000 correct (80.50)
# 25 epoch, 12000 iteration, loss:0.539
#  num 24 epoch
# ####### Training Loss #######
# [0.50878384]
# Checking accuracy on validation set
# Got 801 / 1000 correct (80.10)
# 26 epoch,  1000 iteration, loss:0.486
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
# 26 epoch,  2000 iteration, loss:0.520
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
# 26 epoch,  3000 iteration, loss:0.483
# Checking accuracy on validation set
# Got 818 / 1000 correct (81.80)
# 26 epoch,  4000 iteration, loss:0.495
# Checking accuracy on validation set
# Got 786 / 1000 correct (78.60)
# 26 epoch,  5000 iteration, loss:0.517
# Checking accuracy on validation set
# Got 800 / 1000 correct (80.00)
# 26 epoch,  6000 iteration, loss:0.505
# Checking accuracy on validation set
# Got 815 / 1000 correct (81.50)
# 26 epoch,  7000 iteration, loss:0.515
# Checking accuracy on validation set
# Got 788 / 1000 correct (78.80)
# 26 epoch,  8000 iteration, loss:0.502
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
# 26 epoch,  9000 iteration, loss:0.500
# Checking accuracy on validation set
# Got 786 / 1000 correct (78.60)
# 26 epoch, 10000 iteration, loss:0.545
# Checking accuracy on validation set
# Got 818 / 1000 correct (81.80)
# 26 epoch, 11000 iteration, loss:0.509
# Checking accuracy on validation set
# Got 783 / 1000 correct (78.30)
# 26 epoch, 12000 iteration, loss:0.535
#  num 25 epoch
# ####### Training Loss #######
# [0.49913706]
# Checking accuracy on validation set
# Got 816 / 1000 correct (81.60)
# 27 epoch,  1000 iteration, loss:0.489
# Checking accuracy on validation set
# Got 790 / 1000 correct (79.00)
# 27 epoch,  2000 iteration, loss:0.503
# Checking accuracy on validation set
# Got 815 / 1000 correct (81.50)
# 27 epoch,  3000 iteration, loss:0.508
# Checking accuracy on validation set
# Got 819 / 1000 correct (81.90)
# 27 epoch,  4000 iteration, loss:0.498
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
# 27 epoch,  5000 iteration, loss:0.495
# Checking accuracy on validation set
# Got 802 / 1000 correct (80.20)
# 27 epoch,  6000 iteration, loss:0.500
# Checking accuracy on validation set
# Got 794 / 1000 correct (79.40)
# 27 epoch,  7000 iteration, loss:0.491
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
# 27 epoch,  8000 iteration, loss:0.524
# Checking accuracy on validation set
# Got 801 / 1000 correct (80.10)
# 27 epoch,  9000 iteration, loss:0.508
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
# 27 epoch, 10000 iteration, loss:0.514
# Checking accuracy on validation set
# Got 791 / 1000 correct (79.10)
# 27 epoch, 11000 iteration, loss:0.517
# Checking accuracy on validation set
# Got 796 / 1000 correct (79.60)
# 27 epoch, 12000 iteration, loss:0.528
#  num 26 epoch
# ####### Training Loss #######
# [0.49589632]
# Checking accuracy on validation set
# Got 802 / 1000 correct (80.20)
# 28 epoch,  1000 iteration, loss:0.457
# Checking accuracy on validation set
# Got 817 / 1000 correct (81.70)
# 28 epoch,  2000 iteration, loss:0.480
# Checking accuracy on validation set
# Got 811 / 1000 correct (81.10)
# 28 epoch,  3000 iteration, loss:0.478
# Checking accuracy on validation set
# Got 790 / 1000 correct (79.00)
# 28 epoch,  4000 iteration, loss:0.498
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
# 28 epoch,  5000 iteration, loss:0.497
# Checking accuracy on validation set
# Got 801 / 1000 correct (80.10)
# 28 epoch,  6000 iteration, loss:0.504
# Checking accuracy on validation set
# Got 790 / 1000 correct (79.00)
# 28 epoch,  7000 iteration, loss:0.510
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
# 28 epoch,  8000 iteration, loss:0.472
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
# 28 epoch,  9000 iteration, loss:0.532
# Checking accuracy on validation set
# Got 811 / 1000 correct (81.10)
# 28 epoch, 10000 iteration, loss:0.491
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
# 28 epoch, 11000 iteration, loss:0.510
# Checking accuracy on validation set
# Got 784 / 1000 correct (78.40)
# 28 epoch, 12000 iteration, loss:0.490
#  num 27 epoch
# ####### Training Loss #######
# [0.48531755]
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
# 29 epoch,  1000 iteration, loss:0.450
# Checking accuracy on validation set
# Got 816 / 1000 correct (81.60)
# 29 epoch,  2000 iteration, loss:0.480
# Checking accuracy on validation set
# Got 791 / 1000 correct (79.10)
# 29 epoch,  3000 iteration, loss:0.464
# Checking accuracy on validation set
# Got 773 / 1000 correct (77.30)
# 29 epoch,  4000 iteration, loss:0.487
# Checking accuracy on validation set
# Got 790 / 1000 correct (79.00)
# 29 epoch,  5000 iteration, loss:0.479
# Checking accuracy on validation set
# Got 787 / 1000 correct (78.70)
# 29 epoch,  6000 iteration, loss:0.493
# Checking accuracy on validation set
# Got 820 / 1000 correct (82.00)
# 29 epoch,  7000 iteration, loss:0.498
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
# 29 epoch,  8000 iteration, loss:0.510
# Checking accuracy on validation set
# Got 806 / 1000 correct (80.60)
# 29 epoch,  9000 iteration, loss:0.508
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
# 29 epoch, 10000 iteration, loss:0.499
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
# 29 epoch, 11000 iteration, loss:0.525
# Checking accuracy on validation set
# Got 792 / 1000 correct (79.20)
# 29 epoch, 12000 iteration, loss:0.507
#  num 28 epoch
# ####### Training Loss #######
# [0.48186678]
# Checking accuracy on validation set
# Got 796 / 1000 correct (79.60)
# 30 epoch,  1000 iteration, loss:0.461
# Checking accuracy on validation set
# Got 818 / 1000 correct (81.80)
# 30 epoch,  2000 iteration, loss:0.460
# Checking accuracy on validation set
# Got 778 / 1000 correct (77.80)
# 30 epoch,  3000 iteration, loss:0.493
# Checking accuracy on validation set
# Got 784 / 1000 correct (78.40)
# 30 epoch,  4000 iteration, loss:0.484
# Checking accuracy on validation set
# Got 793 / 1000 correct (79.30)
# 30 epoch,  5000 iteration, loss:0.476
# Checking accuracy on validation set
# Got 818 / 1000 correct (81.80)
# 30 epoch,  6000 iteration, loss:0.477
# Checking accuracy on validation set
# Got 824 / 1000 correct (82.40)
# 30 epoch,  7000 iteration, loss:0.505
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
# 30 epoch,  8000 iteration, loss:0.467
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
# 30 epoch,  9000 iteration, loss:0.497
# Checking accuracy on validation set
# Got 785 / 1000 correct (78.50)
# 30 epoch, 10000 iteration, loss:0.514
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
# 30 epoch, 11000 iteration, loss:0.530
# Checking accuracy on validation set
# Got 802 / 1000 correct (80.20)
# 30 epoch, 12000 iteration, loss:0.485
#  num 29 epoch
# ####### Training Loss #######
# [0.4785746]
# Checking accuracy on validation set
# Got 820 / 1000 correct (82.00)
# 31 epoch,  1000 iteration, loss:0.445
# Checking accuracy on validation set
# Got 801 / 1000 correct (80.10)
# 31 epoch,  2000 iteration, loss:0.428
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
# 31 epoch,  3000 iteration, loss:0.472
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
# 31 epoch,  4000 iteration, loss:0.473
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
# 31 epoch,  5000 iteration, loss:0.478
# Checking accuracy on validation set
# Got 803 / 1000 correct (80.30)
# 31 epoch,  6000 iteration, loss:0.508
# Checking accuracy on validation set
# Got 811 / 1000 correct (81.10)
# 31 epoch,  7000 iteration, loss:0.496
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
# 31 epoch,  8000 iteration, loss:0.495
# Checking accuracy on validation set
# Got 807 / 1000 correct (80.70)
# 31 epoch,  9000 iteration, loss:0.472
# Checking accuracy on validation set
# Got 790 / 1000 correct (79.00)
# 31 epoch, 10000 iteration, loss:0.513
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
# 31 epoch, 11000 iteration, loss:0.490
# Checking accuracy on validation set
# Got 811 / 1000 correct (81.10)
# 31 epoch, 12000 iteration, loss:0.492
#  num 30 epoch
# ####### Training Loss #######
# [0.47058157]
# Checking accuracy on validation set
# Got 816 / 1000 correct (81.60)
# 32 epoch,  1000 iteration, loss:0.446
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
# 32 epoch,  2000 iteration, loss:0.460
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
# 32 epoch,  3000 iteration, loss:0.446
# Checking accuracy on validation set
# Got 806 / 1000 correct (80.60)
# 32 epoch,  4000 iteration, loss:0.450
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
# 32 epoch,  5000 iteration, loss:0.473
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
# 32 epoch,  6000 iteration, loss:0.474
# Checking accuracy on validation set
# Got 815 / 1000 correct (81.50)
# 32 epoch,  7000 iteration, loss:0.463
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
# 32 epoch,  8000 iteration, loss:0.475
# Checking accuracy on validation set
# Got 807 / 1000 correct (80.70)
# 32 epoch,  9000 iteration, loss:0.512
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
# 32 epoch, 10000 iteration, loss:0.504
# Checking accuracy on validation set
# Got 817 / 1000 correct (81.70)
# 32 epoch, 11000 iteration, loss:0.489
# Checking accuracy on validation set
# Got 830 / 1000 correct (83.00)
# 32 epoch, 12000 iteration, loss:0.478
#  num 31 epoch
# ####### Training Loss #######
# [0.46351553]
# Checking accuracy on validation set
# Got 807 / 1000 correct (80.70)
# 33 epoch,  1000 iteration, loss:0.433
# Checking accuracy on validation set
# Got 834 / 1000 correct (83.40)
# 33 epoch,  2000 iteration, loss:0.440
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
# 33 epoch,  3000 iteration, loss:0.445
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
# 33 epoch,  4000 iteration, loss:0.471
# Checking accuracy on validation set
# Got 807 / 1000 correct (80.70)
# 33 epoch,  5000 iteration, loss:0.464
# Checking accuracy on validation set
# Got 813 / 1000 correct (81.30)
# 33 epoch,  6000 iteration, loss:0.447
# Checking accuracy on validation set
# Got 801 / 1000 correct (80.10)
# 33 epoch,  7000 iteration, loss:0.479
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
# 33 epoch,  8000 iteration, loss:0.472
# Checking accuracy on validation set
# Got 835 / 1000 correct (83.50)
# 33 epoch,  9000 iteration, loss:0.492
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
# 33 epoch, 10000 iteration, loss:0.492
# Checking accuracy on validation set
# Got 807 / 1000 correct (80.70)
# 33 epoch, 11000 iteration, loss:0.501
# Checking accuracy on validation set
# Got 793 / 1000 correct (79.30)
# 33 epoch, 12000 iteration, loss:0.485
#  num 32 epoch
# ####### Training Loss #######
# [0.46018865]
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
# 34 epoch,  1000 iteration, loss:0.441
# Checking accuracy on validation set
# Got 786 / 1000 correct (78.60)
# 34 epoch,  2000 iteration, loss:0.429
# Checking accuracy on validation set
# Got 816 / 1000 correct (81.60)
# 34 epoch,  3000 iteration, loss:0.463
# Checking accuracy on validation set
# Got 815 / 1000 correct (81.50)
# 34 epoch,  4000 iteration, loss:0.440
# Checking accuracy on validation set
# Got 811 / 1000 correct (81.10)
# 34 epoch,  5000 iteration, loss:0.458
# Checking accuracy on validation set
# Got 820 / 1000 correct (82.00)
# 34 epoch,  6000 iteration, loss:0.475
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
# 34 epoch,  7000 iteration, loss:0.487
# Checking accuracy on validation set
# Got 825 / 1000 correct (82.50)
# 34 epoch,  8000 iteration, loss:0.463
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
# 34 epoch,  9000 iteration, loss:0.482
# Checking accuracy on validation set
# Got 792 / 1000 correct (79.20)
# 34 epoch, 10000 iteration, loss:0.483
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
# 34 epoch, 11000 iteration, loss:0.461
# Checking accuracy on validation set
# Got 802 / 1000 correct (80.20)
# 34 epoch, 12000 iteration, loss:0.493
#  num 33 epoch
# ####### Training Loss #######
# [0.45524097]
# Checking accuracy on validation set
# Got 806 / 1000 correct (80.60)
# 35 epoch,  1000 iteration, loss:0.418
# Checking accuracy on validation set
# Got 800 / 1000 correct (80.00)
# 35 epoch,  2000 iteration, loss:0.447
# Checking accuracy on validation set
# Got 816 / 1000 correct (81.60)
# 35 epoch,  3000 iteration, loss:0.438
# Checking accuracy on validation set
# Got 815 / 1000 correct (81.50)
# 35 epoch,  4000 iteration, loss:0.455
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
# 35 epoch,  5000 iteration, loss:0.443
# Checking accuracy on validation set
# Got 788 / 1000 correct (78.80)
# 35 epoch,  6000 iteration, loss:0.470
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
# 35 epoch,  7000 iteration, loss:0.473
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
# 35 epoch,  8000 iteration, loss:0.450
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
# 35 epoch,  9000 iteration, loss:0.479
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
# 35 epoch, 10000 iteration, loss:0.450
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
# 35 epoch, 11000 iteration, loss:0.498
# Checking accuracy on validation set
# Got 782 / 1000 correct (78.20)
# 35 epoch, 12000 iteration, loss:0.484
#  num 34 epoch
# ####### Training Loss #######
# [0.44991685]
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
# 36 epoch,  1000 iteration, loss:0.440
# Checking accuracy on validation set
# Got 819 / 1000 correct (81.90)
# 36 epoch,  2000 iteration, loss:0.427
# Checking accuracy on validation set
# Got 827 / 1000 correct (82.70)
# 36 epoch,  3000 iteration, loss:0.433
# Checking accuracy on validation set
# Got 793 / 1000 correct (79.30)
# 36 epoch,  4000 iteration, loss:0.440
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
# 36 epoch,  5000 iteration, loss:0.469
# Checking accuracy on validation set
# Got 822 / 1000 correct (82.20)
# 36 epoch,  6000 iteration, loss:0.460
# Checking accuracy on validation set
# Got 818 / 1000 correct (81.80)
# 36 epoch,  7000 iteration, loss:0.445
# Checking accuracy on validation set
# Got 800 / 1000 correct (80.00)
# 36 epoch,  8000 iteration, loss:0.456
# Checking accuracy on validation set
# Got 806 / 1000 correct (80.60)
# 36 epoch,  9000 iteration, loss:0.466
# Checking accuracy on validation set
# Got 829 / 1000 correct (82.90)
# 36 epoch, 10000 iteration, loss:0.444
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
# 36 epoch, 11000 iteration, loss:0.460
# Checking accuracy on validation set
# Got 811 / 1000 correct (81.10)
# 36 epoch, 12000 iteration, loss:0.483
#  num 35 epoch
# ####### Training Loss #######
# [0.4435645]
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
# 37 epoch,  1000 iteration, loss:0.424
# Checking accuracy on validation set
# Got 827 / 1000 correct (82.70)
# 37 epoch,  2000 iteration, loss:0.458
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
# 37 epoch,  3000 iteration, loss:0.428
# Checking accuracy on validation set
# Got 801 / 1000 correct (80.10)
# 37 epoch,  4000 iteration, loss:0.459
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
# 37 epoch,  5000 iteration, loss:0.444
# Checking accuracy on validation set
# Got 813 / 1000 correct (81.30)
# 37 epoch,  6000 iteration, loss:0.439
# ...
# 341 epoch,  6000 iteration, loss:0.294
# Checking accuracy on validation set
# Got 811 / 1000 correct (81.10)
# 341 epoch,  7000 iteration, loss:0.293
# Checking accuracy on validation set
# Got 828 / 1000 correct (82.80)
# 341 epoch,  8000 iteration, loss:0.288
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
# 341 epoch,  9000 iteration, loss:0.292
# Checking accuracy on validation set
# Got 805 / 1000 correct (80.50)
# 341 epoch, 10000 iteration, loss:0.284
# Checking accuracy on validation set
# Got 803 / 1000 correct (80.30)
# 341 epoch, 11000 iteration, loss:0.316
# Checking accuracy on validation set
# Got 807 / 1000 correct (80.70)
# 341 epoch, 12000 iteration, loss:0.319
#  num 340 epoch
# ####### Training Loss #######
# [0.2789405]
# Checking accuracy on validation set
# Got 820 / 1000 correct (82.00)
# 342 epoch,  1000 iteration, loss:0.240
# Checking accuracy on validation set
# Got 806 / 1000 correct (80.60)
# 342 epoch,  2000 iteration, loss:0.242
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
# 342 epoch,  3000 iteration, loss:0.289
# Checking accuracy on validation set
# Got 817 / 1000 correct (81.70)
# 342 epoch,  4000 iteration, loss:0.281
# Checking accuracy on validation set
# Got 827 / 1000 correct (82.70)
# 342 epoch,  5000 iteration, loss:0.259
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
# 342 epoch,  6000 iteration, loss:0.288
# Checking accuracy on validation set
# Got 802 / 1000 correct (80.20)
# 342 epoch,  7000 iteration, loss:0.303
# Checking accuracy on validation set
# Got 815 / 1000 correct (81.50)
# 342 epoch,  8000 iteration, loss:0.309
# Checking accuracy on validation set
# Got 827 / 1000 correct (82.70)
# 342 epoch,  9000 iteration, loss:0.305
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
# 342 epoch, 10000 iteration, loss:0.289
# Checking accuracy on validation set
# Got 783 / 1000 correct (78.30)
# 342 epoch, 11000 iteration, loss:0.287
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
# 342 epoch, 12000 iteration, loss:0.304
#  num 341 epoch
# ####### Training Loss #######
# [0.27845052]
# Checking accuracy on validation set
# Got 828 / 1000 correct (82.80)
# 343 epoch,  1000 iteration, loss:0.250
# Checking accuracy on validation set
# Got 825 / 1000 correct (82.50)
# 343 epoch,  2000 iteration, loss:0.233
# Checking accuracy on validation set
# Got 818 / 1000 correct (81.80)
# 343 epoch,  3000 iteration, loss:0.243
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
# 343 epoch,  4000 iteration, loss:0.268
# Checking accuracy on validation set
# Got 819 / 1000 correct (81.90)
# 343 epoch,  5000 iteration, loss:0.278
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
# 343 epoch,  6000 iteration, loss:0.277
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
# 343 epoch,  7000 iteration, loss:0.286
# Checking accuracy on validation set
# Got 780 / 1000 correct (78.00)
# 343 epoch,  8000 iteration, loss:0.276
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
# 343 epoch,  9000 iteration, loss:0.306
# Checking accuracy on validation set
# Got 825 / 1000 correct (82.50)
# 343 epoch, 10000 iteration, loss:0.317
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
# 343 epoch, 11000 iteration, loss:0.325
# Checking accuracy on validation set
# Got 774 / 1000 correct (77.40)
# 343 epoch, 12000 iteration, loss:0.300
#  num 342 epoch
# ####### Training Loss #######
# [0.27549106]
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
# 344 epoch,  1000 iteration, loss:0.242
# Checking accuracy on validation set
# Got 807 / 1000 correct (80.70)
# 344 epoch,  2000 iteration, loss:0.268
# Checking accuracy on validation set
# Got 806 / 1000 correct (80.60)
# 344 epoch,  3000 iteration, loss:0.269
# Checking accuracy on validation set
# Got 816 / 1000 correct (81.60)
# 344 epoch,  4000 iteration, loss:0.240
# Checking accuracy on validation set
# Got 807 / 1000 correct (80.70)
# 344 epoch,  5000 iteration, loss:0.285
# Checking accuracy on validation set
# Got 815 / 1000 correct (81.50)
# 344 epoch,  6000 iteration, loss:0.273
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
# 344 epoch,  7000 iteration, loss:0.290
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
# 344 epoch,  8000 iteration, loss:0.299
# Checking accuracy on validation set
# Got 816 / 1000 correct (81.60)
# 344 epoch,  9000 iteration, loss:0.295
# Checking accuracy on validation set
# Got 796 / 1000 correct (79.60)
# 344 epoch, 10000 iteration, loss:0.304
# Checking accuracy on validation set
# Got 813 / 1000 correct (81.30)
# 344 epoch, 11000 iteration, loss:0.303
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
# 344 epoch, 12000 iteration, loss:0.303
#  num 343 epoch
# ####### Training Loss #######
# [0.27588035]
# Checking accuracy on validation set
# Got 830 / 1000 correct (83.00)
# 345 epoch,  1000 iteration, loss:0.248
# Checking accuracy on validation set
# Got 819 / 1000 correct (81.90)
# 345 epoch,  2000 iteration, loss:0.268
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
# 345 epoch,  3000 iteration, loss:0.249
# Checking accuracy on validation set
# Got 802 / 1000 correct (80.20)
# 345 epoch,  4000 iteration, loss:0.262
# Checking accuracy on validation set
# Got 822 / 1000 correct (82.20)
# 345 epoch,  5000 iteration, loss:0.274
# Checking accuracy on validation set
# Got 781 / 1000 correct (78.10)
# 345 epoch,  6000 iteration, loss:0.282
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
# 345 epoch,  7000 iteration, loss:0.284
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
# 345 epoch,  8000 iteration, loss:0.294
# Checking accuracy on validation set
# Got 806 / 1000 correct (80.60)
# 345 epoch,  9000 iteration, loss:0.312
# Checking accuracy on validation set
# Got 819 / 1000 correct (81.90)
# 345 epoch, 10000 iteration, loss:0.304
# Checking accuracy on validation set
# Got 828 / 1000 correct (82.80)
# 345 epoch, 11000 iteration, loss:0.296
# Checking accuracy on validation set
# Got 807 / 1000 correct (80.70)
# 345 epoch, 12000 iteration, loss:0.295
#  num 344 epoch
# ####### Training Loss #######
# [0.27559939]
# Checking accuracy on validation set
# Got 839 / 1000 correct (83.90)
# 346 epoch,  1000 iteration, loss:0.222
# Checking accuracy on validation set
# Got 817 / 1000 correct (81.70)
# 346 epoch,  2000 iteration, loss:0.261
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
# 346 epoch,  3000 iteration, loss:0.259
# Checking accuracy on validation set
# Got 825 / 1000 correct (82.50)
# 346 epoch,  4000 iteration, loss:0.273
# Checking accuracy on validation set
# Got 817 / 1000 correct (81.70)
# 346 epoch,  5000 iteration, loss:0.279
# Checking accuracy on validation set
# Got 810 / 1000 correct (81.00)
# 346 epoch,  6000 iteration, loss:0.286
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
# 346 epoch,  7000 iteration, loss:0.291
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
# 346 epoch,  8000 iteration, loss:0.304
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
# 346 epoch,  9000 iteration, loss:0.290
# Checking accuracy on validation set
# Got 830 / 1000 correct (83.00)
# 346 epoch, 10000 iteration, loss:0.297
# Checking accuracy on validation set
# Got 829 / 1000 correct (82.90)
# 346 epoch, 11000 iteration, loss:0.301
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
# 346 epoch, 12000 iteration, loss:0.291
#  num 345 epoch
# ####### Training Loss #######
# [0.27471144]
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
# 347 epoch,  1000 iteration, loss:0.233
# Checking accuracy on validation set
# Got 829 / 1000 correct (82.90)
# 347 epoch,  2000 iteration, loss:0.262
# Checking accuracy on validation set
# Got 818 / 1000 correct (81.80)
# 347 epoch,  3000 iteration, loss:0.244
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
# 347 epoch,  4000 iteration, loss:0.262
# Checking accuracy on validation set
# Got 813 / 1000 correct (81.30)
# 347 epoch,  5000 iteration, loss:0.289
# Checking accuracy on validation set
# Got 818 / 1000 correct (81.80)
# 347 epoch,  6000 iteration, loss:0.267
# Checking accuracy on validation set
# Got 817 / 1000 correct (81.70)
# 347 epoch,  7000 iteration, loss:0.287
# Checking accuracy on validation set
# Got 825 / 1000 correct (82.50)
# 347 epoch,  8000 iteration, loss:0.295
# Checking accuracy on validation set
# Got 828 / 1000 correct (82.80)
# 347 epoch,  9000 iteration, loss:0.289
# Checking accuracy on validation set
# Got 819 / 1000 correct (81.90)
# 347 epoch, 10000 iteration, loss:0.302
# Checking accuracy on validation set
# Got 829 / 1000 correct (82.90)
# 347 epoch, 11000 iteration, loss:0.318
# Checking accuracy on validation set
# Got 802 / 1000 correct (80.20)
# 347 epoch, 12000 iteration, loss:0.298
#  num 346 epoch
# ####### Training Loss #######
# [0.2739599]
# Checking accuracy on validation set
# Got 828 / 1000 correct (82.80)
# 348 epoch,  1000 iteration, loss:0.236
# Checking accuracy on validation set
# Got 793 / 1000 correct (79.30)
# 348 epoch,  2000 iteration, loss:0.245
# Checking accuracy on validation set
# Got 820 / 1000 correct (82.00)
# 348 epoch,  3000 iteration, loss:0.265
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
# 348 epoch,  4000 iteration, loss:0.284
# Checking accuracy on validation set
# Got 827 / 1000 correct (82.70)
# 348 epoch,  5000 iteration, loss:0.265
# Checking accuracy on validation set
# Got 813 / 1000 correct (81.30)
# 348 epoch,  6000 iteration, loss:0.277
# Checking accuracy on validation set
# Got 825 / 1000 correct (82.50)
# 348 epoch,  7000 iteration, loss:0.296
# Checking accuracy on validation set
# Got 817 / 1000 correct (81.70)
# 348 epoch,  8000 iteration, loss:0.316
# Checking accuracy on validation set
# Got 840 / 1000 correct (84.00)
# 348 epoch,  9000 iteration, loss:0.287
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
# 348 epoch, 10000 iteration, loss:0.291
# Checking accuracy on validation set
# Got 820 / 1000 correct (82.00)
# 348 epoch, 11000 iteration, loss:0.302
# Checking accuracy on validation set
# Got 819 / 1000 correct (81.90)
# 348 epoch, 12000 iteration, loss:0.310
#  num 347 epoch
# ####### Training Loss #######
# [0.27624831]
# Checking accuracy on validation set
# Got 836 / 1000 correct (83.60)
# 349 epoch,  1000 iteration, loss:0.253
# Checking accuracy on validation set
# Got 796 / 1000 correct (79.60)
# 349 epoch,  2000 iteration, loss:0.246
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
# 349 epoch,  3000 iteration, loss:0.236
# Checking accuracy on validation set
# Got 810 / 1000 correct (81.00)
# 349 epoch,  4000 iteration, loss:0.271
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
# 349 epoch,  5000 iteration, loss:0.255
# Checking accuracy on validation set
# Got 819 / 1000 correct (81.90)
# 349 epoch,  6000 iteration, loss:0.299
# Checking accuracy on validation set
# Got 796 / 1000 correct (79.60)
# 349 epoch,  7000 iteration, loss:0.292
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
# 349 epoch,  8000 iteration, loss:0.286
# Checking accuracy on validation set
# Got 820 / 1000 correct (82.00)
# 349 epoch,  9000 iteration, loss:0.323
# Checking accuracy on validation set
# Got 810 / 1000 correct (81.00)
# 349 epoch, 10000 iteration, loss:0.302
# Checking accuracy on validation set
# Got 824 / 1000 correct (82.40)
# 349 epoch, 11000 iteration, loss:0.298
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
# 349 epoch, 12000 iteration, loss:0.317
#  num 348 epoch
# ####### Training Loss #######
# [0.27692021]
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
# 350 epoch,  1000 iteration, loss:0.217
# Checking accuracy on validation set
# Got 831 / 1000 correct (83.10)
# 350 epoch,  2000 iteration, loss:0.261
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
# 350 epoch,  3000 iteration, loss:0.283
# Checking accuracy on validation set
# Got 830 / 1000 correct (83.00)
# 350 epoch,  4000 iteration, loss:0.268
# Checking accuracy on validation set
# Got 824 / 1000 correct (82.40)
# 350 epoch,  5000 iteration, loss:0.267
# Checking accuracy on validation set
# Got 829 / 1000 correct (82.90)
# 350 epoch,  6000 iteration, loss:0.289
# Checking accuracy on validation set
# Got 799 / 1000 correct (79.90)
# 350 epoch,  7000 iteration, loss:0.276
# Checking accuracy on validation set
# Got 828 / 1000 correct (82.80)
# 350 epoch,  8000 iteration, loss:0.298
# Checking accuracy on validation set
# Got 805 / 1000 correct (80.50)
# 350 epoch,  9000 iteration, loss:0.290
# Checking accuracy on validation set
# Got 822 / 1000 correct (82.20)
# 350 epoch, 10000 iteration, loss:0.317
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
# 350 epoch, 11000 iteration, loss:0.304
# Checking accuracy on validation set
# Got 828 / 1000 correct (82.80)
# 350 epoch, 12000 iteration, loss:0.314
#  num 349 epoch
# ####### Training Loss #######
# [0.27680772]
# finish training
#
# Checking accuracy on test set
# Got 8097 / 10000 correct (80.97)
# #####################################
# Accuracy on testing set 8097.00
# #####################################
# now begin saving datum for next step plotting
# now plotting accuracies and losses
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-c434bd685769> in <module>()
#       7
#       8 help_func.running_model(run_num, net_b, net_name, lr, epoch,
# ----> 9                         loader_train, loader_val, loader_test)
#
# ~/DL_course/midterm-Quant95/Nets/help_func.py in running_model(run_num, net, net_name, lr_list, epoch_list, loader_train, loader_val, loader_test)
#     270     a = np.concatenate(array_epoch_acc)
#     271     a /= 100
# --> 272     length = a.shape[0]
#     273     acc_axis_test = np.array(np.linspace(1,length, num=max_epoch))
#     274     plt.plot(acc_axis_test, a.reshape(-1,1), '--r', label='Test')
#
# ~/Anacondas/anaconda3/envs/cs231n/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2747 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
#    2748     return gca().plot(
# -> 2749         *args, scalex=scalex, scaley=scaley, data=data, **kwargs)
#    2750
#    2751 # Autogenerated by boilerplate.py.  Do not edit as changes will be lost.
#
# ~/Anacondas/anaconda3/envs/cs231n/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1783                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1784                         RuntimeWarning, stacklevel=2)
# -> 1785             return func(ax, *args, **kwargs)
#    1786
#    1787         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/Anacondas/anaconda3/envs/cs231n/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, *args, **kwargs)
#    1602         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
#    1603
# -> 1604         for line in self._get_lines(*args, **kwargs):
#    1605             self.add_line(line)
#    1606             lines.append(line)
#
# ~/Anacondas/anaconda3/envs/cs231n/lib/python3.6/site-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     391                 this += args[0],
#     392                 args = args[1:]
# --> 393             yield from self._plot_args(this, kwargs)
#     394
#     395
#
# ~/Anacondas/anaconda3/envs/cs231n/lib/python3.6/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     368             x, y = index_of(tup[-1])
#     369
# --> 370         x, y = self._xy_from_xy(x, y)
#     371
#     372         if self.command == 'plot':
#
# ~/Anacondas/anaconda3/envs/cs231n/lib/python3.6/site-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     229         if x.shape[0] != y.shape[0]:
#     230             raise ValueError("x and y must have same first dimension, but "
# --> 231                              "have shapes {} and {}".format(x.shape, y.shape))
#     232         if x.ndim > 2 or y.ndim > 2:
#     233             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (1,) and (4200,)
